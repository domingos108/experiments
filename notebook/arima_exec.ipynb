# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'scnexpsv1'

seazonal_list= [
    1, 
    12, 
    12, 
    1, 
    1,
    1, 
    1, 
    1,
    1,
    12,
    1,
    1,
    1,
    4
]

# %%
base_name_list
# Out:
# ['sunspot.txt',
#  'coloradoRiver.txt',
#  'milk.txt',
#  'Unemployment.txt',
#  'ausbee.txt',
#  'austres.txt',
#  'heartrate.txt',
#  'ozon.txt',
#  'pollution.txt',
#  'redwine.txt',
#  'gasoline.txt',
#  'temperature.txt',
#  'woolyrnq.txt',
#  'taylor.txt']

# %%
len(seazonal_list), len(base_name_list)
# Out:
# (14, 14)

# %%
for base_name, seazonal_lag in zip(base_name_list, seazonal_list):
    print(base_name)
    exec_training_testing(base_name, experiment_id, model_name, seazonal_lag)
# Out:
# sunspot.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1910.447, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=2286.428, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=2038.922, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=2086.508, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2509.238, Time=0.00 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1934.925, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1908.565, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1966.744, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1909.389, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=1909.464, Time=0.16 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=1908.404, Time=0.04 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=1910.362, Time=0.06 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=1912.345, Time=0.08 sec
# ...
