# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.simplefilter('ignore', InterpolationWarning)

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np

from sklearn.neural_network import MLPRegressor
import pandas as pd
from tqdm.notebook import tqdm

# %load_ext autoreload
# %autoreload 2

# %%
for parms in tqdm([
    {'max_it': 1, 'learning_rate': 0.01},
    {'max_it': 2, 'learning_rate': 0.01},
    {'max_it': 3, 'learning_rate':  0.01},
     {'max_it': 5, 'learning_rate': 0.01},
    {'max_it': 10, 'learning_rate': 0.01},
    {'max_it': 20, 'learning_rate':  0.01},
    {'max_it': 40, 'learning_rate':  0.01},

    {'max_it': 1, 'learning_rate': 0.1},
    {'max_it': 2, 'learning_rate': 0.1},
    {'max_it': 3, 'learning_rate':  0.1},
     {'max_it': 5, 'learning_rate': 0.1},
    {'max_it': 10, 'learning_rate': 0.1},
    {'max_it': 20, 'learning_rate':  0.1},
    {'max_it': 40, 'learning_rate':  0.1},
    
    {'max_it': 1, 'learning_rate': 0.5},
    {'max_it': 2, 'learning_rate': 0.5},
    {'max_it': 3, 'learning_rate':  0.5},
     {'max_it': 5, 'learning_rate': 0.5},
    {'max_it': 10, 'learning_rate': 0.5},
    {'max_it': 20, 'learning_rate':  0.5},
    {'max_it': 40, 'learning_rate':  0.5},
    
      {'max_it': 1, 'learning_rate': 1},
    {'max_it': 2, 'learning_rate': 1},
    {'max_it': 3, 'learning_rate':  1},
     {'max_it': 5, 'learning_rate': 1},
    {'max_it': 10, 'learning_rate': 1},
    {'max_it': 20, 'learning_rate':  1},
    {'max_it': 40, 'learning_rate':  1},
    
]
):
    model = MLPRegressor(activation='logistic', solver='lbfgs') 
    
    experiment_id = 'arimarec'
    model_name = f"mlp-{parms['max_it']}-{parms['learning_rate']}"
    normalize = True
    force = True
    model_exec = 10
    experiment_params = {
        'linear_model_name': 'arima',
        "lag_size": None,
        "max_it": parms['max_it'],
        "learning_rate": parms['learning_rate'],
        "diff_kpss": False
        
    }
    
    model_parameters = {
        'hidden_layer_sizes': [2, 5, 10, 15, 20, 50], 
        'max_iter': [1000],
    }
    
    grid_search_exp.grid_seach_multiple_bases(
         hybrid_system_exp.RecursiveAdditive, model, normalize, model_parameters,experiment_params,
         model_exec, model_name, experiment_id, force = force
    )
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# ...
