# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np

from sklearn.neural_network import MLPRegressor
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %%
model = MLPRegressor(activation='logistic', solver='lbfgs') 

experiment_id = 'scnexpsv1'
model_name = 'arimamlpnonlinear'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'linear_model_name': 'arima',
    'diff_kpss': True,
    "lag_size": None,
    "use_linear": True,
    "use_error": True,
    "use_series": True
}
model_parameters = {
    'hidden_layer_sizes': [2, 5, 10, 15, 20, 50], 
    'max_iter': [1000],
}

# %%
grid_search_exp.grid_seach_multiple_bases(
     hybrid_system_exp.NonLinear, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# coloradoRiver.txt
# sunspot.txt
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# milk.txt
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# Unemployment.txt
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
# ...
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sktime/param_est/stationarity/_statsmodels.py:255: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   res = kpss(
