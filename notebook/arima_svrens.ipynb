# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np

from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor
import pandas as pd

# %load_ext autoreload
# %autoreload 2
    
for n_estimators in [100]:
    for max_samples in [0.8]:
        for max_features in [0.8]:
            for hidden_layer_sizes in [10, 20, 50]:
                model = BaggingRegressor()
                max_samples: []
                experiment_id = 'consumoenergiav2'
                model_name = f'arimamlpn{n_estimators}s{max_samples}f{max_features}'
                normalize = True
                force = False
                model_exec = 10
                
                experiment_params = {
                    'linear_model_name': '1arimaval',
                    "lag_size": 12,
                    'diff_kpss': False,
                    'horizon': 1
                    
                }
                
                model_parameters = {
                    'estimator': [
                        SVR(max_iter=100000, C=10, epsilon = 0.1, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=100, epsilon = 0.1, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=1000, epsilon = 0.1, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=10, epsilon = 0.01, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=100, epsilon = 0.01, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=1000, epsilon = 0.01, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=10, epsilon = 0.001, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=100, epsilon = 0.001, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=1000, epsilon = 0.001, gamma='auto', kernel='rbf', tol=0.001),
                    ], 
                    'n_estimators': [n_estimators],
                    'max_features': [max_features],
                    'max_samples': [max_samples]
                    
                }
        
                grid_search_exp.grid_seach_multiple_bases(
                     hybrid_system_exp.Additive, model, normalize, model_parameters,experiment_params,
                     model_exec, model_name, experiment_id, force = force
                )
# Out:
# consumocoformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumoneformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumonoformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumosdformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumosulformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumocoformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumoneformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumonoformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumosdformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumosulformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# consumocoformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 55
#      29 experiment_params = {
#      30     'linear_model_name': '1arimaval',
#      31     "lag_size": 12,
#    (...)
#      34
#      35 }
#      37 model_parameters = {
#      38     'estimator': [
#      39         SVR(max_iter=100000, C=10, epsilon = 0.1, gamma='auto', kernel='rbf', tol=0.001),
#    (...)
#      52
#      53 }
# ---> 55 grid_search_exp.grid_seach_multiple_bases(
#      56      hybrid_system_exp.Additive, model, normalize, model_parameters,experiment_params,
#      57      model_exec, model_name, experiment_id, force = force
#      58 )
#
# File ~/experiments/src/model/grid_search_exp.py:160, in grid_seach_multiple_bases(fit_predict_class, model, normalize, model_parameters, experiment_params, model_exec, model_name, experiment_id, force, use_val_slipt_for_prev)
#     144     continue
#     146 exec_gs = GridSearch(
#     147     fit_predict_class,
#     148     model,
#    (...)
#     157     use_val_slipt_for_prev = use_val_slipt_for_prev
#     158 )
# --> 160 exec_gs.execution()
#
# File ~/experiments/src/model/grid_search_exp.py:94, in GridSearch.execution(self)
#      92 def execution(self):
# ---> 94     best_exec_val, best_params = self._search_params()
#      96     experiment_params = self.experiment_params.copy()
#      97     experiment_params['test_size'] = config.TEST_SIZE
#
# File ~/experiments/src/model/grid_search_exp.py:80, in GridSearch._search_params(self)
#      68     model_actual = clone(self.model).set_params(** params)
#      70 model_exp = self.model_class_exp(
#      71     model_actual,
#      72     self.experiment_id,
#    (...)
#      77     experiment_params
#      78 )
# ---> 80 model_exp.fit_predict()
#      81 metrics_results = model_exp.metrics_results
#      82 exec_list_metrics.append(
#      83     metrics_results.get(self.group_metrics_name, {self.metric: np.inf})[self.metric]
#      84 )
#
# File ~/experiments/src/model/hybrid_system_exp.py:92, in Additive.fit_predict(self)
#      85 def fit_predict(self):
#      87     (
#      88         error_series,
#      89         ts_forecast,
#      90         base_info,
#      91         exec_config
# ---> 92     ) = input_linear_info(
#      93         self.experiment_id,
#      94         self.base_name,
#      95         self.experiment_params,
#      96     )
#      97     original_ts = base_info.original_ts
#      98     test_size = base_info.test_size
#
# File ~/experiments/src/model/hybrid_system_exp.py:41, in input_linear_info(experiment_id, base_name, experiment_params)
#      27 exec_config = {
#      28     "test_size": experiment_params['test_size'],
#      29     "val_size": experiment_params['val_size'],
#      30     "horizon": experiment_params['horizon']
#      31 }
#      33 base_info = input.open_format_train_val_test(
#      34     base_name,
#      35     False,
#    (...)
#      38     diff_kpss
#      39 )
# ---> 41 pn = generics.open_saved_result(
#      42     linear_title
#      43 )[0]['experiment'].metrics_results
#      45 if pn['val_predict'] is not None:
#      46     ts_forecast = np.concatenate((pn['train_predict'],  pn['val_predict'], pn['test_predict']), axis=0)
#
# File ~/experiments/src/model/generics.py:131, in open_saved_result(title)
#     129 def open_saved_result(title):
# --> 131     with open(title, 'rb') as handle:
#     132         b = pkl.load(handle)
#     133     return b
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/domingossj/experiments/data/result/consumoenergiav2/consumocoformated_1arimaval.pkl'
