# %%
from pathlib import Path

import config
from utils.compare_fs_vs_baseline import build_comparison
from utils.export_metrics_to_csv import save_csv

# %load_ext autoreload
# %autoreload 2
# Out:
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\pydoc_data\topics.py' for module 'pydoc_data.topics': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 4751: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\urllib\parse.py' for module 'urllib.parse': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 2030: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\shlex.py' for module 'shlex': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1482: character maps to <undefined>
# Failed to read module file 'C:\Projetos\mestrado_codigos\experiments\src\utils\export_metrics_to_csv.py' for module 'utils.export_metrics_to_csv': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 3950: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\functools.py' for module 'functools': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 308: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\re\_casefix.py' for module 're._casefix': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 913: character maps to <undefined>

# %%
# === CELULA DE CONFIGURACAO -- Tarefa 3.2 (fluxo notebook-only) ===
# Edite aqui para comparar um conjunto diferente de rodadas. baseline_dir e
# SEMPRE data/result/chamados (os 5 baselines intocaveis da Secao 3 do
# CLAUDE.md) -- nunca aponte para uma pasta chamados_v*_fs_*, ver a nota
# "AMBIGUIDADE HISTORICA" em src/utils/compare_fs_vs_baseline.py sobre
# chamados_v2_fs_ftest (la, 1amv1 ja e a variante f_test, nao o baseline).
baseline_dir = Path(config.MODEL_DATA_PATH) / 'chamados'

# (rotulo, experiment_id) de cada variante de FS a comparar -- rotulo vira o
# prefixo das colunas no DataFrame de saida (<rotulo>_RMSE, <rotulo>_PctGain,
# <rotulo>_NFeatures).
fs_variants = [
    ('ftest', 'chamados_v4_fs_ftest'),
    ('mutualinfo', 'chamados_v4_fs_mutualinfo'),
    ('rfembedded', 'chamados_v4_fs_rfembedded'),
    ('lasso', 'chamados_v4_fs_lasso'),
    ('rfecv', 'chamados_v4_fs_rfecv')
]

output_path = Path(config.ROOT_PATH) / 'results' / 'chamados_v4_fs_comparison.csv'

# %%
# Compara o baseline x cada variante de FS lado a lado, por serie -- mesma
# funcao usada pela CLI (src/utils/compare_fs_vs_baseline.py), so o ponto de
# entrada muda (Tarefa 3.2, fluxo notebook-only). Equivale ao Passo 3 do
# RUNBOOK.md Secao 8b.
fs_dirs = {rotulo: Path(config.MODEL_DATA_PATH) / experiment_id for rotulo, experiment_id in fs_variants}

df_comparison = build_comparison(baseline_dir, fs_dirs)
save_csv(df_comparison, output_path, label='CSV de comparacao (baseline x variantes FS)')
df_comparison
# Out:
# [INFO] 90 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados'.
#
#   OK  airlines_1amv1.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  1 linha(s)
#   OK  airlines_1as.pkl  ->  1 linha(s)
#   OK  airlines_1mlp.pkl  ->  10 linha(s)
#   OK  airlines_1svr.pkl  ->  1 linha(s)
#   OK  ausbee_1amv1.pkl  ->  10 linha(s)
#   OK  ausbee_1arima.pkl  ->  1 linha(s)
#   OK  ausbee_1as.pkl  ->  1 linha(s)
#   OK  ausbee_1mlp.pkl  ->  10 linha(s)
#   OK  ausbee_1svr.pkl  ->  1 linha(s)
#   OK  austres_1amv1.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  1 linha(s)
#   OK  austres_1as.pkl  ->  1 linha(s)
#   OK  austres_1mlp.pkl  ->  10 linha(s)
#   OK  austres_1svr.pkl  ->  1 linha(s)
#   OK  coloradoRiver_1amv1.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  1 linha(s)
#   OK  coloradoRiver_1as.pkl  ->  1 linha(s)
#   OK  coloradoRiver_1mlp.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1svr.pkl  ->  1 linha(s)
#   OK  gasoline_1amv1.pkl  ->  10 linha(s)
#   OK  gasoline_1arima.pkl  ->  1 linha(s)
#   OK  gasoline_1as.pkl  ->  1 linha(s)
#   OK  gasoline_1mlp.pkl  ->  10 linha(s)
#   OK  gasoline_1svr.pkl  ->  1 linha(s)
#   OK  heartrate_1amv1.pkl  ->  10 linha(s)
#   OK  heartrate_1arima.pkl  ->  1 linha(s)
#   OK  heartrate_1as.pkl  ->  1 linha(s)
#   OK  heartrate_1mlp.pkl  ->  10 linha(s)
#   OK  heartrate_1svr.pkl  ->  1 linha(s)
#   OK  lakeerie_1amv1.pkl  ->  10 linha(s)
#   OK  lakeerie_1arima.pkl  ->  1 linha(s)
#   OK  lakeerie_1as.pkl  ->  1 linha(s)
#   OK  lakeerie_1mlp.pkl  ->  10 linha(s)
#   OK  lakeerie_1svr.pkl  ->  1 linha(s)
#   OK  lynx_1amv1.pkl  ->  10 linha(s)
#   OK  lynx_1arima.pkl  ->  1 linha(s)
#   OK  lynx_1as.pkl  ->  1 linha(s)
#   OK  lynx_1mlp.pkl  ->  10 linha(s)
#   OK  lynx_1svr.pkl  ->  1 linha(s)
#   OK  milk_1amv1.pkl  ->  10 linha(s)
#   OK  milk_1arima.pkl  ->  1 linha(s)
#   OK  milk_1as.pkl  ->  1 linha(s)
#   OK  milk_1mlp.pkl  ->  10 linha(s)
#   OK  milk_1svr.pkl  ->  1 linha(s)
#   OK  ozon_1amv1.pkl  ->  10 linha(s)
#   OK  ozon_1arima.pkl  ->  1 linha(s)
#   OK  ozon_1as.pkl  ->  1 linha(s)
#   OK  ozon_1mlp.pkl  ->  10 linha(s)
#   OK  ozon_1svr.pkl  ->  1 linha(s)
#   OK  pollution_1amv1.pkl  ->  10 linha(s)
#   OK  pollution_1arima.pkl  ->  1 linha(s)
#   OK  pollution_1as.pkl  ->  1 linha(s)
#   OK  pollution_1mlp.pkl  ->  10 linha(s)
#   OK  pollution_1svr.pkl  ->  1 linha(s)
#   OK  redwine_1amv1.pkl  ->  10 linha(s)
#   OK  redwine_1arima.pkl  ->  1 linha(s)
#   OK  redwine_1as.pkl  ->  1 linha(s)
#   OK  redwine_1mlp.pkl  ->  10 linha(s)
#   OK  redwine_1svr.pkl  ->  1 linha(s)
#   OK  samurec_1amv1.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  1 linha(s)
#   OK  samurec_1as.pkl  ->  1 linha(s)
#   OK  samurec_1mlp.pkl  ->  10 linha(s)
#   OK  samurec_1svr.pkl  ->  1 linha(s)
#   OK  sunspot_1amv1.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  1 linha(s)
#   OK  sunspot_1as.pkl  ->  1 linha(s)
#   OK  sunspot_1mlp.pkl  ->  10 linha(s)
#   OK  sunspot_1svr.pkl  ->  1 linha(s)
#   OK  temperature_1amv1.pkl  ->  10 linha(s)
#   OK  temperature_1arima.pkl  ->  1 linha(s)
#   OK  temperature_1as.pkl  ->  1 linha(s)
#   OK  temperature_1mlp.pkl  ->  10 linha(s)
#   OK  temperature_1svr.pkl  ->  1 linha(s)
#   OK  Unemployment_1amv1.pkl  ->  10 linha(s)
#   OK  Unemployment_1arima.pkl  ->  1 linha(s)
#   OK  Unemployment_1as.pkl  ->  1 linha(s)
#   OK  Unemployment_1mlp.pkl  ->  10 linha(s)
#   OK  Unemployment_1svr.pkl  ->  1 linha(s)
#   OK  windspeedfortaleza_1amv1.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  1 linha(s)
#   OK  windspeedfortaleza_1as.pkl  ->  1 linha(s)
#   OK  windspeedfortaleza_1mlp.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1svr.pkl  ->  1 linha(s)
#   OK  woolyrnq_1amv1.pkl  ->  10 linha(s)
#   OK  woolyrnq_1arima.pkl  ->  1 linha(s)
#   OK  woolyrnq_1as.pkl  ->  1 linha(s)
#   OK  woolyrnq_1mlp.pkl  ->  10 linha(s)
#   OK  woolyrnq_1svr.pkl  ->  1 linha(s)
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_ftest'.
#
#   OK  airlines_1amv1ftest.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  1 linha(s)
#   OK  austres_1amv1ftest.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  1 linha(s)
#   OK  coloradoRiver_1amv1ftest.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  1 linha(s)
#   OK  samurec_1amv1ftest.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  1 linha(s)
#   OK  sunspot_1amv1ftest.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  1 linha(s)
#   OK  windspeedfortaleza_1amv1ftest.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  1 linha(s)
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_ftest'.
#
#   OK  airlines_1amv1ftest.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  sem seletor -- ignorado
#   OK  austres_1amv1ftest.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  sem seletor -- ignorado
#   OK  coloradoRiver_1amv1ftest.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  sem seletor -- ignorado
#   OK  samurec_1amv1ftest.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  sem seletor -- ignorado
#   OK  sunspot_1amv1ftest.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  sem seletor -- ignorado
#   OK  windspeedfortaleza_1amv1ftest.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  sem seletor -- ignorado
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_mutualinfo'.
#
#   OK  airlines_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  1 linha(s)
#   OK  austres_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  1 linha(s)
#   OK  coloradoRiver_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  1 linha(s)
#   OK  samurec_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  1 linha(s)
#   OK  sunspot_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  1 linha(s)
#   OK  windspeedfortaleza_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  1 linha(s)
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_mutualinfo'.
#
#   OK  airlines_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  sem seletor -- ignorado
#   OK  austres_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  sem seletor -- ignorado
#   OK  coloradoRiver_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  sem seletor -- ignorado
#   OK  samurec_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  sem seletor -- ignorado
#   OK  sunspot_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  sem seletor -- ignorado
#   OK  windspeedfortaleza_1amv1mutualinfo.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  sem seletor -- ignorado
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_rfembedded'.
#
#   OK  airlines_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  1 linha(s)
#   OK  austres_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  1 linha(s)
#   OK  coloradoRiver_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  1 linha(s)
#   OK  samurec_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  1 linha(s)
#   OK  sunspot_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  1 linha(s)
#   OK  windspeedfortaleza_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  1 linha(s)
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_rfembedded'.
#
#   OK  airlines_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  sem seletor -- ignorado
#   OK  austres_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  sem seletor -- ignorado
#   OK  coloradoRiver_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  sem seletor -- ignorado
#   OK  samurec_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  sem seletor -- ignorado
#   OK  sunspot_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  sem seletor -- ignorado
#   OK  windspeedfortaleza_1amv1rfembedded.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  sem seletor -- ignorado
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_lasso'.
#
#   OK  airlines_1amv1lasso.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  1 linha(s)
#   OK  austres_1amv1lasso.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  1 linha(s)
#   OK  coloradoRiver_1amv1lasso.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  1 linha(s)
#   OK  samurec_1amv1lasso.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  1 linha(s)
#   OK  sunspot_1amv1lasso.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  1 linha(s)
#   OK  windspeedfortaleza_1amv1lasso.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  1 linha(s)
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_lasso'.
#
#   OK  airlines_1amv1lasso.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  sem seletor -- ignorado
#   OK  austres_1amv1lasso.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  sem seletor -- ignorado
#   OK  coloradoRiver_1amv1lasso.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  sem seletor -- ignorado
#   OK  samurec_1amv1lasso.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  sem seletor -- ignorado
#   OK  sunspot_1amv1lasso.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  sem seletor -- ignorado
#   OK  windspeedfortaleza_1amv1lasso.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  sem seletor -- ignorado
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_rfecv'.
#
#   OK  airlines_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  1 linha(s)
#   OK  austres_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  1 linha(s)
#   OK  coloradoRiver_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  1 linha(s)
#   OK  samurec_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  1 linha(s)
#   OK  sunspot_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  1 linha(s)
#   OK  windspeedfortaleza_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  1 linha(s)
# [INFO] 12 arquivo(s) .pkl encontrado(s) em 'C:\Projetos\mestrado_codigos\experiments\data\result\chamados_v4_fs_rfecv'.
#
#   OK  airlines_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  airlines_1arima.pkl  ->  sem seletor -- ignorado
#   OK  austres_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  austres_1arima.pkl  ->  sem seletor -- ignorado
#   OK  coloradoRiver_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  coloradoRiver_1arima.pkl  ->  sem seletor -- ignorado
#   OK  samurec_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  samurec_1arima.pkl  ->  sem seletor -- ignorado
#   OK  sunspot_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  sunspot_1arima.pkl  ->  sem seletor -- ignorado
#   OK  windspeedfortaleza_1amv1rfecv.pkl  ->  10 linha(s)
#   OK  windspeedfortaleza_1arima.pkl  ->  sem seletor -- ignorado
#
# [OK] CSV de comparacao (baseline x variantes FS) gerado em: C:\Projetos\mestrado_codigos\experiments\results\chamados_v4_fs_comparison.csv
#      18 linha(s) × 17 coluna(s)
#                  Serie  Baseline_RMSE  ftest_RMSE  ftest_PctGain  \
# 0         Unemployment      36.829564         NaN            NaN
# 1             airlines      17.436180   22.781014     -30.653700
# 2               ausbee      15.776063         NaN            NaN
# 3              austres      19.085848   19.202413      -0.610737
# 4        coloradoRiver       0.328696    0.326097       0.790683
# 5             gasoline     202.818488         NaN            NaN
# 6            heartrate       0.557998         NaN            NaN
# 7             lakeerie       0.385127         NaN            NaN
# 8                 lynx     384.822245         NaN            NaN
# 9                 milk       5.203431         NaN            NaN
# 10                ozon       1.049465         NaN            NaN
# 11           pollution    1069.570690         NaN            NaN
# 12             redwine     300.442448         NaN            NaN
# 13             samurec       6.957531    6.950392       0.102607
# 14             sunspot      19.072983   19.123798      -0.266420
# 15         temperature       2.772422         NaN            NaN
# 16  windspeedfortaleza       0.455899    0.436700       4.211218
# 17            woolyrnq     432.021395         NaN            NaN
#
#     ftest_NFeatures  mutualinfo_RMSE  mutualinfo_PctGain  \
# 0               NaN              NaN                 NaN
# 1               5.0        19.655233          -12.726717
# 2               NaN              NaN                 NaN
# 3               1.0        19.189379           -0.542445
# 4               9.0         0.329470           -0.235422
# 5               NaN              NaN                 NaN
# 6               NaN              NaN                 NaN
# 7               NaN              NaN                 NaN
# 8               NaN              NaN                 NaN
# 9               NaN              NaN                 NaN
# 10              NaN              NaN                 NaN
# 11              NaN              NaN                 NaN
# 12              NaN              NaN                 NaN
# 13              5.0         6.942275            0.219266
# 14              5.0        19.061434            0.060553
# 15              NaN              NaN                 NaN
# 16              5.0         0.409719           10.129469
# 17              NaN              NaN                 NaN
#
#     mutualinfo_NFeatures  rfembedded_RMSE  rfembedded_PctGain  \
# 0                    NaN              NaN                 NaN
# 1                    9.0        19.409056          -11.314841
# 2                    NaN              NaN                 NaN
# 3                    1.0        19.171959           -0.451173
# 4                   15.0         0.319745            2.723114
# 5                    NaN              NaN                 NaN
# 6                    NaN              NaN                 NaN
# 7                    NaN              NaN                 NaN
# 8                    NaN              NaN                 NaN
# 9                    NaN              NaN                 NaN
# 10                   NaN              NaN                 NaN
# 11                   NaN              NaN                 NaN
# 12                   NaN              NaN                 NaN
# 13                   9.0         6.935367            0.318556
# 14                   9.0        18.946771            0.661734
# 15                   NaN              NaN                 NaN
# 16                   1.0         0.455901           -0.000561
# 17                   NaN              NaN                 NaN
#
#     rfembedded_NFeatures  lasso_RMSE  lasso_PctGain  lasso_NFeatures  \
# 0                    NaN         NaN            NaN              NaN
# 1                    7.7   19.736261     -13.191428              1.0
# 2                    NaN         NaN            NaN              NaN
# 3                    1.0   19.276967      -1.001365              1.0
# 4                    4.0    0.322716       1.819443              1.0
# 5                    NaN         NaN            NaN              NaN
# 6                    NaN         NaN            NaN              NaN
# 7                    NaN         NaN            NaN              NaN
# 8                    NaN         NaN            NaN              NaN
# 9                    NaN         NaN            NaN              NaN
# 10                   NaN         NaN            NaN              NaN
# 11                   NaN         NaN            NaN              NaN
# 12                   NaN         NaN            NaN              NaN
# 13                   7.5    6.965624      -0.116326              1.0
# 14                   3.9   18.958174       0.601949              2.0
# 15                   NaN         NaN            NaN              NaN
# 16                   7.8    0.399673      12.333059              1.0
# 17                   NaN         NaN            NaN              NaN
#
#     rfecv_RMSE  rfecv_PctGain  rfecv_NFeatures
# 0          NaN            NaN              NaN
# 1    18.193204      -4.341688             15.1
# 2          NaN            NaN              NaN
# 3    18.966348       0.626121              1.0
# 4     0.330096      -0.425788             13.0
# 5          NaN            NaN              NaN
# 6          NaN            NaN              NaN
# 7          NaN            NaN              NaN
# 8          NaN            NaN              NaN
# 9          NaN            NaN              NaN
# 10         NaN            NaN              NaN
# 11         NaN            NaN              NaN
# 12         NaN            NaN              NaN
# 13    6.938519       0.273248             12.9
# 14   19.003210       0.365824              5.6
# 15         NaN            NaN              NaN
# 16    0.441205       3.223096             16.8
# 17         NaN            NaN              NaN
