# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.filterwarnings("ignore", category=UserWarning)
warnings.simplefilter('ignore', InterpolationWarning)

from model.elm import Model as ELM

from model import generics

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = config.BASE_NAME_LIST
normalize=True
force = True
model_exec = 10

parameters = {'hidden_dim': [20, 50, 100, 200, 500], 
              'time_window': [None]
        }

model = ELM() 
model_name = 'elm'
experiment_id = 'scnexps'

generics.grid_seach_multiple_bases(model,  base_name_list, normalize,
                                   parameters, model_exec, model_name, experiment_id, force = force)
# Out:
# sunspot.txt
#   0%|          | 0/5 [00:00<?, ?it/s]
# coloradoRiver.txt
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#      11 model_name = 'elm'
#      12 experiment_id = 'scnexps'
# ---> 14 generics.grid_seach_multiple_bases(model,  base_name_list, normalize,
#      15                                    parameters, model_exec, model_name, experiment_id, force = force)
#
# File ~/experiments/src/model/generics.py:249, in grid_seach_multiple_bases(model, base_name_list, normalize, parameters, model_exec, model_name, experiment_id, force, diff_kpss)
#     247 for base_name in base_name_list:
#     248     print(base_name)
# --> 249     grid_seach(model,  base_name,
#     250                normalize,
#     251                parameters, model_exec,
#     252                model_name, experiment_id,
#     253                 group_metrics_name = 'val_metrics', metric = 'RMSE', force = force, diff_kpss = diff_kpss)
#
# File ~/experiments/src/model/generics.py:213, in grid_seach(model, base_name, normalize, parameters, model_exec, model_name, experiment_id, group_metrics_name, metric, force, diff_kpss)
#     209     list_metrics.append(np.mean(local_metrics))
#     211 int_arg_min = np.argmin(list_metrics)
# --> 213 predict_results = predict_test_set(model, base_name, normalize,
#     214                                    model_exec,
#     215                                    list_params[int_arg_min], list_metrics[int_arg_min], diff_kpss)
#     217 save_result(fold, title, predict_results)
#
# File ~/experiments/src/model/generics.py:237, in predict_test_set(model, base_name, normalize, model_exec, best_params, best_metric, diff_kpss)
#     235 for k in range(0, model_exec):
#     236     forecaster = clone(model).set_params(** params_actual)
# --> 237     result = fit_predict_model(forecaster, base_name, normalize, lag_size, exec_config, diff_kpss)
#     238     result['params'] = best_params
#     239     result['best_metric'] = best_metric
#
# File ~/experiments/src/model/generics.py:88, in fit_predict_model(model, base_name, normalize, lag_size, exec_config, diff_kpss)
#      75     (
#      76         train_predict,
#      77         val_predict,
#      78         test_predict,
#      79         time_exec
#      80     ) = fit_predict_ts_schemma(model, ts_univariate, test_size, val_size)
#      82 else:
#      83     (
#      84         train_predict,
#      85         val_predict,
#      86         test_predict,
#      87         time_exec
# ---> 88     ) = fit_predict_ml_schemma(model,x_train, y_train, x_val, x_test)
#      90 y_train_original = original_ts[0:-(test_size+val_size)][- len(train_predict):]
#      91 y_test_original = original_ts[-test_size:]
#
# File ~/experiments/src/model/generics.py:28, in fit_predict_ml_schemma(model, x_train, y_train, x_val, x_test)
#      25 if x_val.shape[0]>0:
#      26     val_predict = model.predict(x_val)
# ---> 28 train_predict = model.predict(x_train)
#      30 time_exec = {
#      31     'training': end_time_training - start_time_training,
#      32     'testing': end_time_test - start_time_test
#      33 }
#      35 return train_predict, val_predict, test_predict, time_exec
#
# File ~/experiments/src/model/elm.py:41, in Model.predict(self, x)
#      39 x = np.matrix(x)
#      40 if self.solver == 'sigmoid':
# ---> 41     hidden_activation = self.sigmoid(x @ self.W1)
#      42 elif self.solver == 'linear':
#      43     hidden_activation = x @ self.W1
#
# File ~/experiments/.venv/lib/python3.10/site-packages/numpy/matrixlib/defmatrix.py:168, in matrix.__array_finalize__(self, obj)
#     163     ret = N.ndarray.__new__(subtype, shape, arr.dtype,
#     164                             buffer=arr,
#     165                             order=order)
#     166     return ret
# --> 168 def __array_finalize__(self, obj):
#     169     self._getitem = False
#     170     if (isinstance(obj, matrix) and obj._getitem): return
#
# KeyboardInterrupt:
