# %%
import glob
import pandas as pd

from model import generics
from input import input
from posmodel import model_comb

import config
# %load_ext autoreload
# %autoreload 2

experiment_id = 'windspeed'

# %%
modelo_list = [ '1nhits10', '1nhits20',
       '1nhits30', '1nhits40', '1nhits50', '1nhits60', '1nhits70',
       '1nhits80']
for rc in [3, 6, 12]:
    for k in [3, 5]:
        for ens_type in ['mostrecent']:
            print(f'{rc}{k}')
            ds_args = {
                'rc': rc, # 5, 10, 20
                'k': k,  # 1, 3, 5
                'lag_size': rc
            } 
               
            model_comb.exec_ensemble(experiment_id, modelo_list, ens_type = ens_type, ds_args = ds_args)
# Out:
# 33
# 35
# 63
# 65
# 123
# 125

# %%
model_comb.exec_ensemble(experiment_id, [ '1nhits10', '1nhits20',
       '1nhits30', '1nhits40', '1nhits50', '1nhits60', '1nhits70',
       '1nhits80'], ens_type = 'fixedweights', ds_args = {})
# Out:
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
# ...

# %%
'fixedweights', 'ds', 'mean', 'mostrecent'
