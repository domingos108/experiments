# %%
import glob
import pandas as pd

from model import generics
from input import input

import config
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
experiment_id = 'consumoenergia'
modelo_list = [ 'scn', 'arima', 'mlp', 'nhits' , 'svr']

# %%
from posmodel import model_comb
model_comb.exec_mean_ensemble(experiment_id, modelo_list)
