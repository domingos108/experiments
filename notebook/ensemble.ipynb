# %%
import glob
import pandas as pd

from model import generics
from input import input

import config
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
experiment_id = 'consumoenergia'
modelo_list = [ '1scnval', '1arimaval', '1mlpval' , '1svrval']

# %%
from posmodel import model_comb
for rc in [5, 10, 20]:
    for k in [1]:
        ds_args = {
            'rc': rc, # 5, 10, 20
            'k': k,  # 1, 3, 5
            'lag_size': 12
        }
        model_comb.exec_ensemble(experiment_id, modelo_list, ens_type = 'ds', ds_args = ds_args)
