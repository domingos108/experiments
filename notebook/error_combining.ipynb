# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np
from sklearn.neural_network import MLPRegressor

import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = MLPRegressor(activation='logistic', solver='lbfgs', max_iter=1000) 

experiment_id = 'consumoenergia'
model_name = 'comb'
normalize = True
force = True
model_exec = 1

experiment_params = {
    'nonlinear_model': 'arimascn',
    "lag_size": None,
    'diff_kpss': False,
    'test_size': config.TEST_SIZE,
    'val_size': 0
}

# %%
for base_name in config.BASE_NAME_LIST:
    print(base_name)
    
    rc = hybrid_system_exp.ResidualCombination(
        model,
        experiment_id, 
        base_name, 
        model_name, 
        force,
        normalize,
        experiment_params 
    )
    rc.exec_comb()
# Out:
# consumocoformated.txt
# consumoneformated.txt
# consumonoformated.txt
# consumosdformated.txt
# consumosulformated.txt
