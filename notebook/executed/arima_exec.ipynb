# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2
# Out:
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\pydoc_data\topics.py' for module 'pydoc_data.topics': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 4751: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\functools.py' for module 'functools': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 308: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\urllib\parse.py' for module 'urllib.parse': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 2030: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\re\_casefix.py' for module 're._casefix': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 913: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\shlex.py' for module 'shlex': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1482: character maps to <undefined>

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'chamados'
horizon = 1
force= False

# %%
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'], horizon, force)
# Out:
# airlines.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=766.298, Time=0.36 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=765.723, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=764.756, Time=0.04 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=765.328, Time=0.06 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=764.138, Time=0.02 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=764.944, Time=0.06 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=766.619, Time=0.11 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=765.206, Time=0.01 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=762.550, Time=0.05 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=765.329, Time=0.11 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=765.510, Time=0.12 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=767.126, Time=0.29 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=764.631, Time=0.02 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=766.465, Time=0.04 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=766.346, Time=0.05 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=766.167, Time=0.03 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=763.479, Time=0.12 sec
#  ARIMA(1,1,1)(0,1,0)[12] intercept   : AIC=766.438, Time=0.07 sec
#
# Best model:  ARIMA(1,1,1)(0,1,0)[12]
# Total fit time: 1.621 seconds
# ausbee.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1625.974, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1909.727, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1902.104, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1813.829, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1907.752, Time=0.00 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1714.266, Time=0.09 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1459.902, Time=0.15 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1492.877, Time=0.09 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=1466.107, Time=0.15 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=1463.642, Time=0.14 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=1491.429, Time=0.13 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=1462.691, Time=0.15 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1462.248, Time=0.08 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0] intercept
# Total fit time: 1.428 seconds
# austres.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=504.372, Time=0.10 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=518.210, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=510.096, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=505.742, Time=0.01 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=509.724, Time=0.05 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=509.397, Time=0.03 sec
#  ARIMA(3,2,2)(0,0,0)[0]             : AIC=489.632, Time=0.08 sec
#  ARIMA(3,2,1)(0,0,0)[0]             : AIC=501.800, Time=0.05 sec
#  ARIMA(4,2,2)(0,0,0)[0]             : AIC=490.573, Time=0.13 sec
#  ARIMA(3,2,3)(0,0,0)[0]             : AIC=506.036, Time=0.13 sec
#  ARIMA(2,2,3)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(4,2,1)(0,0,0)[0]             : AIC=498.999, Time=0.05 sec
#  ARIMA(4,2,3)(0,0,0)[0]             : AIC=492.586, Time=0.14 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=491.617, Time=0.10 sec
#
# Best model:  ARIMA(3,2,2)(0,0,0)[0]
# Total fit time: 1.022 seconds
# coloradoRiver.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=1340.110, Time=0.68 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1988.866, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1623.949, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1800.940, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1986.866, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=1623.991, Time=0.55 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=1343.821, Time=1.80 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=2.09 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=1576.703, Time=1.26 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=1425.433, Time=1.50 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=1302.494, Time=1.83 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=1328.947, Time=1.57 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=1.68 sec
#  ARIMA(3,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=1.86 sec
#  ARIMA(2,1,3)(2,0,2)[12] intercept   : AIC=inf, Time=2.34 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=1.58 sec
#  ARIMA(1,1,3)(2,0,2)[12] intercept   : AIC=1312.200, Time=2.04 sec
#  ARIMA(3,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(3,1,3)(2,0,2)[12] intercept   : AIC=inf, Time=2.45 sec
#  ARIMA(2,1,2)(2,0,2)[12]             : AIC=inf, Time=1.47 sec
#
# Best model:  ARIMA(2,1,2)(2,0,2)[12] intercept
# Total fit time: 28.076 seconds
# gasoline.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=8884.910, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=8699.867, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=8595.636, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=8882.965, Time=0.00 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=8595.052, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=8597.156, Time=0.15 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=8597.088, Time=0.14 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=8595.159, Time=0.08 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=8632.063, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=8594.482, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=8594.946, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=8698.074, Time=0.00 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=8596.184, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=8596.325, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=8594.232, Time=0.06 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=8596.276, Time=0.04 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=inf, Time=0.19 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 1.408 seconds
# heartrate.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=204.820, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=634.801, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=320.556, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1432.602, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=206.718, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=204.733, Time=0.10 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=357.193, Time=0.07 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=256.335, Time=0.12 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=210.904, Time=0.09 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0] intercept
# Total fit time: 1.356 seconds
# lakeerie.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=965.729, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=742.965, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=797.268, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=963.731, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=815.079, Time=0.02 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=674.227, Time=0.41 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=702.724, Time=0.31 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=676.153, Time=0.51 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=676.184, Time=0.63 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=677.928, Time=0.36 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=676.947, Time=1.04 sec
#  ARIMA(1,1,0)(2,0,0)[12]             : AIC=672.228, Time=0.18 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=740.967, Time=0.06 sec
#  ARIMA(1,1,0)(2,0,1)[12]             : AIC=inf, Time=0.93 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=inf, Time=0.32 sec
#  ARIMA(0,1,0)(2,0,0)[12]             : AIC=700.724, Time=0.09 sec
#  ARIMA(2,1,0)(2,0,0)[12]             : AIC=674.154, Time=0.22 sec
#  ARIMA(1,1,1)(2,0,0)[12]             : AIC=674.185, Time=0.27 sec
#  ARIMA(0,1,1)(2,0,0)[12]             : AIC=675.928, Time=0.18 sec
#  ARIMA(2,1,1)(2,0,0)[12]             : AIC=674.947, Time=0.49 sec
#
# Best model:  ARIMA(1,1,0)(2,0,0)[12]
# Total fit time: 8.158 seconds
# lynx.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1520.716, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1625.985, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1562.481, Time=0.00 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1555.151, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1680.540, Time=0.00 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1529.580, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1521.739, Time=0.03 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=1522.906, Time=0.08 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=1524.267, Time=0.13 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1533.095, Time=0.02 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=1532.339, Time=0.09 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=1523.724, Time=0.04 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=1526.008, Time=0.09 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1541.215, Time=0.02 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0] intercept
# Total fit time: 0.661 seconds
# milk.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=747.605, Time=0.43 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=915.578, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=748.463, Time=0.14 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=1081.250, Time=0.01 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=746.971, Time=0.44 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=776.737, Time=0.17 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=748.460, Time=0.84 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=752.826, Time=0.37 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=749.305, Time=0.98 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=744.925, Time=0.21 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=776.698, Time=0.08 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=746.703, Time=0.39 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=746.774, Time=0.61 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=750.861, Time=0.25 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=748.477, Time=0.74 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=784.027, Time=0.24 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=742.992, Time=0.22 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=774.903, Time=0.05 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=744.737, Time=0.37 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=744.817, Time=0.50 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=749.312, Time=0.16 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=746.572, Time=0.60 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=741.453, Time=0.13 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=773.431, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=743.114, Time=0.26 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=743.213, Time=0.54 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=745.366, Time=0.63 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=742.977, Time=0.16 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=744.976, Time=0.28 sec
#  ARIMA(1,0,0)(0,1,1)[12]             : AIC=749.213, Time=0.10 sec
#
# Best model:  ARIMA(1,0,0)(0,1,1)[12] intercept
# Total fit time: 10.340 seconds
# ozon.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=499.418, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=619.247, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=534.031, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=558.730, Time=0.01 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=903.409, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=524.714, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=496.140, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=534.300, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=532.443, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=475.858, Time=0.09 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=509.027, Time=0.05 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=472.449, Time=0.13 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=482.576, Time=0.05 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=474.428, Time=0.17 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=477.755, Time=0.13 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=473.659, Time=0.13 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=480.399, Time=0.14 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : AIC=476.782, Time=0.17 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=556.777, Time=0.05 sec
#
# Best model:  ARIMA(4,0,1)(0,0,0)[0] intercept
# Total fit time: 1.502 seconds
# pollution.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1478.467, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1535.690, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1517.873, Time=0.00 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1490.670, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1533.918, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1487.977, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1476.569, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1492.336, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1474.891, Time=0.02 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1476.634, Time=0.02 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1478.568, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=1476.000, Time=0.02 sec
#
# Best model:  ARIMA(2,1,0)(0,0,0)[0] intercept
# Total fit time: 0.472 seconds
# redwine.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=2120.007, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2215.425, Time=0.00 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2083.776, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2142.364, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2213.679, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=2209.478, Time=0.04 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=2075.690, Time=0.24 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=2148.628, Time=0.08 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=2059.681, Time=0.46 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=2063.566, Time=0.48 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=2084.128, Time=0.40 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=2057.304, Time=0.65 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=2070.775, Time=0.24 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=2077.267, Time=0.19 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=2058.251, Time=0.54 sec
#  ARIMA(3,1,0)(2,0,1)[12] intercept   : AIC=2051.501, Time=0.59 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=2056.620, Time=0.30 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(3,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=2073.369, Time=0.22 sec
#  ARIMA(3,1,0)(1,0,2)[12] intercept   : AIC=2073.076, Time=0.54 sec
#  ARIMA(4,1,0)(2,0,1)[12] intercept   : AIC=2067.053, Time=0.73 sec
#  ARIMA(3,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=2069.906, Time=0.60 sec
#  ARIMA(4,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.88 sec
# C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\pmdarima\arima\_auto_solvers.py:524: ModelFitWarning: Error fitting  ARIMA(3,1,0)(2,0,1)[12]           (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\pmdarima\arima\_auto_solvers.py", line 508, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\pmdarima\arima\arima.py", line 610, in fit
#     self._fit(y, X, **fit_args)
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\pmdarima\arima\arima.py", line 531, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#                            ^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\pmdarima\arima\arima.py", line 517, in _fit_wrapper
#     fitted = arima.fit(
#              ^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 705, in fit
#     mlefit = super().fit(start_params, method=method,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\base\model.py", line 566, in fit
#     xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\base\optimizer.py", line 245, in _fit
#     xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\base\optimizer.py", line 665, in _fit_lbfgs
#     retvals = optimize.fmin_l_bfgs_b(
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\scipy\optimize\_lbfgsb_py.py", line 281, in fmin_l_bfgs_b
#     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\scipy\optimize\_lbfgsb_py.py", line 469, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py", line 412, in fun_and_grad
#     self._update_fun()
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py", line 362, in _update_fun
#     fx = self._wrapped_fun(self.x)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\scipy\_lib\_util.py", line 603, in __call__
#     fx = self.f(np.copy(x), *self.args)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\base\model.py", line 534, in f
#     return -self.loglike(params, *args) / nobs
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\tsa\statespace\mlemodel.py", line 940, in loglike
#     loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 1001, in loglike
#     kfilter = self._filter(**kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py", line 921, in _filter
#     self._initialize_state(prefix=prefix, complex_step=complex_step)
#   File "C:\Users\joaol\mestrado_codigos\experiments\.venv\Lib\site-packages\statsmodels\tsa\statespace\representation.py", line 1058, in _initialize_state
#     self._statespaces[prefix].initialize(self.initialization,
#   File "statsmodels/tsa/statespace/_representation.pyx", line 1373, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels/tsa/statespace/_representation.pyx", line 1362, in statsmodels.tsa.statespace._representation.dStatespace.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 288, in statsmodels.tsa.statespace._initialization.dInitialization.initialize
#   File "statsmodels/tsa/statespace/_initialization.pyx", line 406, in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov
#   File "statsmodels/tsa/statespace/_tools.pyx", line 1548, in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov
# numpy.linalg.LinAlgError: LU decomposition error.
#
#   warnings.warn(warning_str, ModelFitWarning)
#  ARIMA(3,1,0)(2,0,1)[12]             : AIC=inf, Time=nan sec
#
# Best model:  ARIMA(3,1,0)(2,0,1)[12] intercept
# Total fit time: 12.418 seconds
# sunspot.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1917.682, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=2295.737, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=2047.359, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=2094.824, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2519.238, Time=0.00 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1942.247, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1915.798, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1974.409, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1916.637, Time=0.05 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=1917.082, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=1915.639, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=1917.600, Time=0.09 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=1919.584, Time=0.11 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=1971.700, Time=0.03 sec
#
# Best model:  ARIMA(3,0,0)(0,0,0)[0] intercept
# Total fit time: 0.888 seconds
# taylor.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=47930.970, Time=3.37 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=64855.737, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=53342.486, Time=0.87 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=60440.685, Time=1.44 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=75706.295, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=47944.923, Time=1.25 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=47943.020, Time=3.71 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=inf, Time=4816.78 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=47908.542, Time=8.70 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=47915.305, Time=3.13 sec
#  ARIMA(2,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=10.79 sec
#  ARIMA(1,0,2)(1,0,2)[12] intercept   : AIC=49148.028, Time=7.88 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=48299.724, Time=7.12 sec
#  ARIMA(3,0,2)(1,0,2)[12] intercept   : AIC=47941.286, Time=10.46 sec
#  ARIMA(2,0,3)(1,0,2)[12] intercept   : AIC=47922.418, Time=8.27 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=51652.060, Time=6.57 sec
#  ARIMA(1,0,3)(1,0,2)[12] intercept   : AIC=48235.250, Time=6.91 sec
#  ARIMA(3,0,1)(1,0,2)[12] intercept   : AIC=48560.786, Time=8.88 sec
#  ARIMA(3,0,3)(1,0,2)[12] intercept   : AIC=47947.094, Time=10.22 sec
#  ARIMA(2,0,2)(1,0,2)[12]             : AIC=inf, Time=6.86 sec
#
# Best model:  ARIMA(2,0,2)(1,0,2)[12] intercept
# Total fit time: 4923.271 seconds
# temperature.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1292.468, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1375.242, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1170.744, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1222.044, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2046.902, Time=0.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1081.665, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=1020.117, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=990.253, Time=0.14 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=981.595, Time=0.18 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=981.841, Time=0.22 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=985.700, Time=0.16 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 1.064 seconds
# Unemployment.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2018.922, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=2425.004, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=2116.249, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=2218.028, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2842.629, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=2042.523, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=2021.121, Time=0.09 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=2032.332, Time=0.14 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=2011.596, Time=0.16 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=2004.571, Time=0.14 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=2016.028, Time=0.16 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=2126.083, Time=0.16 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=2019.314, Time=0.19 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=2008.410, Time=0.23 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=2033.236, Time=0.10 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0] intercept
# Total fit time: 1.806 seconds
# woolyrnq.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[4] intercept   : AIC=1465.465, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=1528.568, Time=0.00 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=1478.631, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=1502.714, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=1526.651, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[4] intercept   : AIC=1464.750, Time=0.14 sec
#  ARIMA(2,1,2)(0,0,0)[4] intercept   : AIC=1463.365, Time=0.10 sec
#  ARIMA(2,1,2)(1,0,0)[4] intercept   : AIC=1464.576, Time=0.18 sec
#  ARIMA(1,1,2)(0,0,0)[4] intercept   : AIC=1507.733, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,0)[4] intercept   : AIC=1483.332, Time=0.07 sec
#  ARIMA(3,1,2)(0,0,0)[4] intercept   : AIC=1459.815, Time=0.09 sec
#  ARIMA(3,1,2)(1,0,0)[4] intercept   : AIC=1461.650, Time=0.19 sec
#  ARIMA(3,1,2)(0,0,1)[4] intercept   : AIC=1461.859, Time=0.19 sec
#  ARIMA(3,1,2)(1,0,1)[4] intercept   : AIC=1464.694, Time=0.21 sec
#  ARIMA(3,1,1)(0,0,0)[4] intercept   : AIC=1470.873, Time=0.10 sec
#  ARIMA(3,1,3)(0,0,0)[4] intercept   : AIC=1460.152, Time=0.14 sec
#  ARIMA(2,1,3)(0,0,0)[4] intercept   : AIC=1461.133, Time=0.11 sec
#  ARIMA(3,1,2)(0,0,0)[4]             : AIC=1457.933, Time=0.08 sec
#  ARIMA(3,1,2)(1,0,0)[4]             : AIC=1459.863, Time=0.14 sec
#  ARIMA(3,1,2)(0,0,1)[4]             : AIC=1460.192, Time=0.13 sec
#  ARIMA(3,1,2)(1,0,1)[4]             : AIC=1459.770, Time=0.18 sec
#  ARIMA(2,1,2)(0,0,0)[4]             : AIC=1461.488, Time=0.08 sec
#  ARIMA(3,1,1)(0,0,0)[4]             : AIC=1469.049, Time=0.07 sec
#  ARIMA(3,1,3)(0,0,0)[4]             : AIC=1458.417, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[4]             : AIC=1481.536, Time=0.01 sec
#  ARIMA(2,1,3)(0,0,0)[4]             : AIC=1459.261, Time=0.11 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[4]
# Total fit time: 2.875 seconds
