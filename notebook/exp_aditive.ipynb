# %%
from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np

from sklearn.neural_network import MLPRegressor
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %%
model = MLPRegressor(activation='logistic', solver='adam') 
experiment_id = 'scnexps'
base_name = "sunspot"
model_name = 'arimasvr'
normalize = True
force = False
experiment_params = {
    'linear_model_name': 'arima',
    "lag_size": 12
}

# %%
exec_gs = grid_search_exp.GridSearch(
    hybrid_system_exp.Additive,
    model,
    experiment_id, 
    base_name, 
    model_name, 
    force,
    normalize,
    experiment_params
)

# %%
exec_gs.search_params()
# Out:
# --Return--
# None
# > /home/domingossj/experiments/src/model/grid_search_exp.py(78)search_params()
#      76         generics.save_result(self.fold, self.title, predict_results)
#      77
# ---> 78         import ipdb;ipdb.set_trace()
# ipdb>  exit
