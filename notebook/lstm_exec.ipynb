# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from model.lstm import CustomLSTM

from model import single_ml_model_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
# Out:
# 2025-12-14 01:03:43.462929: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-14 01:03:43.528332: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-14 01:03:45.111547: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-14 01:03:45.806513: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model = CustomLSTM() 

experiment_id = 'pertexps'
model_name = 'lstm'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    "lag_size": None
}

model_parameters = {
    'hidden_layer_sizes': [20, 40, 60], 
    'epochs': [200],
}

# %%
grid_search_exp.grid_seach_multiple_bases(
     single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = True
)
# Out:
# coloradoRiver.txt
# Epoch 53: early stopping
# Restoring model weights from the end of the best epoch: 43.
# Restoring model weights from the end of the best epoch: 200.
# Restoring model weights from the end of the best epoch: 197.
# Restoring model weights from the end of the best epoch: 200.
# Epoch 50: early stopping
# Restoring model weights from the end of the best epoch: 40.
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 grid_search_exp.grid_seach_multiple_bases(
#       2      single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
#       3      model_exec, model_name, experiment_id, force = True
#       4 )
#
# ...
