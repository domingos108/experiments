# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np

from sklearn.neural_network import MLPRegressor
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = MLPRegressor(activation='logistic', solver='lbfgs') 

experiment_id = 'consumoenergia'
model_name = 'marimamlp'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'linear_model_name': 'marima',
    "lag_size": 12,
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'hidden_layer_sizes': [10, 20, 50], 
    'max_iter': [1000],
}

# %%
grid_search_exp.grid_seach_multiple_bases(
     hybrid_system_exp.HighLowAdditive, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# consumocoformated.txt
# > /home/domingossj/experiments/src/model/hybrid_system_exp.py(427)fit_predict()
#     426         import ipdb;ipdb.set_trace()
# --> 427         final_forecast = ts_forecast[lag_size:] + all_residual_forecasts
#     428
# ipdb>  ts_forecast
# array([   8.55430644, 1435.10099583, 1492.99481196, 1515.87378337,
#        1536.16337526, 1547.10781272, 1538.78543053, 1603.85880175,
#        1597.14800979, 1619.59043129, 1602.08724699, 1524.00296809,
#        1528.90674471, 1488.37043102, 1533.14361926, 1626.8733196 ,
#        1560.55078338, 1557.87458898, 1628.57886654, 1647.1653926 ,
#        1713.9692684 , 1742.31624687, 1609.55112111, 1626.23358332,
#        1643.03905196, 1568.26257288, 1660.08088387, 1731.96973628,
#        1667.77899742, 1646.85786462, 1740.60435658, 1731.62566204,
#        1753.31166304, 1771.79404766, 1734.88227172, 1684.34133218,
#        1630.5850616 , 1689.95710973, 1714.89787387, 1728.51982124,
# ...

# %%
from model import hybrid_system_exp, arima

# %%
experiment_params  = {'linear_model_name': 'marima', 'lag_size': 12, 'diff_kpss': False, 'test_size': 0.1, 'val_size': 0.1, 'horizon': 1}
(error_series,
ts_forecast,
base_info,
exec_config )= hybrid_system_exp.input_linear_info('consumoenergia', 'consumoneformated.txt', experiment_params, 'teste')

# %%
# Out:
# array([4417.5, 4443. , 4416.5, 4392.5, 4407.5, 4504.5, 4614. , 4683. ,
#        4739.5, 4773. , 4650.5, 4609. , 4683.5, 4707. , 4657. , 4609.5,
#        4692. , 4752. , 4807. , 4884.5, 4962. , 4959. , 4808.5, 4840. ,
#        4916. , 4825. , 4782. , 4765. , 4849.5, 4945. , 5046.5, 5137.5,
#        5128. , 5154. , 5034. , 4934. , 5051.5, 5125.5, 5106.5, 5106. ,
#        5172.5, 5180.5, 5294.5, 5472. , 5525. , 5526. , 5395. , 5325.5,
#        5316.5, 5352. , 5339. , 5287.5, 5367. , 5431. , 5573.5, 5635.5,
#        5561. , 5438. , 5219.5, 5245. , 5349.5, 5249. , 5156. , 5189.5,
#        5379. , 5541. , 5680.5, 5743. , 5837. , 5854. , 5664.5, 5854. ,
#        6001.5, 5922. , 5933. , 5875. , 5838.5, 5864.5, 6009.5, 6129.5,
#        6151. , 6077.5, 5746. , 5765. , 5997. , 5933. , 5854. , 5873. ,
#        6015. , 6093. , 6154.5, 6177. , 6191. , 6271. , 6154. , 6209. ,
#        6340. , 6354. , 6285.5, 6123.5, 6218. , 6306. , 6358. , 6424.5,
# ...

# %%
pd.DataFrame(
    {'real': base_info.original_ts[-250:],
     'ma': arima.ma_filter(2, base_info.original_ts)[-250:],
     'ts_forecast':ts_forecast[-250:]
     
    }
).plot()
# Out:
# <Axes: >

# %%
arima.ma_filter(2, base_info.original_ts)
# Out:
# array([4181. , 4082. , 4123. , 4111.5, 4110. , 4107. , 4048.5, 4033.5,
#        4228. , 4378.5, 4405.5, 4454.5, 4298.5, 4256.5, 4417.5, 4443. ,
#        4416.5, 4392.5, 4407.5, 4504.5, 4614. , 4683. , 4739.5, 4773. ,
#        4650.5, 4609. , 4683.5, 4707. , 4657. , 4609.5, 4692. , 4752. ,
#        4807. , 4884.5, 4962. , 4959. , 4808.5, 4840. , 4916. , 4825. ,
#        4782. , 4765. , 4849.5, 4945. , 5046.5, 5137.5, 5128. , 5154. ,
#        5034. , 4934. , 5051.5, 5125.5, 5106.5, 5106. , 5172.5, 5180.5,
#        5294.5, 5472. , 5525. , 5526. , 5395. , 5325.5, 5316.5, 5352. ,
#        5339. , 5287.5, 5367. , 5431. , 5573.5, 5635.5, 5561. , 5438. ,
#        5219.5, 5245. , 5349.5, 5249. , 5156. , 5189.5, 5379. , 5541. ,
#        5680.5, 5743. , 5837. , 5854. , 5664.5, 5854. , 6001.5, 5922. ,
#        5933. , 5875. , 5838.5, 5864.5, 6009.5, 6129.5, 6151. , 6077.5,
#        5746. , 5765. , 5997. , 5933. , 5854. , 5873. , 6015. , 6093. ,
# ...
