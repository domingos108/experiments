# %%
from sklearn.ensemble import RandomForestRegressor
from model import generics

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = ['lynx.txt', 'sunspot.txt']
lag_size_list = [5, 18]
normalize=True

model_exec = 10

parameters ={'n_estimators': [50, 100, 200], 
                  'max_depth': [5, 10, 15],
                  'max_features': [0.6, 0.8, 1],
                  #'max_samples' : [0.6, 0.8, 1],
                  
                 }

model = RandomForestRegressor() 
model_name = 'rf'
experiment_id = 'test'

result = generics.grid_seach_multiple_bases(model,  base_name_list, normalize, lag_size_list, parameters, model_exec, model_name, experiment_id)
# Out:
# lynx.txt
# 100%|███████████████████████████████████████████| 27/27 [00:17<00:00,  1.58it/s]
# > /home/domingossj/experiments/src/model/generics.py(134)grid_seach()
#     133     import ipdb;ipdb.set_trace()
# --> 134     int_arg_min = np.argmin(list_metrics)
#     135
# ipdb>  c
# sunspot.txt
# 100%|███████████████████████████████████████████| 27/27 [00:23<00:00,  1.15it/s]
# > /home/domingossj/experiments/src/model/generics.py(134)grid_seach()
#     133
# --> 134     int_arg_min = np.argmin(list_metrics)
#     135
# ipdb>  c
