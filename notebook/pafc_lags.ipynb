# %%
from input import input
import config

# %%
normalize = True
diff_kpss = True
lag_size = None
exec_config = {
        "test_size": config.TEST_SIZE,
        "val_size": config.VAL_SIZE
    }
for base_name in config.BASE_NAME_LIST:
    (
        ts_univariate,
        df_train, 
        df_val,
        df_test, 
        min_max_scaler,
        test_size, 
        val_size,
        is_stationary, 
        original_ts
    ) = input.open_format_train_val_test(base_name, normalize, lag_size, exec_config, diff_kpss)
    print(f"Serie: {base_name} lags: {df_train.shape[1] -1}")
# Out:
# Serie: sunspot.txt lags: 18
# Serie: coloradoRiver.txt lags: 12
# Serie: milk.txt lags: 19
# Serie: Unemployment.txt lags: 16
# Serie: ausbee.txt lags: 20
# Serie: austres.txt lags: 13
# Serie: heartrate.txt lags: 6
# Serie: ozon.txt lags: 17
# Serie: pollution.txt lags: 20
# Serie: redwine.txt lags: 19
# Serie: taylor.txt lags: 19
# Serie: gasoline.txt lags: 8
# Serie: temperature.txt lags: 20
# Serie: woolyrnq.txt lags: 16
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sktime/param_est/stationarity/_statsmodels.py:256: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   res = kpss(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sktime/param_est/stationarity/_statsmodels.py:256: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# ...

# %%
df_train.shape[1] -1
# Out:
# 18
