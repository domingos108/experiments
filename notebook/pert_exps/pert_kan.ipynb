# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import RMSE
import torch.optim as optim

from model import perturbative_neural_forecast, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

experiment_id = 'resudualens'
normalize = None
model_name = 'kanpert1'
force = False
model_exec = 10


model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100]
    #'optimizer':[optim.LBFGS]
}

model = KAN

experiment_params = {
    "model_pertub": KAN,
    "lag_size": None,
    "learning_rate_init" : 1,
    "qtd_perturbations": 1,
    'bagging_pct': None,
    'horizon': 1

}

grid_search_exp.grid_seach_multiple_bases(
     perturbative_neural_forecast.Perturbative, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 3919
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedrecife.txt
# windspeednatal.txt
# windspeedfortaleza.txt
# recifeaccday.txt
# samurec.txt
# Seed set to 3919
# Seed set to 6791
# Seed set to 6791
# Seed set to 3955
# Seed set to 3955
# Seed set to 4767
# Seed set to 4767
# Seed set to 9626
# Seed set to 9626
# Seed set to 9401
# Seed set to 9401
# Seed set to 932
# Seed set to 932
# Seed set to 9073
# Seed set to 9073
# Seed set to 5869
# Seed set to 5869
# Seed set to 4230
# Seed set to 4230
# Seed set to 4020
# Seed set to 4020
# Seed set to 757
# Seed set to 757
# Seed set to 3247
# Seed set to 3247
# Seed set to 1625
# Seed set to 1625
# Seed set to 8629
# Seed set to 8629
# Seed set to 7677
# Seed set to 7677
# Seed set to 5105
# Seed set to 5105
# Seed set to 2621
# Seed set to 2621
# Seed set to 3347
# Seed set to 3347
# Seed set to 24
# Seed set to 24
# Seed set to 2043
# Seed set to 2043
# ...

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import RMSE
import torch.optim as optim

from model import perturbative_neural_forecast, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

experiment_id = 'resudualens'
normalize = None
model_name = 'kanpert2'
force = False
model_exec = 10


model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100]
    #'optimizer':[optim.LBFGS]
}

model = KAN

experiment_params = {
    "model_pertub": KAN,
    "lag_size": None,
    "learning_rate_init" : 1,
    "qtd_perturbations": 2,
    'bagging_pct': None,
    'horizon': 1

}

grid_search_exp.grid_seach_multiple_bases(
     perturbative_neural_forecast.Perturbative, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 1804
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedrecife.txt
# Seed set to 1804
# Seed set to 1804
# Seed set to 1169
# Seed set to 1169
# Seed set to 1169
# Seed set to 4825
# Seed set to 4825
# Seed set to 4825
# Seed set to 9213
# Seed set to 9213
# Seed set to 9213
# Seed set to 9627
# Seed set to 9627
# Seed set to 9627
# Seed set to 2261
# Seed set to 2261
# Seed set to 2261
# Seed set to 8744
# Seed set to 8744
# Seed set to 8744
# Seed set to 4446
# Seed set to 4446
# Seed set to 4446
# Seed set to 639
# Seed set to 639
# Seed set to 639
# Seed set to 6819
# Seed set to 6819
# Seed set to 6819
# Seed set to 6828
# Seed set to 6828
# Seed set to 6828
# Seed set to 7687
# Seed set to 7687
# Seed set to 7687
# Seed set to 6883
# Seed set to 6883
# Seed set to 6883
# Seed set to 5211
# Seed set to 5211
# Seed set to 5211
# Seed set to 7963
# Seed set to 7963
# Seed set to 7963
# Seed set to 8180
# ...

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import RMSE
import torch.optim as optim

from model import perturbative_neural_forecast, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

experiment_id = 'resudualens'
normalize = None
model_name = 'kanpert3'
force = False
model_exec = 10


model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100]
    #'optimizer':[optim.LBFGS]
}

model = KAN

experiment_params = {
    "model_pertub": KAN,
    "lag_size": None,
    "learning_rate_init" : 1,
    "qtd_perturbations": 3,
    'bagging_pct': None,
    'horizon': 1

}

grid_search_exp.grid_seach_multiple_bases(
     perturbative_neural_forecast.Perturbative, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 7588
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedrecife.txt
# Seed set to 7588
# Seed set to 7588
# Seed set to 7588
# Seed set to 347
# Seed set to 347
# Seed set to 347
# Seed set to 347
# Seed set to 5919
# Seed set to 5919
# Seed set to 5919
# Seed set to 5919
# Seed set to 8934
# Seed set to 8934
# Seed set to 8934
# Seed set to 8934
# Seed set to 6950
# Seed set to 6950
# Seed set to 6950
# Seed set to 6950
# Seed set to 9976
# Seed set to 9976
# Seed set to 9976
# Seed set to 9976
# Seed set to 4622
# Seed set to 4622
# Seed set to 4622
# Seed set to 4622
# Seed set to 78
# Seed set to 78
# Seed set to 78
# Seed set to 78
# Seed set to 6429
# Seed set to 6429
# Seed set to 6429
# Seed set to 6429
# Seed set to 9278
# Seed set to 9278
# Seed set to 9278
# Seed set to 9278
# Seed set to 6734
# Seed set to 6734
# Seed set to 6734
# Seed set to 6734
# Seed set to 4438
# Seed set to 4438
# Seed set to 4438
# ...

# %%
from posmodel import linear_comb
from sklearn import model_comb

#model_comb = model_comb.TweedieRegressor()
#linear_comb.exec_linear_comb(experiment_id, model_name, model_comb, 'tw')
# Out:
# /home/domingossj/experiments/data/result/pertexps/coloradoRiver_kanpert.pkl
