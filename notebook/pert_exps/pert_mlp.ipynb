# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from sklearn.neural_network import MLPRegressor

from model import perturbative, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name = '1mlp'
model_name_list = [
    f'{base_name}p1', 
    f'{base_name}p2', 
    f'{base_name}p3', 

]
model_before_list = [
    [
        base_name, 
    ],
    [
        base_name, 
        f'1{base_name}p1', 
    ],
    [
        base_name, 
        f'1{base_name}p1', 
        f'1{base_name}p2'
    ]
]

# %%
experiment_id = 'consumoenergia'
normalize = None

force = True
model_exec = 10

model_parameters = {
    'hidden_layer_sizes': [10, 20, 50], 
    'max_iter': [1000],
}

# %%
for model_name, models_before in zip(
    model_name_list, 
    model_before_list
):
    model = MLPRegressor(activation='logistic', solver='lbfgs') 

    experiment_params = {
        'models_before': models_before,
        "model_pertub": MLPRegressor(activation='logistic', solver='lbfgs'),
        "lag_size": None,
        "learning_rate_init" :1 ,
        "qtd_perturbations": None,
        'bagging_pct': None,
        'horizon': 1
    }

    grid_search_exp.grid_seach_multiple_bases(
         perturbative.Perturbative, model, normalize, model_parameters,experiment_params,
         model_exec, model_name, experiment_id, force = force
    )
# Out:
# consumocoformated.txt
# consumoneformated.txt
# consumonoformated.txt
# consumosdformated.txt
# consumosulformated.txt
# consumocoformated.txt
# consumoneformated.txt
# consumonoformated.txt
# consumosdformated.txt
# consumosulformated.txt
# consumocoformated.txt
# consumoneformated.txt
# consumonoformated.txt
# consumosdformated.txt
# consumosulformated.txt
# ---------------------------------------------------------------------------
# LossySetitemError                         Traceback (most recent call last)
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1855, in Block.shift(self, periods, fill_value)
#    1852 try:
#    1853     # error: Argument 1 to "np_can_hold_element" has incompatible type
#    1854     # "Union[dtype[Any], ExtensionDtype]"; expected "dtype[Any]"
# -> 1855     casted = np_can_hold_element(
#    1856         self.dtype, fill_value  # type: ignore[arg-type]
#    1857     )
#    1858 except LossySetitemError:
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1856, in np_can_hold_element(dtype, element)
#    1854         return element
# -> 1856     raise LossySetitemError
#    1858 if dtype.kind == "f":
#
# LossySetitemError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#       5 model = MLPRegressor(activation='logistic', solver='lbfgs')
#       7 experiment_params = {
#       8     'models_before': models_before,
#       9     "model_pertub": MLPRegressor(activation='logistic', solver='lbfgs'),
#    (...)
#      15
#      16 }
# ---> 18 grid_search_exp.grid_seach_multiple_bases(
#      19      perturbative.Perturbative, model, normalize, model_parameters,experiment_params,
#      20      model_exec, model_name, experiment_id, force = force
#      21 )
#
# File ~/experiments/src/model/grid_search_exp.py:152, in grid_seach_multiple_bases(fit_predict_class, model, normalize, model_parameters, experiment_params, model_exec, model_name, experiment_id, force)
#     137     continue
#     139 exec_gs = GridSearch(
#     140     fit_predict_class,
#     141     model,
#    (...)
#     149     model_exec = model_exec
#     150 )
# --> 152 exec_gs.execution()
#
# File ~/experiments/src/model/grid_search_exp.py:93, in GridSearch.execution(self)
#      91 def execution(self):
# ---> 93     best_exec_val, best_params = self._search_params()
#      95     experiment_params = self.experiment_params.copy()
#      96     experiment_params['test_size'] = config.TEST_SIZE
#
# File ~/experiments/src/model/grid_search_exp.py:79, in GridSearch._search_params(self)
#      67     model_actual = clone(self.model).set_params(** params)
#      69 model_exp = self.model_class_exp(
#      70     model_actual,
#      71     self.experiment_id,
#    (...)
#      76     experiment_params
#      77 )
# ---> 79 model_exp.fit_predict()
#      80 metrics_results = model_exp.metrics_results
#      81 exec_list_metrics.append(
#      82     metrics_results.get(self.group_metrics_name, {self.metric: np.inf})[self.metric]
#      83 )
#
# File ~/experiments/src/model/perturbative.py:222, in Perturbative.fit_predict(self)
#     214 diff_kpss = self.experiment_params.get('diff_kpss', False)
#     216 exec_config = {
#     217     "test_size": self.experiment_params['test_size'],
#     218     "val_size": self.experiment_params['val_size'],
#     219     'horizon': self.experiment_params['horizon']
#     220 }
# --> 222 base_info = input.open_format_train_val_test(
#     223     self.base_name,
#     224     False,
#     225     lag_size_base,
#     226     exec_config,
#     227     diff_kpss
#     228 )
#     229 test_size = base_info.test_size
#     230 val_size = base_info.val_size
#
# File ~/experiments/src/input/input.py:108, in open_format_train_val_test(base_name, normalize, lag_size, exec_config, diff_kpss)
#     105     lag_actual = get_max_lag_to_consider(ts_univariate, test_size)
#     106     #print(f"PACF LAG SELECT {lag_actual}")
# --> 108 df_windowed = create_windowing(ts_normalized, lag_actual+(horizon-1))
#     109 horizon_cols = [f'actual_{i}' for i in range(1,horizon)] + ['actual']
#     110 lags_cols = [f'lag_{i}' for i in reversed(range(1,lag_actual+1))]
#
# File ~/experiments/src/input/input.py:40, in create_windowing(df, lag_size)
#      38 final_df = None
#      39 for i in range(0, (lag_size + 1)):
# ---> 40     serie = df.shift(i)
#      41     if (i == 0):
#      42         serie.columns = ['actual']
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/frame.py:5952, in DataFrame.shift(self, periods, freq, axis, fill_value, suffix)
#    5949     else:
#    5950         return self.T.shift(periods=periods, fill_value=fill_value).T
# -> 5952 return super().shift(
#    5953     periods=periods, freq=freq, axis=axis, fill_value=fill_value
#    5954 )
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/generic.py:11225, in NDFrame.shift(self, periods, freq, axis, fill_value, suffix)
#   11223     axis = self._get_axis_number(axis)
#   11224     assert axis == 0  # axis == 1 cases handled in DataFrame.shift
# > 11225     new_data = self._mgr.shift(periods=periods, fill_value=fill_value)
#   11226     return self._constructor_from_mgr(
#   11227         new_data, axes=new_data.axes
#   11228     ).__finalize__(self, method="shift")
#   11230 return self._shift_with_freq(periods, axis, freq)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/internals/base.py:312, in DataManager.shift(self, periods, fill_value)
#     309 if fill_value is lib.no_default:
#     310     fill_value = None
# --> 312 return self.apply_with_block("shift", periods=periods, fill_value=fill_value)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1859, in Block.shift(self, periods, fill_value)
#    1855     casted = np_can_hold_element(
#    1856         self.dtype, fill_value  # type: ignore[arg-type]
#    1857     )
#    1858 except LossySetitemError:
# -> 1859     nb = self.coerce_to_target_dtype(fill_value)
#    1860     return nb.shift(periods, fill_value=fill_value)
#    1862 else:
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:531, in Block.coerce_to_target_dtype(self, other, warn_on_upcast)
#     525 if self.values.dtype == new_dtype:
#     526     raise AssertionError(
#     527         f"Did not expect new dtype {new_dtype} to equal self.dtype "
#     528         f"{self.values.dtype}. Please report a bug at "
#     529         "https://github.com/pandas-dev/pandas/issues."
#     530     )
# --> 531 return self.astype(new_dtype, copy=False)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:760, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     756     values = values[0, :]  # type: ignore[call-overload]
#     758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
# --> 760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#     763 if (using_cow or not copy) and astype_is_view(values.dtype, new_values.dtype):
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2662, in maybe_coerce_values(values)
#    2659 # Caller is responsible for ensuring NumpyExtensionArray is already extracted.
#    2661 if isinstance(values, np.ndarray):
# -> 2662     values = ensure_wrapped_if_datetimelike(values)
#    2664     if issubclass(values.dtype.type, str):
#    2665         values = np.array(values, dtype=object)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pandas/core/construction.py:481, in ensure_wrapped_if_datetimelike(arr)
#     476         return obj.to_numpy()  # type: ignore[attr-defined]
#     478     return obj
# --> 481 def ensure_wrapped_if_datetimelike(arr):
#     482     """
#     483     Wrap datetime64 and timedelta64 ndarrays in DatetimeArray/TimedeltaArray.
#     484     """
#     485     if isinstance(arr, np.ndarray):
#
# KeyboardInterrupt:
