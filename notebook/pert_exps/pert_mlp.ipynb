# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from sklearn.neural_network import MLPRegressor

from model import perturbative, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_name = 'mlpkpssfalse'
model_name_list = [
    #f'{base_name}p1inv', 
    f'{base_name}p2fl', 
    f'{base_name}p3fl', 
    f'{base_name}p4fl', 
    f'{base_name}p5fl', 
]
model_before_list = [
    #[
    #    base_name, 
    #],
    [
        base_name, 
        f'{base_name}p1', 
    ],
    [
        base_name, 
        f'{base_name}p1', 
        f'{base_name}p2fl'
    ],
    [
        base_name, 
        f'{base_name}p1', 
        f'{base_name}p2fl', 
        f'{base_name}p3fl'
    ],
    [
        base_name, 
        f'{base_name}p1', 
        f'{base_name}p2fl', 
        f'{base_name}p3fl', 
        f'{base_name}p4fl'
    ]
]

# %%
experiment_id = 'pertexps'
normalize = None

force = True
model_exec = 10

model_parameters = {
    'hidden_layer_sizes': [2, 5, 10, 15, 20, 50], 
    'max_iter': [1000],
}

# %%
for model_name, models_before in zip(
    model_name_list, 
    model_before_list
):
    model = MLPRegressor(activation='logistic', solver='lbfgs') 

    experiment_params = {
        'models_before': models_before,
        "model_pertub": MLPRegressor(activation='logistic', solver='lbfgs'),
        "lag_size": None,
        "learning_rate_init" :1 ,
        "qtd_perturbations": None
        
    }

    grid_search_exp.grid_seach_multiple_bases(
         perturbative.Perturbative, model, normalize, model_parameters,experiment_params,
         model_exec, model_name, experiment_id, force = force
    )
# Out:
# coloradoRiver.txt
# > <string>(29)fit_predict()
# ipdb>  self.perturb_models[0].coefs_
# [array([[ 0.02090019, -0.11951513],
#        [-0.09161506,  0.0199845 ],
#        [ 0.4066682 ,  0.23265469],
#        [ 0.28645923,  0.06019641],
#        [-0.4323436 ,  0.71070609],
#        [ 0.07287069,  0.55811351],
#        [ 0.16460778,  0.16545552],
#        [-0.00291586, -0.19253669],
#        [-0.10751987, -0.15375669],
#        [-0.16964167, -0.47794056],
#        [ 0.13936793,  0.18569226],
#        [-0.02847802, -0.03626532],
#        [ 0.11963715,  0.08634523],
#        [-0.0943044 , -0.12532592],
#        [ 0.01955557, -0.15757846],
#        [-0.44816438,  0.75241566]]), array([[-2.60425915],
#        [ 1.41481479]])]
# ipdb>  sum(self.perturb_models[0].coefs_)
# *** ValueError: operands could not be broadcast together with shapes (16,2) (2,1)
# ipdb>  np.sum(self.perturb_models[0].coefs_)
# ...
