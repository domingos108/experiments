# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from sklearn.neural_network import MLPRegressor

from model import perturbative, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

# %%
experiment_id = 'pertexps'
normalize = None

force = True
model_exec = 10

model_parameters = {
    'hidden_layer_sizes': [2, 5, 10, 15, 20, 50], 
    'max_iter': [1000],
}

# %%
for bag_size in [0.5, 0.7, 1]:
    for qtd_pert in [10, 30, 60, 90]:
        model_name = f'mlpwk{bag_size}{qtd_pert}5'
        model = MLPRegressor(activation='logistic', solver='lbfgs') 
        
        experiment_params = {
            'models_before': None,
            "model_pertub": MLPRegressor(activation='logistic', solver='lbfgs'),
            "lag_size": None,
            "learning_rate_init" :1 ,
            "qtd_perturbations": qtd_pert,
            'earlystop': None,
            'bagging_pct': bag_size
            
        }
        grid_search_exp.grid_seach_multiple_bases(
             perturbative.Perturbative, model, normalize, model_parameters,experiment_params,
             model_exec, model_name, experiment_id, force = force
        )
# Out:
# coloradoRiver.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# sunspot.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# milk.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# Unemployment.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# ausbee.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# austres.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# heartrate.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# ozon.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# pollution.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# redwine.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# gasoline.txt
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# qt_models_seletected 10
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:602: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# qt_models_seletected 10
