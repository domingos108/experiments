# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.filterwarnings("ignore", category=UserWarning)
warnings.simplefilter('ignore', InterpolationWarning)

from model.elm import Model as ELM
from sklearn.neural_network import MLPRegressor

from model import generics, perturbative
from sklearn.model_selection import ParameterGrid

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name = 'elm'
model_name_list = [f'{base_name}mlpp1', 
                   f'{base_name}mlpp2', 
                   f'{base_name}mlpp3', 
                  ]
model_before_list = [base_name, 
                     f'{base_name}mlpp1', 
                   f'{base_name}mlpp2', 
                ]
model_base = ELM() 
model_pert = MLPRegressor(activation='logistic', solver='lbfgs')

params_modelo_base = list(
    ParameterGrid( 
        {'hidden_layer_sizes': [2, 5, 10, 15, 20, 50], 
         'max_iter': [1000],
         'time_window': [2, 6, 8, 12]
        }
))

# %%
base_name_list = config.BASE_NAME_LIST
normalize=False
force = False
model_exec = 10
experiment_id = 'test'

for model_name, models_before in zip(
    model_name_list, 
        model_before_list
):
    
    perturbative.exec_model(
        base_name_list, 
        experiment_id, 
        models_before,
        model_base, 
        params_modelo_base,
        normalize,
        model_exec,
        model_name,
        force,
        qtd_perturbative = None,
        learning_rate_init = 1,
        fixed_error_lags = False,
        learning_rate = 'constant',
        model_pert = model_pert
    )
# Out:
# sunspot.txt
#   0%|          | 0/24 [00:00<?, ?it/s]
# > /home/domingossj/experiments/src/model/perturbative.py(110)fit()
#     109             import ipdb;ipdb.set_trace()
# --> 110             model = model.fit(X, y)
#     111
# ipdb>  model
# Model(hidden_dim=20)
# ipdb>  c
# > /home/domingossj/experiments/src/model/perturbative.py(110)fit()
#     109             import ipdb;ipdb.set_trace()
# --> 110             model = model.fit(X, y)
#     111
# ipdb>  model
# MLPRegressor(activation='logistic', hidden_layer_sizes=10, max_iter=1000,
#              solver='lbfgs')
# ipdb>  c
# > /home/domingossj/experiments/src/model/perturbative.py(110)fit()
#     109             import ipdb;ipdb.set_trace()
# --> 110             model = model.fit(X, y)
#     111
# ipdb>  model
# MLPRegressor(activation='logistic', hidden_layer_sizes=20, max_iter=1000,
#              solver='lbfgs')
# ipdb>  count
# 2
# ipdb>  model
# MLPRegressor(activation='logistic', hidden_layer_sizes=20, max_iter=1000,
#              solver='lbfgs')
# ipdb>  count
# 2
# ipdb>  model
# MLPRegressor(activation='logistic', hidden_layer_sizes=20, max_iter=1000,
#              solver='lbfgs')
# ipdb>  count
# 2
# ipdb>  c
# > /home/domingossj/experiments/src/model/perturbative.py(110)fit()
#     109             import ipdb;ipdb.set_trace()
# --> 110             model = model.fit(X, y)
#     111
# ipdb>  model
# MLPRegressor(activation='logistic', hidden_layer_sizes=2, max_iter=1000,
#              solver='lbfgs')
# ipdb>  count
# 3
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# > /home/domingossj/experiments/src/model/perturbative.py(110)fit()
#     109                 model = clone(self.model_base).set_params(**params_actual)
# --> 110
#     111             model = model.fit(X, y)
