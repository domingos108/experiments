# %%
from sklearn.ensemble import RandomForestRegressor

from model import generics, perturbative
from sklearn.model_selection import ParameterGrid

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name = 'rf'
model_name_list = [f'{base_name}p1', 
                   f'{base_name}p2', 
                   f'{base_name}p3', 
                   f'{base_name}p4'
                  ]
model_before_list = [base_name, 
                     f'{base_name}p1', 
                     f'{base_name}p2',
                     f'{base_name}p3'
                ]
model_base = RandomForestRegressor()
params_modelo_base = list(
    ParameterGrid({'n_estimators': [50, 100, 200], 
                  'max_depth': [5, 10, 15],
                  'max_features': [0.6, 0.8, 1],
                  #'max_samples' : [0.6, 0.8, 1],
                  
                 }
))

# %%
base_name_list = config.BASE_NAME_LIST
lag_size_list = config.LAG_SIZE_LIST
normalize=False

model_exec = 10
experiment_id = 'test'

for model_name, models_before in zip(
    model_name_list, 
    model_before_list
):
    
    perturbative.exec_model(
        base_name_list, 
        lag_size_list, 
        experiment_id, 
        models_before,
        model_base, 
        params_modelo_base,
        normalize,
        model_exec,
        model_name 
    )
# Out:
# airlines.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# sunspot.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# coloradoRiver.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# lakeerie.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# milk
#   0%|          | 0/27 [00:00<?, ?it/s]
# ozon.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# pollution.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# temperature.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# airlines.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# sunspot.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# coloradoRiver.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# lakeerie.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# milk
#   0%|          | 0/27 [00:00<?, ?it/s]
# ozon.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# pollution.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# temperature.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# airlines.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# sunspot.txt
#   0%|          | 0/27 [00:00<?, ?it/s]
# ...
