# %%
from sklearn.ensemble import RandomForestRegressor

from model import generics, perturbative
from sklearn.model_selection import ParameterGrid

import config
# %load_ext autoreload
# %autoreload 2

# %%
grid_params = list(ParameterGrid( 
       {'n_estimators': [50, 100, 200], 
                  'max_depth': [5, 10, 15],
                  'max_features': [0.6, 0.8, 1],
                  #'max_samples' : [0.6, 0.8, 1],
      }
    ))

# %%
base_name_list = config.BASE_NAME_LIST
lag_size_list = config.LAG_SIZE_LIST
normalize=False
force = False

model_exec = 10

parameters = {
    'model_params': [[c]for c in grid_params],
    'qtd_pertubacao': [2, 3, 4, 5],
    'model_base': [RandomForestRegressor(n_jobs=-1)],
    'learning_rate': ['constant'],
    'learning_rate_init': [0.75, 0.85, 0.95],
    'fixed_error_lags':[False]
}

model = perturbative.Perturbative(model_base = RandomForestRegressor(n_jobs=-1)) 
model_name = 'rfweeklr'
experiment_id = 'test'

generics.grid_seach_multiple_bases(model,  base_name_list, normalize, lag_size_list,
                                   parameters, model_exec, model_name, experiment_id, force)
# Out:
# airlines.txt
# Modelo já executado
# sunspot.txt
# Modelo já executado
# coloradoRiver.txt
#   0%|          | 0/324 [00:00<?, ?it/s]
# lakeerie.txt
#   0%|          | 0/324 [00:00<?, ?it/s]
# milk
#   0%|          | 0/324 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 21
#      18 model_name = 'rfweeklr'
#      19 experiment_id = 'test'
# ---> 21 generics.grid_seach_multiple_bases(model,  base_name_list, normalize, lag_size_list,
#      22                                    parameters, model_exec, model_name, experiment_id, force)
#
# File ~/experiments/src/model/generics.py:205, in grid_seach_multiple_bases(model, base_name_list, normalize, lag_size_list, parameters, model_exec, model_name, experiment_id, force)
#     203 for base_name,lag_size in zip(base_name_list, lag_size_list):
#     204     print(base_name)
# ...
