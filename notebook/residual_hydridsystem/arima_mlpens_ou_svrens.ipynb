# %%
import warnings

# Filter out this specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn')

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp, custom_bagging
from metrics import metrics
import numpy as np

from sklearn.neural_network import MLPRegressor
import pandas as pd


# %load_ext autoreload
# %autoreload 2

# %%
for n_estimators in [20, 40, 80]:
    for max_samples in [""]:
        for max_features in [""]:
            model = custom_bagging.CustomBaggingRegressor(n_jobs=-1, agg_type='mean')
            max_samples: []
            experiment_id = 'windspeed'
            model_name = f'ammean{n_estimators}{max_samples}{max_features}'
            normalize = True
            force = False
            model_exec = 10
            
            experiment_params = {
                'linear_model_name': '1arima',
                "lag_size": None,
                'diff_kpss': False,
                'horizon': 1
                
            }
            
            model_parameters = {
                'estimator': [
                    MLPRegressor(activation='logistic', solver='lbfgs', max_iter= 1000, hidden_layer_sizes=10),
                    MLPRegressor(activation='logistic', solver='lbfgs', max_iter= 1000, hidden_layer_sizes=20),
                    MLPRegressor(activation='logistic', solver='lbfgs', max_iter= 1000, hidden_layer_sizes=50)
                ], 
                'n_estimators': [n_estimators],
                'max_features': [0.4, 0.6, 0.8],
                'max_samples': [0.4, 0.6, 0.8]
                
            }
    
            grid_search_exp.grid_seach_multiple_bases(
                 hybrid_system_exp.Additive, model, normalize, model_parameters,experiment_params,
                 model_exec, model_name, experiment_id, force = force
            )
# Out:
# windspeedrecife.txt
#   0%|                                                    | 0/27 [00:00<?, ?it/s]/home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np

from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor
import pandas as pd

# %load_ext autoreload
# %autoreload 2
    
for n_estimators in [20, 40, 80]:
    for max_samples in [ ""]:
        for max_features in [""]:
                model = BaggingRegressor(n_jobs=-1)
                max_samples: []
                experiment_id = 'windspeed'
                model_name = f'asens{n_estimators}'
                normalize = True
                force = False
                model_exec = 10
                
                experiment_params = {
                    'linear_model_name': '1arima',
                    "lag_size": None,
                    'diff_kpss': False,
                    'horizon': 1
                    
                }
                
                model_parameters = {
                    'estimator': [
                            SVR(max_iter=100000, C=10, epsilon = 0.1, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=100, epsilon = 0.1, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=1000, epsilon = 0.1, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=10, epsilon = 0.01, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=100, epsilon = 0.01, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=1000, epsilon = 0.01, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=10, epsilon = 0.001, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=100, epsilon = 0.001, gamma='auto', kernel='rbf', tol=0.001),
                            SVR(max_iter=100000, C=1000, epsilon = 0.001, gamma='auto', kernel='rbf', tol=0.001),
                    ], 
                    'n_estimators': [n_estimators],
                    'max_features': [0.4, 0.6, 0.8],
                    'max_samples': [0.4, 0.6, 0.8]
                    
                }
        
                grid_search_exp.grid_seach_multiple_bases(
                     hybrid_system_exp.Additive, model, normalize, model_parameters,experiment_params,
                     model_exec, model_name, experiment_id, force = force
                )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedrecife.txt
# 100%|███████████████████████████████████████████| 81/81 [00:48<00:00,  1.67it/s]
# {'estimator': SVR(C=10, epsilon=0.001, gamma='auto', max_iter=100000), 'max_features': 0.4, 'max_samples': 0.8, 'n_estimators': 20}
# windspeednatal.txt
# 100%|███████████████████████████████████████████| 81/81 [00:47<00:00,  1.72it/s]
# {'estimator': SVR(C=10, epsilon=0.001, gamma='auto', max_iter=100000), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 20}
# windspeedfortaleza.txt
# 100%|███████████████████████████████████████████| 81/81 [00:48<00:00,  1.66it/s]
# {'estimator': SVR(C=100, epsilon=0.001, gamma='auto', max_iter=100000), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 20}
# windspeedrecife.txt
# 100%|███████████████████████████████████████████| 81/81 [01:07<00:00,  1.20it/s]
# ...

# %%
import warnings

# Filter out this specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn')

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp, custom_bagging
from metrics import metrics
import numpy as np

from model.elm import Model as ELM

import pandas as pd


# %load_ext autoreload
# %autoreload 2
    
for n_estimators in [20, 40, 80]:
    for max_samples in [0.4, 0.6, 0.8]:
        for max_features in [0.4, 0.6, 0.8]:
            model = custom_bagging.CustomBaggingRegressor(n_jobs=-1, agg_type='mean')
            max_samples: []
            experiment_id = 'windspeed'
            model_name = f'aelmmean{n_estimators}{max_samples}{max_features}'
            normalize = True
            force = False
            model_exec = 10
            
            experiment_params = {
                'linear_model_name': '1arima',
                "lag_size": None,
                'diff_kpss': False,
                'horizon': 1
                
            }
            
            model_parameters = {
                'estimator': [
                    ELM(hidden_dim=10) ,
                    ELM(hidden_dim=20),
                    ELM(hidden_dim=50),
                    ELM(hidden_dim=100)
                ], 
                'n_estimators': [n_estimators],
                'max_features': [max_samples],
                'max_samples': [max_features]
                
            }
    
            grid_search_exp.grid_seach_multiple_bases(
                 hybrid_system_exp.Additive, model, normalize, model_parameters,experiment_params,
                 model_exec, model_name, experiment_id, force = force
            )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedrecife.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:02<00:00,  1.79it/s]
# {'estimator': Model(), 'max_features': 0.4, 'max_samples': 0.4, 'n_estimators': 20}
# windspeednatal.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  3.82it/s]
# {'estimator': Model(), 'max_features': 0.4, 'max_samples': 0.4, 'n_estimators': 20}
# windspeedfortaleza.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  3.80it/s]
# {'estimator': Model(), 'max_features': 0.4, 'max_samples': 0.4, 'n_estimators': 20}
# windspeedrecife.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  3.86it/s]
# {'estimator': Model(), 'max_features': 0.4, 'max_samples': 0.6, 'n_estimators': 20}
# windspeednatal.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  3.79it/s]
# ...
