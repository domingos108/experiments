# %%
import warnings

# Filter out this specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn')

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp, custom_bagging
from metrics import metrics
import numpy as np

from sklearn.linear_model import QuantileRegressor
import pandas as pd


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for n_estimators in [100]:
    for max_samples in ['']:#[0.4, 0.6, 0.8]:
        for max_features in ['']:# [0.4, 0.6, 0.8]:
            model = custom_bagging.CustomBaggingRegressor(n_jobs=-1, agg_type='mean')
            max_samples: []
            experiment_id = 'residualens'
            model_name = f'aquantmean{n_estimators}{max_samples}{max_features}'
            normalize = True
            force = False
            model_exec = 10
            
            experiment_params = {
                'linear_model_name': '1arima',
                "lag_size": None,
                'diff_kpss': False,
                'horizon': 1
                
            }
            
            model_parameters = {
                'estimator': [
                    QuantileRegressor(quantile=0.3),
                    QuantileRegressor(quantile=0.5),
                    QuantileRegressor(quantile=0.7),
                ], 
                'n_estimators': [n_estimators],
                'max_features':[0.4, 0.6, 0.8],# [max_samples],#[0.4, 0.6, 0.8],
                'max_samples': [0.4, 0.6, 0.8],# [max_features]#[0.4, 0.6, 0.8]
                
            }
    
            grid_search_exp.grid_seach_multiple_bases(
                 hybrid_system_exp.Additive, model, normalize, model_parameters,experiment_params,
                 model_exec, model_name, experiment_id, force = force
            )
# Out:
# coloradoRiver.txt
# /home/domingosjr/experiments/src/metrics/metrics.py:44: RuntimeWarning: divide by zero encountered in scalar divide
#   return error_sup / error_inf
# /home/domingosjr/experiments/src/metrics/metrics.py:44: RuntimeWarning: divide by zero encountered in scalar divide
#   return error_sup / error_inf
# /home/domingosjr/experiments/src/metrics/metrics.py:44: RuntimeWarning: divide by zero encountered in scalar divide
#   return error_sup / error_inf
# /home/domingosjr/experiments/src/metrics/metrics.py:44: RuntimeWarning: divide by zero encountered in scalar divide
#   return error_sup / error_inf
# /home/domingosjr/experiments/src/metrics/metrics.py:44: RuntimeWarning: divide by zero encountered in scalar divide
#   return error_sup / error_inf
# /home/domingosjr/experiments/src/metrics/metrics.py:44: RuntimeWarning: divide by zero encountered in scalar divide
#   return error_sup / error_inf
# ...

# %%
import pandas as pd
from model import generics, hybrid_system_exp
from input import input
from metrics import metrics
from posmodel import residual_ens_agg
import config 

# %load_ext autoreload
# %autoreload 2

base_name_list = config.BASE_NAME_LIST
normalize = True
experiment_id = 'residualens'

"""resultados promissores:
ausbee,
gasoline,
heartrate,
ozon,
pollution,
sunspot,
temperature"""

for model_name in ['1aquantmean100']:
    for rc in [1]:#[0.1, 0.5, 0.8]:
        for k in [1, 5, 10, 20, 40, 80]:
            print(k)
            for base_name in base_name_list:
                lag_size = config.BASE_INFORMATION[base_name]['lag_size']
                experiment_params = {
                    'linear_model_name': '1arima',
                    "lag_size": lag_size,
                    'diff_kpss': False,
                    'horizon': 1,
                    'test_size': config.TEST_SIZE,
                    'val_size': config.VAL_SIZE,
                    'select_type': 'mostrecent',
                    'ds_args': {
                        'rc': rc,
                        'k': k,
                    }
                }
                #model_name = '1aelmmean100'
                
                residual_ens_agg.exec_ensemble(experiment_params, experiment_id, base_name, model_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 1
# 5
# 10
# 20
# 40
# 80

# %%
import pandas as pd
from model import generics, hybrid_system_exp
from input import input
from metrics import metrics
from posmodel import residual_ens_agg
import config 

# %load_ext autoreload
# %autoreload 2

base_name_list = config.BASE_NAME_LIST
normalize = True
experiment_id = 'residualens'

"""resultados promissores:
ausbee,
gasoline,
heartrate,
ozon,
pollution,
sunspot,
temperature"""

for model_name in ['1aquantmean100']:
    for rc in [0.1, 0.5, 0.8]:
        print(rc)
        for k in [1, 5, 10, 20, 40, 80]:
    
            for base_name in base_name_list:
                lag_size = config.BASE_INFORMATION[base_name]['lag_size']
                experiment_params = {
                    'linear_model_name': '1arima',
                    "lag_size": lag_size,
                    'diff_kpss': False,
                    'horizon': 1,
                    'test_size': config.TEST_SIZE,
                    'val_size': config.VAL_SIZE,
                    'select_type': 'ds',
                    'ds_args': {
                        'rc': rc,
                        'k': k,
                    }
                }
                
                #model_name = '1aelmmean100'
                residual_ens_agg.exec_ensemble(experiment_params, experiment_id, base_name, model_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0.1
# 0.5
# 0.8
