# %%
from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np

from model.scn import SCN_III, sigmoid, linear
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for lag_size in [2, 4, 6, 8, 10, 12]:
    model = SCN_III()
    
    experiment_id = 'consumoenergia'
    model_name = f'arimascnval{lag_size}'
    normalize = True
    force = False
    model_exec = 10
    
    experiment_params = {
        'linear_model_name': '1arimaval',
        "lag_size": lag_size,
        'diff_kpss': False,
        'horizon': 1
    }
    
    model_parameters = {
      'l_max': [5, 10, 20, 30],
        "t_max": [10],
        'hidden_act_fuction': [linear],#, relu, sigmoid, linear]
    }
    grid_search_exp.grid_seach_multiple_bases(
         hybrid_system_exp.Additive, model, normalize, model_parameters,experiment_params,
         model_exec, model_name, experiment_id, force = force
    )
# Out:
# consumocoformatedlog.txt
# consumoneformatedlog.txt
# consumonoformatedlog.txt
# consumosdformatedlog.txt
# consumosulformatedlog.txt
# consumocoformatedlog.txt
# consumoneformatedlog.txt
# consumonoformatedlog.txt
# consumosdformatedlog.txt
# consumosulformatedlog.txt
# consumocoformatedlog.txt
# consumoneformatedlog.txt
# consumonoformatedlog.txt
# consumosdformatedlog.txt
# consumosulformatedlog.txt
# consumocoformatedlog.txt
# consumoneformatedlog.txt
# consumonoformatedlog.txt
# consumosdformatedlog.txt
# consumosulformatedlog.txt
# consumocoformatedlog.txt
# consumoneformatedlog.txt
# consumonoformatedlog.txt
# consumosdformatedlog.txt
# consumosulformatedlog.txt
# consumocoformatedlog.txt
# consumoneformatedlog.txt
# consumonoformatedlog.txt
# consumosdformatedlog.txt
# consumosulformatedlog.txt
