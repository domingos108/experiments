# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

from input import input
import config
from model import generics, hybrid_system_exp, grid_search_exp
from metrics import metrics
import numpy as np

from sklearn.neural_network import MLPRegressor
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = MLPRegressor(activation='relu', solver='adam') 

experiment_id = 'validfits'
model_name = f'validam'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'linear_model_name': '1validfitsarima',
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'hidden_layer_sizes': [100, 200, 300], 
    'max_iter': [1000],
}

grid_search_exp.grid_seach_multiple_bases(
 hybrid_system_exp.AdditiveValidFits, model, normalize, model_parameters,experiment_params,
 model_exec, model_name, experiment_id, force = force
)
# Out:
# sunspot.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]/home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1771: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/domingosjr/experiments/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1771: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
