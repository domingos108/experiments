# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model.scn import SCN_III

from model import generics

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = config.BASE_NAME_LIST
normalize=True
force = False
model_exec = 10

parameters = {
    'l_max': [5, 10, 20, 30],
    "t_max": [10],
    'time_window': [None]#[7, 14, 21],#[12, 24, 72, 168]
}

# %%
model = SCN_III()
model_name = f'scn'
experiment_id = 'scnexps'

generics.grid_seach_multiple_bases(model,  base_name_list, normalize,
                                   parameters, model_exec, model_name, 
                                   experiment_id, force = force)
# Out:
# sunspot.txt
# Modelo já executado
# coloradoRiver.txt
# Modelo já executado
# milk.txt
# Modelo já executado
# Unemployment.txt
# Modelo já executado
# ausbee.txt
# Modelo já executado
# austres.txt
# Modelo já executado
# heartrate.txt
# Modelo já executado
# ozon.txt
# Modelo já executado
# pollution.txt
# Modelo já executado
# redwine.txt
# Modelo já executado
# taylor.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# MAX ITERATONS REACHED, ERROR 0.001001718740463517, ITERATORS 6
# MAX ITERATONS REACHED, ERROR 0.002276097581089442, ITERATORS 6
# MAX ITERATONS REACHED, ERROR 0.0015781871569825181, ITERATORS 6
# MAX ITERATONS REACHED, ERROR 0.0017016491043991223, ITERATORS 6
# MAX ITERATONS REACHED, ERROR 0.0012112965797940003, ITERATORS 6
# MAX ITERATONS REACHED, ERROR 0.0012769221675174769, ITERATORS 6
# MAX ITERATONS REACHED, ERROR 0.0015890939254201446, ITERATORS 6
