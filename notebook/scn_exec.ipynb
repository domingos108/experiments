# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model.scn import SCN_III, sigmoid, linear

from model import generics

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = config.BASE_NAME_LIST
normalize=True
force = True
model_exec = 10

parameters = {
    'l_max': [5, 10, 20, 30],
    "t_max": [10],
    'time_window': [None],#[7, 14, 21],#[12, 24, 72, 168]
    'hidden_act_fuction': [linear],#, relu, sigmoid]
}

# %%
model = SCN_III()
model_name = f'scnlinear'
experiment_id = 'scnexps'

generics.grid_seach_multiple_bases(model,  base_name_list, normalize,
                                   parameters, model_exec, model_name, 
                                   experiment_id, force = force)
# Out:
# sunspot.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# coloradoRiver.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# milk.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# Unemployment.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# ausbee.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# austres.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# heartrate.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# ozon.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# pollution.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# redwine.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# gasoline.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# temperature.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# woolyrnq.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
# taylor.txt
#   0%|          | 0/4 [00:00<?, ?it/s]
