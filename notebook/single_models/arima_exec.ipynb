# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'consumoenergia'
horizon = 3

# %%
for base_name in base_name_list:
    print(base_name)
    
    exec_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'], horizon)
# Out:
# consumocoformated.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=5938.735, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=5791.364, Time=0.31 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=5860.511, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=5941.563, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=5937.472, Time=0.02 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=5730.902, Time=0.91 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=5693.426, Time=1.53 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=5691.771, Time=0.56 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=5860.876, Time=0.40 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=5693.522, Time=1.41 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=5784.277, Time=0.71 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.32 sec
# ...
