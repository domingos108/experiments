# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2
# Out:
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\re\_casefix.py' for module 're._casefix': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 913: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\shlex.py' for module 'shlex': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1482: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\urllib\parse.py' for module 'urllib.parse': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 2030: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\pydoc_data\topics.py' for module 'pydoc_data.topics': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 4751: character maps to <undefined>
# Failed to read module file 'C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\functools.py' for module 'functools': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Projetos\mestrado_codigos\experiments\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 308: character maps to <undefined>

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'chamados'
horizon = 1
force= False

# %%
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'], horizon, force)
# Out:
# airlines.txt
# Modelo já executado
# austres.txt
# Modelo já executado
# coloradoRiver.txt
# Modelo já executado
# sunspot.txt
# Modelo já executado
# windspeedfortaleza.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=91.950, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=267.490, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=130.346, Time=0.19 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=148.787, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=589.231, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=74.727, Time=0.27 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=80.407, Time=0.10 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=72.873, Time=0.60 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=86.168, Time=0.57 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=105.717, Time=0.29 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=113.551, Time=0.32 sec
#  ARIMA(3,0,2)(0,0,2)[12] intercept   : AIC=110.646, Time=0.53 sec
#  ARIMA(2,0,3)(0,0,2)[12] intercept   : AIC=70.710, Time=0.60 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=67.089, Time=0.26 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=71.112, Time=0.14 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=82.579, Time=0.34 sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : AIC=166.558, Time=0.25 sec
#  ARIMA(2,0,3)(1,0,2)[12] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=100.150, Time=0.17 sec
#  ARIMA(3,0,3)(0,0,1)[12] intercept   : AIC=73.085, Time=0.27 sec
#  ARIMA(2,0,4)(0,0,1)[12] intercept   : AIC=67.141, Time=0.33 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=107.444, Time=0.12 sec
#  ARIMA(1,0,4)(0,0,1)[12] intercept   : AIC=106.647, Time=0.28 sec
#  ARIMA(3,0,2)(0,0,1)[12] intercept   : AIC=111.098, Time=0.28 sec
#  ARIMA(3,0,4)(0,0,1)[12] intercept   : AIC=71.107, Time=0.40 sec
#  ARIMA(2,0,3)(0,0,1)[12]             : AIC=126.013, Time=0.30 sec
#
# Best model:  ARIMA(2,0,3)(0,0,1)[12] intercept
# Total fit time: 7.726 seconds
# samurec.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=1.05 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=7152.882, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=6885.017, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=6510.167, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=7150.885, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=6511.996, Time=0.08 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(0,1,1)(0,0,2)[7] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,1,1)(1,0,0)[7] intercept   : AIC=6508.881, Time=0.21 sec
#  ARIMA(0,1,1)(2,0,0)[7] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(0,1,1)(2,0,1)[7] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(0,1,0)(1,0,0)[7] intercept   : AIC=7153.288, Time=0.06 sec
#  ARIMA(1,1,1)(1,0,0)[7] intercept   : AIC=6510.751, Time=0.43 sec
#  ARIMA(0,1,2)(1,0,0)[7] intercept   : AIC=6510.746, Time=0.30 sec
#  ARIMA(1,1,2)(1,0,0)[7] intercept   : AIC=6512.773, Time=0.44 sec
#  ARIMA(0,1,1)(1,0,0)[7]             : AIC=6508.023, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[7]             : AIC=6510.738, Time=0.03 sec
#  ARIMA(0,1,1)(2,0,0)[7]             : AIC=6487.794, Time=0.21 sec
#  ARIMA(0,1,1)(2,0,1)[7]             : AIC=inf, Time=0.67 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=inf, Time=0.37 sec
#  ARIMA(0,1,0)(2,0,0)[7]             : AIC=7135.258, Time=0.11 sec
#  ARIMA(1,1,1)(2,0,0)[7]             : AIC=6489.648, Time=0.29 sec
#  ARIMA(0,1,2)(2,0,0)[7]             : AIC=6489.645, Time=0.32 sec
#  ARIMA(1,1,0)(2,0,0)[7]             : AIC=6863.461, Time=0.12 sec
#  ARIMA(1,1,2)(2,0,0)[7]             : AIC=6489.607, Time=0.59 sec
#
# Best model:  ARIMA(0,1,1)(2,0,0)[7]
# Total fit time: 8.719 seconds
