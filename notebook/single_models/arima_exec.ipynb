# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing, exec_training_testing_valid_fits
from input import input
import config

# %load_ext autoreload
# %autoreload 2

base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'hourwindspeed'
horizon = 24
force= True
           
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name,
                          config.BASE_INFORMATION[base_name]['m'],
                          horizon, force)
    # exec_training_testing_valid_fits exec_training_testing
# Out:
# windspeedcampinagrandehour.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=16058.871, Time=2.89 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16423.062, Time=0.36 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16070.466, Time=0.47 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=16060.583, Time=0.84 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16421.062, Time=0.15 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=16060.931, Time=3.64 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=16058.046, Time=2.51 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=16060.624, Time=2.82 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=16058.112, Time=0.95 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=16059.229, Time=1.39 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=16057.285, Time=1.02 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=16059.153, Time=1.54 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=16061.227, Time=2.21 sec
# ...

# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing, exec_training_testing_valid_fits
from input import input
import config

# %load_ext autoreload
# %autoreload 2

base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'hourwindspeed'
horizon = 48
force= True
           
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name,
                          config.BASE_INFORMATION[base_name]['m'],
                          horizon, force)
    # exec_training_testing_valid_fits exec_training_testing
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcampinagrandehour.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=15997.149, Time=6.31 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16357.892, Time=0.73 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16008.223, Time=0.55 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=15998.699, Time=2.00 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16355.892, Time=0.16 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=15998.995, Time=5.71 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=15996.362, Time=2.64 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=15998.710, Time=1.61 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=15996.305, Time=0.76 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=15995.622, Time=0.96 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=15997.449, Time=1.88 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=15997.542, Time=1.18 sec
# ...

# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing, exec_training_testing_valid_fits
from input import input
import config

# %load_ext autoreload
# %autoreload 2

base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'hourwindspeed'
horizon = 72
force= True
           
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name,
                          config.BASE_INFORMATION[base_name]['m'],
                          horizon, force)
    # exec_training_testing_valid_fits exec_training_testing
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcampinagrandehour.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=15945.513, Time=5.54 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16306.775, Time=0.79 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=15956.186, Time=0.56 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=15946.964, Time=2.97 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16304.776, Time=0.15 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=15947.158, Time=3.71 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=15944.567, Time=2.88 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=15946.865, Time=1.53 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=15944.530, Time=0.73 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=15943.875, Time=0.80 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=15945.752, Time=1.33 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=15945.818, Time=1.10 sec
# ...
