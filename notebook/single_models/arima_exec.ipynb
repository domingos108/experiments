# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'resudualens'
horizon = 1
force= False

# %%
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'], horizon, force)
# Out:
# recifeaccday.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=1.64 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=10235.376, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=9859.344, Time=0.19 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=9518.906, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=10233.376, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=9638.012, Time=0.09 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=9190.367, Time=0.86 sec
#  ARIMA(0,1,1)(1,0,0)[7] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,1,1)(2,0,1)[7] intercept   : AIC=inf, Time=1.78 sec
#  ARIMA(0,1,1)(1,0,2)[7] intercept   : AIC=inf, Time=1.72 sec
#  ARIMA(0,1,1)(0,0,2)[7] intercept   : AIC=9451.844, Time=1.21 sec
#  ARIMA(0,1,1)(2,0,0)[7] intercept   : AIC=inf, Time=1.23 sec
#  ARIMA(0,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=2.24 sec
#  ARIMA(0,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=1.32 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=inf, Time=0.59 sec
#
# Best model:  ARIMA(0,1,1)(1,0,1)[7] intercept
# Total fit time: 16.555 seconds
# windspeedrecife.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=34.313, Time=1.81 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=134.269, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=50.463, Time=0.26 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=57.602, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=512.954, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=52.073, Time=0.34 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=91.099, Time=0.36 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=37.341, Time=0.87 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=37.606, Time=1.12 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=54.229, Time=0.12 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=28.751, Time=0.95 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=39.991, Time=0.74 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=41.217, Time=0.79 sec
#  ARIMA(3,0,2)(0,0,2)[12] intercept   : AIC=43.212, Time=1.00 sec
#  ARIMA(2,0,3)(0,0,2)[12] intercept   : AIC=11.523, Time=0.87 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=11.560, Time=0.41 sec
#  ARIMA(2,0,3)(1,0,2)[12] intercept   : AIC=34.489, Time=1.04 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=28.119, Time=0.52 sec
#  ARIMA(1,0,3)(0,0,2)[12] intercept   : AIC=37.861, Time=1.25 sec
#  ARIMA(3,0,3)(0,0,2)[12] intercept   : AIC=20.639, Time=1.34 sec
#  ARIMA(2,0,4)(0,0,2)[12] intercept   : AIC=15.011, Time=1.30 sec
#  ARIMA(1,0,4)(0,0,2)[12] intercept   : AIC=37.242, Time=1.10 sec
#  ARIMA(3,0,4)(0,0,2)[12] intercept   : AIC=9.022, Time=1.40 sec
#  ARIMA(3,0,4)(0,0,1)[12] intercept   : AIC=8.127, Time=0.48 sec
#  ARIMA(3,0,4)(0,0,0)[12] intercept   : AIC=4.872, Time=0.20 sec
#  ARIMA(3,0,4)(1,0,0)[12] intercept   : AIC=inf, Time=1.23 sec
#  ARIMA(3,0,4)(1,0,1)[12] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(2,0,4)(0,0,0)[12] intercept   : AIC=12.347, Time=0.18 sec
#  ARIMA(3,0,3)(0,0,0)[12] intercept   : AIC=34.734, Time=0.19 sec
#  ARIMA(4,0,4)(0,0,0)[12] intercept   : AIC=9.908, Time=0.20 sec
#  ARIMA(3,0,5)(0,0,0)[12] intercept   : AIC=6.624, Time=0.24 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=6.449, Time=0.16 sec
#  ARIMA(2,0,5)(0,0,0)[12] intercept   : AIC=14.308, Time=0.20 sec
#  ARIMA(4,0,3)(0,0,0)[12] intercept   : AIC=32.098, Time=0.19 sec
#  ARIMA(4,0,5)(0,0,0)[12] intercept   : AIC=4.163, Time=0.23 sec
#  ARIMA(4,0,5)(1,0,0)[12] intercept   : AIC=111.171, Time=0.59 sec
#  ARIMA(4,0,5)(0,0,1)[12] intercept   : AIC=6.356, Time=0.89 sec
#  ARIMA(4,0,5)(1,0,1)[12] intercept   : AIC=61.892, Time=0.81 sec
#  ARIMA(5,0,5)(0,0,0)[12] intercept   : AIC=6.414, Time=0.30 sec
#  ARIMA(5,0,4)(0,0,0)[12] intercept   : AIC=4.274, Time=0.21 sec
#  ARIMA(4,0,5)(0,0,0)[12]             : AIC=84.511, Time=0.22 sec
#
# Best model:  ARIMA(4,0,5)(0,0,0)[12] intercept
# Total fit time: 25.188 seconds
# windspeednatal.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.41 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=260.156, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=182.673, Time=0.92 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=194.899, Time=0.43 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=668.253, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=187.986, Time=0.03 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=175.491, Time=1.45 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=166.282, Time=0.60 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.83 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=170.543, Time=1.53 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=170.266, Time=0.82 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=166.993, Time=0.81 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=178.146, Time=0.75 sec
#  ARIMA(0,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(2,0,1)(2,0,1)[12] intercept   : AIC=169.581, Time=0.87 sec
#  ARIMA(1,0,0)(2,0,1)[12]             : AIC=inf, Time=0.68 sec
#
# Best model:  ARIMA(1,0,0)(2,0,1)[12] intercept
# Total fit time: 12.562 seconds
# windspeedfortaleza.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=91.947, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=267.490, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=130.399, Time=0.52 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=148.787, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=589.231, Time=0.00 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=74.727, Time=0.35 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=80.405, Time=0.15 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=72.873, Time=1.15 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=88.886, Time=1.15 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=105.717, Time=0.56 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=113.551, Time=0.55 sec
#  ARIMA(3,0,2)(0,0,2)[12] intercept   : AIC=110.646, Time=0.93 sec
#  ARIMA(2,0,3)(0,0,2)[12] intercept   : AIC=70.710, Time=0.92 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=67.089, Time=0.28 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=71.112, Time=0.14 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=77.477, Time=0.42 sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : AIC=166.560, Time=0.31 sec
#  ARIMA(2,0,3)(1,0,2)[12] intercept   : AIC=inf, Time=1.13 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=100.150, Time=0.19 sec
#  ARIMA(3,0,3)(0,0,1)[12] intercept   : AIC=73.085, Time=0.31 sec
#  ARIMA(2,0,4)(0,0,1)[12] intercept   : AIC=67.141, Time=0.41 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=107.444, Time=0.14 sec
#  ARIMA(1,0,4)(0,0,1)[12] intercept   : AIC=106.647, Time=0.35 sec
#  ARIMA(3,0,2)(0,0,1)[12] intercept   : AIC=111.098, Time=0.34 sec
#  ARIMA(3,0,4)(0,0,1)[12] intercept   : AIC=71.107, Time=0.45 sec
#  ARIMA(2,0,3)(0,0,1)[12]             : AIC=126.012, Time=0.29 sec
#
# Best model:  ARIMA(2,0,3)(0,0,1)[12] intercept
# Total fit time: 11.652 seconds
# irradiancesalvador.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=3.96 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=59662.363, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=58616.804, Time=1.44 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=58854.442, Time=1.46 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=59660.363, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=59087.482, Time=0.11 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=58339.267, Time=4.39 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=58299.704, Time=5.50 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=58338.248, Time=1.67 sec
#  ARIMA(1,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=8.07 sec
#  ARIMA(1,1,0)(1,0,2)[7] intercept   : AIC=58276.045, Time=6.16 sec
#  ARIMA(1,1,0)(0,0,2)[7] intercept   : AIC=58656.880, Time=3.37 sec
#  ARIMA(1,1,0)(0,0,1)[7] intercept   : AIC=58826.340, Time=1.09 sec
#  ARIMA(0,1,0)(1,0,2)[7] intercept   : AIC=58274.081, Time=4.47 sec
#  ARIMA(0,1,0)(0,0,2)[7] intercept   : AIC=58727.198, Time=3.05 sec
#  ARIMA(0,1,0)(1,0,1)[7] intercept   : AIC=58338.671, Time=1.33 sec
#  ARIMA(0,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=6.50 sec
#  ARIMA(0,1,0)(0,0,1)[7] intercept   : AIC=59019.220, Time=1.03 sec
#  ARIMA(0,1,0)(2,0,1)[7] intercept   : AIC=58298.363, Time=4.94 sec
#  ARIMA(0,1,1)(1,0,2)[7] intercept   : AIC=58276.038, Time=6.64 sec
#  ARIMA(1,1,1)(1,0,2)[7] intercept   : AIC=inf, Time=7.69 sec
#  ARIMA(0,1,0)(1,0,2)[7]             : AIC=58272.081, Time=1.63 sec
#  ARIMA(0,1,0)(0,0,2)[7]             : AIC=58725.198, Time=1.25 sec
#  ARIMA(0,1,0)(1,0,1)[7]             : AIC=58336.671, Time=0.53 sec
#  ARIMA(0,1,0)(2,0,2)[7]             : AIC=inf, Time=4.41 sec
#  ARIMA(0,1,0)(0,0,1)[7]             : AIC=59017.220, Time=0.39 sec
#  ARIMA(0,1,0)(2,0,1)[7]             : AIC=58296.363, Time=1.73 sec
#  ARIMA(1,1,0)(1,0,2)[7]             : AIC=58274.045, Time=2.11 sec
#  ARIMA(0,1,1)(1,0,2)[7]             : AIC=58274.038, Time=2.86 sec
#  ARIMA(1,1,1)(1,0,2)[7]             : AIC=inf, Time=3.74 sec
#
# Best model:  ARIMA(0,1,0)(1,0,2)[7]
# Total fit time: 91.723 seconds
# irradiancefortaleza.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=18.39 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=57802.739, Time=0.25 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=56641.193, Time=5.60 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=56872.549, Time=6.29 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=57800.740, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=57033.605, Time=0.26 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=56350.353, Time=12.27 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=56319.690, Time=18.85 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=56369.623, Time=9.72 sec
#  ARIMA(1,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=27.77 sec
#  ARIMA(1,1,0)(1,0,2)[7] intercept   : AIC=56300.831, Time=22.27 sec
#  ARIMA(1,1,0)(0,0,2)[7] intercept   : AIC=56618.678, Time=10.13 sec
#  ARIMA(1,1,0)(0,0,1)[7] intercept   : AIC=56805.668, Time=4.39 sec
#  ARIMA(0,1,0)(1,0,2)[7] intercept   : AIC=56313.595, Time=14.01 sec
#  ARIMA(2,1,0)(1,0,2)[7] intercept   : AIC=56299.749, Time=21.66 sec
#  ARIMA(2,1,0)(0,0,2)[7] intercept   : AIC=56616.326, Time=14.31 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=56369.142, Time=12.54 sec
#  ARIMA(2,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=34.78 sec
#  ARIMA(2,1,0)(0,0,1)[7] intercept   : AIC=56801.991, Time=6.01 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=56319.290, Time=24.38 sec
#  ARIMA(3,1,0)(1,0,2)[7] intercept   : AIC=56256.622, Time=27.82 sec
#  ARIMA(3,1,0)(0,0,2)[7] intercept   : AIC=56582.817, Time=15.16 sec
#  ARIMA(3,1,0)(1,0,1)[7] intercept   : AIC=56316.187, Time=17.42 sec
#  ARIMA(3,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=32.96 sec
#  ARIMA(3,1,0)(0,0,1)[7] intercept   : AIC=56736.595, Time=8.18 sec
#  ARIMA(3,1,0)(2,0,1)[7] intercept   : AIC=56276.466, Time=22.01 sec
#  ARIMA(4,1,0)(1,0,2)[7] intercept   : AIC=56189.956, Time=11.18 sec
#  ARIMA(4,1,0)(0,0,2)[7] intercept   : AIC=56473.977, Time=12.38 sec
#  ARIMA(4,1,0)(1,0,1)[7] intercept   : AIC=56232.090, Time=13.20 sec
#  ARIMA(4,1,0)(2,0,2)[7] intercept   : AIC=55337.402, Time=33.54 sec
#  ARIMA(4,1,0)(2,0,1)[7] intercept   : AIC=56205.027, Time=26.90 sec
#  ARIMA(5,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=42.01 sec
#  ARIMA(4,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=32.29 sec
#  ARIMA(3,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=23.10 sec
#  ARIMA(5,1,1)(2,0,2)[7] intercept   : AIC=55354.923, Time=18.79 sec
#  ARIMA(4,1,0)(2,0,2)[7]             : AIC=55335.366, Time=8.22 sec
#  ARIMA(4,1,0)(1,0,2)[7]             : AIC=56187.956, Time=2.81 sec
#  ARIMA(4,1,0)(2,0,1)[7]             : AIC=56203.027, Time=3.38 sec
#  ARIMA(4,1,0)(1,0,1)[7]             : AIC=56230.090, Time=2.13 sec
#  ARIMA(3,1,0)(2,0,2)[7]             : AIC=inf, Time=7.02 sec
#  ARIMA(5,1,0)(2,0,2)[7]             : AIC=inf, Time=7.65 sec
#  ARIMA(4,1,1)(2,0,2)[7]             : AIC=inf, Time=5.86 sec
#  ARIMA(3,1,1)(2,0,2)[7]             : AIC=inf, Time=7.44 sec
#  ARIMA(5,1,1)(2,0,2)[7]             : AIC=55353.302, Time=5.41 sec
#
# Best model:  ARIMA(4,1,0)(2,0,2)[7]
# Total fit time: 650.969 seconds
# irradiancefloripa.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=2.40 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=58421.250, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=56678.492, Time=0.87 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=57022.459, Time=0.82 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=58419.251, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=57194.527, Time=0.07 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=56419.734, Time=2.72 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=56396.087, Time=4.44 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=56426.970, Time=1.62 sec
#  ARIMA(1,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=5.72 sec
#  ARIMA(1,1,0)(1,0,2)[7] intercept   : AIC=56385.259, Time=4.81 sec
#  ARIMA(1,1,0)(0,0,2)[7] intercept   : AIC=56686.495, Time=2.73 sec
#  ARIMA(1,1,0)(0,0,1)[7] intercept   : AIC=56904.020, Time=0.83 sec
#  ARIMA(0,1,0)(1,0,2)[7] intercept   : AIC=56518.611, Time=4.61 sec
#  ARIMA(2,1,0)(1,0,2)[7] intercept   : AIC=56384.779, Time=5.26 sec
#  ARIMA(2,1,0)(0,0,2)[7] intercept   : AIC=56687.894, Time=3.28 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=56426.437, Time=2.12 sec
#  ARIMA(2,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=7.12 sec
#  ARIMA(2,1,0)(0,0,1)[7] intercept   : AIC=56905.580, Time=0.91 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=56395.714, Time=5.29 sec
#  ARIMA(3,1,0)(1,0,2)[7] intercept   : AIC=56349.425, Time=5.81 sec
#  ARIMA(3,1,0)(0,0,2)[7] intercept   : AIC=56643.434, Time=3.84 sec
#  ARIMA(3,1,0)(1,0,1)[7] intercept   : AIC=56388.131, Time=2.94 sec
#  ARIMA(3,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=9.50 sec
#  ARIMA(3,1,0)(0,0,1)[7] intercept   : AIC=56834.556, Time=1.58 sec
#  ARIMA(3,1,0)(2,0,1)[7] intercept   : AIC=56360.463, Time=6.61 sec
#  ARIMA(4,1,0)(1,0,2)[7] intercept   : AIC=56271.956, Time=6.18 sec
#  ARIMA(4,1,0)(0,0,2)[7] intercept   : AIC=56501.230, Time=4.34 sec
#  ARIMA(4,1,0)(1,0,1)[7] intercept   : AIC=56299.149, Time=2.29 sec
#  ARIMA(4,1,0)(2,0,2)[7] intercept   : AIC=inf, Time=10.26 sec
#  ARIMA(4,1,0)(0,0,1)[7] intercept   : AIC=56642.768, Time=0.94 sec
#  ARIMA(4,1,0)(2,0,1)[7] intercept   : AIC=56279.200, Time=7.97 sec
#  ARIMA(5,1,0)(1,0,2)[7] intercept   : AIC=56189.691, Time=7.36 sec
#  ARIMA(5,1,0)(0,0,2)[7] intercept   : AIC=56328.307, Time=2.58 sec
#  ARIMA(5,1,0)(1,0,1)[7] intercept   : AIC=56201.010, Time=5.82 sec
#  ARIMA(5,1,0)(2,0,2)[7] intercept   : AIC=55601.783, Time=11.49 sec
#  ARIMA(5,1,0)(2,0,1)[7] intercept   : AIC=56190.035, Time=9.27 sec
#  ARIMA(5,1,1)(2,0,2)[7] intercept   : AIC=55654.680, Time=11.28 sec
#  ARIMA(4,1,1)(2,0,2)[7] intercept   : AIC=55762.864, Time=11.46 sec
#  ARIMA(5,1,0)(2,0,2)[7]             : AIC=55595.044, Time=7.16 sec
#  ARIMA(5,1,0)(1,0,2)[7]             : AIC=56187.691, Time=3.05 sec
#  ARIMA(5,1,0)(2,0,1)[7]             : AIC=56188.035, Time=3.49 sec
#  ARIMA(5,1,0)(1,0,1)[7]             : AIC=56199.010, Time=2.47 sec
#  ARIMA(4,1,0)(2,0,2)[7]             : AIC=inf, Time=8.13 sec
#  ARIMA(5,1,1)(2,0,2)[7]             : AIC=55652.681, Time=7.80 sec
#  ARIMA(4,1,1)(2,0,2)[7]             : AIC=55763.351, Time=9.03 sec
#
# Best model:  ARIMA(5,1,0)(2,0,2)[7]
# Total fit time: 218.375 seconds
# irradiancesp.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[7] intercept   : AIC=60569.802, Time=3.10 sec
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=64825.681, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=61027.254, Time=1.33 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=62267.276, Time=2.01 sec
#  ARIMA(0,0,0)(0,0,0)[7]             : AIC=67909.708, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,1)[7] intercept   : AIC=60886.074, Time=2.81 sec
#  ARIMA(2,0,2)(1,0,0)[7] intercept   : AIC=60795.357, Time=2.68 sec
#  ARIMA(2,0,2)(2,0,1)[7] intercept   : AIC=60538.519, Time=7.43 sec
#  ARIMA(2,0,2)(2,0,0)[7] intercept   : AIC=60611.905, Time=5.36 sec
#  ARIMA(2,0,2)(2,0,2)[7] intercept   : AIC=60515.147, Time=8.59 sec
#  ARIMA(2,0,2)(1,0,2)[7] intercept   : AIC=60495.776, Time=8.54 sec
#  ARIMA(2,0,2)(0,0,2)[7] intercept   : AIC=60698.351, Time=4.29 sec
#  ARIMA(1,0,2)(1,0,2)[7] intercept   : AIC=60712.011, Time=6.37 sec
#  ARIMA(2,0,1)(1,0,2)[7] intercept   : AIC=60592.007, Time=5.69 sec
#  ARIMA(3,0,2)(1,0,2)[7] intercept   : AIC=60504.997, Time=7.77 sec
#  ARIMA(2,0,3)(1,0,2)[7] intercept   : AIC=60074.666, Time=8.90 sec
#  ARIMA(2,0,3)(0,0,2)[7] intercept   : AIC=60332.161, Time=7.91 sec
#  ARIMA(2,0,3)(1,0,1)[7] intercept   : AIC=60138.489, Time=5.72 sec
#  ARIMA(2,0,3)(2,0,2)[7] intercept   : AIC=60565.888, Time=9.24 sec
#  ARIMA(2,0,3)(0,0,1)[7] intercept   : AIC=60402.677, Time=4.56 sec
#  ARIMA(2,0,3)(2,0,1)[7] intercept   : AIC=60074.294, Time=7.05 sec
#  ARIMA(2,0,3)(2,0,0)[7] intercept   : AIC=60566.141, Time=5.76 sec
#  ARIMA(2,0,3)(1,0,0)[7] intercept   : AIC=60701.975, Time=2.13 sec
#  ARIMA(1,0,3)(2,0,1)[7] intercept   : AIC=60614.624, Time=6.84 sec
#  ARIMA(3,0,3)(2,0,1)[7] intercept   : AIC=60308.977, Time=9.12 sec
#  ARIMA(2,0,4)(2,0,1)[7] intercept   : AIC=60567.709, Time=6.80 sec
#  ARIMA(1,0,2)(2,0,1)[7] intercept   : AIC=60630.676, Time=5.98 sec
#  ARIMA(1,0,4)(2,0,1)[7] intercept   : AIC=60628.136, Time=8.05 sec
#  ARIMA(3,0,2)(2,0,1)[7] intercept   : AIC=60549.911, Time=8.51 sec
#  ARIMA(3,0,4)(2,0,1)[7] intercept   : AIC=59931.557, Time=9.49 sec
#  ARIMA(3,0,4)(1,0,1)[7] intercept   : AIC=59962.088, Time=5.88 sec
#  ARIMA(3,0,4)(2,0,0)[7] intercept   : AIC=59981.374, Time=9.07 sec
#  ARIMA(3,0,4)(2,0,2)[7] intercept   : AIC=60625.938, Time=11.95 sec
#  ARIMA(3,0,4)(1,0,0)[7] intercept   : AIC=60015.008, Time=3.87 sec
#  ARIMA(3,0,4)(1,0,2)[7] intercept   : AIC=59931.797, Time=10.54 sec
#  ARIMA(4,0,4)(2,0,1)[7] intercept   : AIC=60018.948, Time=10.33 sec
#  ARIMA(3,0,5)(2,0,1)[7] intercept   : AIC=59804.454, Time=9.94 sec
#  ARIMA(3,0,5)(1,0,1)[7] intercept   : AIC=59807.481, Time=6.95 sec
#  ARIMA(3,0,5)(2,0,0)[7] intercept   : AIC=59863.193, Time=9.15 sec
#  ARIMA(3,0,5)(2,0,2)[7] intercept   : AIC=59813.605, Time=13.04 sec
#  ARIMA(3,0,5)(1,0,0)[7] intercept   : AIC=59815.654, Time=2.80 sec
#  ARIMA(3,0,5)(1,0,2)[7] intercept   : AIC=59797.417, Time=10.01 sec
#  ARIMA(3,0,5)(0,0,2)[7] intercept   : AIC=59765.054, Time=10.11 sec
#  ARIMA(3,0,5)(0,0,1)[7] intercept   : AIC=59796.605, Time=6.80 sec
#  ARIMA(2,0,5)(0,0,2)[7] intercept   : AIC=60049.854, Time=9.36 sec
#  ARIMA(3,0,4)(0,0,2)[7] intercept   : AIC=60267.071, Time=11.85 sec
#  ARIMA(4,0,5)(0,0,2)[7] intercept   : AIC=59738.270, Time=12.70 sec
#  ARIMA(4,0,5)(0,0,1)[7] intercept   : AIC=59778.051, Time=7.87 sec
#  ARIMA(4,0,5)(1,0,2)[7] intercept   : AIC=59819.633, Time=11.37 sec
#  ARIMA(4,0,5)(1,0,1)[7] intercept   : AIC=59806.880, Time=8.51 sec
#  ARIMA(4,0,4)(0,0,2)[7] intercept   : AIC=60031.205, Time=13.16 sec
#  ARIMA(5,0,5)(0,0,2)[7] intercept   : AIC=59655.229, Time=12.12 sec
#  ARIMA(5,0,5)(0,0,1)[7] intercept   : AIC=59716.730, Time=8.94 sec
#  ARIMA(5,0,5)(1,0,2)[7] intercept   : AIC=59677.919, Time=13.21 sec
#  ARIMA(5,0,5)(1,0,1)[7] intercept   : AIC=59693.340, Time=8.30 sec
#  ARIMA(5,0,4)(0,0,2)[7] intercept   : AIC=59786.573, Time=14.91 sec
#  ARIMA(5,0,5)(0,0,2)[7]             : AIC=61341.455, Time=5.20 sec
#
# Best model:  ARIMA(5,0,5)(0,0,2)[7] intercept
# Total fit time: 430.111 seconds
# coloradoRiver.txt
# Modelo já executado
# sunspot.txt
# Modelo já executado
# milk.txt
# Modelo já executado
# Unemployment.txt
# Modelo já executado
# ausbee.txt
# Modelo já executado
# austres.txt
# Modelo já executado
# heartrate.txt
# Modelo já executado
# ozon.txt
# Modelo já executado
# pollution.txt
# Modelo já executado
# redwine.txt
# Modelo já executado
# gasoline.txt
# Modelo já executado
# temperature.txt
# Modelo já executado
# woolyrnq.txt
# Modelo já executado
# melbmin.txt
# Modelo já executado
