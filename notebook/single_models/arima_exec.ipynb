# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'chamados'
horizon = 1
force= False

# %%
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'], horizon, force)
# Out:
# masamu.txt
# Modelo já executado
# marecacc.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=1.42 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=4697.442, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=4311.260, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=4695.442, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=4679.422, Time=0.05 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=4186.513, Time=0.46 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=1.94 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=0.82 sec
#  ARIMA(0,1,0)(2,0,0)[7] intercept   : AIC=4235.653, Time=0.41 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=4174.057, Time=0.59 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=4306.249, Time=0.27 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=2.54 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(3,1,0)(2,0,0)[7] intercept   : AIC=4173.318, Time=1.07 sec
#  ARIMA(3,1,0)(1,0,0)[7] intercept   : AIC=4302.075, Time=0.30 sec
#  ARIMA(3,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=2.92 sec
#  ARIMA(3,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(4,1,0)(2,0,0)[7] intercept   : AIC=4175.055, Time=1.11 sec
#  ARIMA(3,1,1)(2,0,0)[7] intercept   : AIC=4173.598, Time=2.40 sec
#  ARIMA(2,1,1)(2,0,0)[7] intercept   : AIC=4171.767, Time=1.84 sec
#  ARIMA(2,1,1)(1,0,0)[7] intercept   : AIC=4303.442, Time=0.67 sec
#  ARIMA(2,1,1)(2,0,1)[7] intercept   : AIC=inf, Time=2.82 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(1,1,1)(2,0,0)[7] intercept   : AIC=4169.773, Time=1.15 sec
#  ARIMA(1,1,1)(1,0,0)[7] intercept   : AIC=4301.465, Time=0.39 sec
#  ARIMA(1,1,1)(2,0,1)[7] intercept   : AIC=inf, Time=2.22 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(0,1,1)(2,0,0)[7] intercept   : AIC=4195.904, Time=0.62 sec
#  ARIMA(1,1,2)(2,0,0)[7] intercept   : AIC=4171.767, Time=1.50 sec
#  ARIMA(0,1,2)(2,0,0)[7] intercept   : AIC=4180.467, Time=0.69 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=4173.769, Time=1.55 sec
#  ARIMA(1,1,1)(2,0,0)[7]             : AIC=4167.773, Time=0.52 sec
#  ARIMA(1,1,1)(1,0,0)[7]             : AIC=4299.466, Time=0.20 sec
#  ARIMA(1,1,1)(2,0,1)[7]             : AIC=inf, Time=2.10 sec
#  ARIMA(1,1,1)(1,0,1)[7]             : AIC=inf, Time=0.70 sec
#  ARIMA(0,1,1)(2,0,0)[7]             : AIC=4193.904, Time=0.26 sec
#  ARIMA(1,1,0)(2,0,0)[7]             : AIC=4184.514, Time=0.30 sec
#  ARIMA(2,1,1)(2,0,0)[7]             : AIC=4169.767, Time=0.89 sec
#  ARIMA(1,1,2)(2,0,0)[7]             : AIC=4169.767, Time=0.87 sec
#  ARIMA(0,1,0)(2,0,0)[7]             : AIC=4233.653, Time=0.16 sec
#  ARIMA(0,1,2)(2,0,0)[7]             : AIC=4178.467, Time=0.28 sec
#  ARIMA(2,1,0)(2,0,0)[7]             : AIC=4172.058, Time=0.28 sec
#  ARIMA(2,1,2)(2,0,0)[7]             : AIC=4171.769, Time=0.62 sec
#
# Best model:  ARIMA(1,1,1)(2,0,0)[7]
# Total fit time: 42.243 seconds
