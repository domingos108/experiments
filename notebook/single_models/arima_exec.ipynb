# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'irradiance'
horizon = 1
force= False

# %%
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'], horizon, force)
# Out:
# irradiancecabrobo.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[13] intercept   : AIC=inf, Time=24.09 sec
#  ARIMA(0,1,0)(0,0,0)[13] intercept   : AIC=89702.021, Time=0.10 sec
#  ARIMA(1,1,0)(1,0,0)[13] intercept   : AIC=86412.760, Time=10.92 sec
#  ARIMA(0,1,1)(0,0,1)[13] intercept   : AIC=87667.020, Time=8.77 sec
#  ARIMA(0,1,0)(0,0,0)[13]             : AIC=89700.025, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[13] intercept   : AIC=88146.951, Time=0.31 sec
#  ARIMA(1,1,0)(2,0,0)[13] intercept   : AIC=inf, Time=36.54 sec
#  ARIMA(1,1,0)(1,0,1)[13] intercept   : AIC=inf, Time=19.86 sec
#  ARIMA(1,1,0)(0,0,1)[13] intercept   : AIC=87530.358, Time=9.19 sec
#  ARIMA(1,1,0)(2,0,1)[13] intercept   : AIC=inf, Time=44.09 sec
#  ARIMA(0,1,0)(1,0,0)[13] intercept   : AIC=86446.788, Time=4.03 sec
#  ARIMA(2,1,0)(1,0,0)[13] intercept   : AIC=86384.042, Time=12.58 sec
#  ARIMA(2,1,0)(0,0,0)[13] intercept   : AIC=88122.573, Time=0.38 sec
#  ARIMA(2,1,0)(2,0,0)[13] intercept   : AIC=inf, Time=31.39 sec
#  ARIMA(2,1,0)(1,0,1)[13] intercept   : AIC=84024.219, Time=12.44 sec
#  ARIMA(2,1,0)(0,0,1)[13] intercept   : AIC=87474.258, Time=8.56 sec
#  ARIMA(2,1,0)(2,0,1)[13] intercept   : AIC=84273.932, Time=37.84 sec
#  ARIMA(2,1,0)(1,0,2)[13] intercept   : AIC=84803.133, Time=30.97 sec
#  ARIMA(2,1,0)(0,0,2)[13] intercept   : AIC=86926.049, Time=21.41 sec
#  ARIMA(2,1,0)(2,0,2)[13] intercept   : AIC=84575.268, Time=40.49 sec
#  ARIMA(3,1,0)(1,0,1)[13] intercept   : AIC=84433.173, Time=17.29 sec
#  ARIMA(2,1,1)(1,0,1)[13] intercept   : AIC=inf, Time=13.72 sec
#  ARIMA(1,1,1)(1,0,1)[13] intercept   : AIC=inf, Time=12.74 sec
#  ARIMA(3,1,1)(1,0,1)[13] intercept   : AIC=inf, Time=21.85 sec
#  ARIMA(2,1,0)(1,0,1)[13]             : AIC=inf, Time=8.36 sec
#
# Best model:  ARIMA(2,1,0)(1,0,1)[13] intercept
# Total fit time: 428.117 seconds
