# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model.elm import Model as ELM
from sklearn.ensemble import BaggingRegressor

from model import single_ml_model_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2


for n_estimators in [50]:
    for max_samples in [0.8]:
        for max_features in [0.8]:
            model = BaggingRegressor(n_jobs=-1)
            
            experiment_id = 'irradiacao2024'
            model_name = f'elmbagg{n_estimators}{max_samples}{max_features}'
            normalize = True
            force = False
            model_exec = 10
            
            experiment_params = {
                'diff_kpss': False,
                'horizon': 1
            }
            
            model_parameters = {
                        'estimator': [
                            ELM(hidden_dim=10),
                            ELM(hidden_dim=20),
                            ELM(hidden_dim=50),
                            ELM(hidden_dim=100),
                        ], 
                        'n_estimators': [n_estimators],
                        'max_features': [max_features],
                        'max_samples': [max_samples]
                        
                    }
    
            grid_search_exp.grid_seach_multiple_bases(
                 single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
                 model_exec, model_name, experiment_id, force = force
            )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.79s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 10}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:06<00:00,  1.50s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 10}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:05<00:00,  1.48s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 10}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:05<00:00,  1.48s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 10}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:05<00:00,  1.46s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 10}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:05<00:00,  1.47s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 10}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.87s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 10}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.86s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 10}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.84s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 10}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.86s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 10}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.87s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 10}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.86s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 10}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:10<00:00,  2.60s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 20}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:09<00:00,  2.41s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 20}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:09<00:00,  2.44s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 20}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:10<00:00,  2.62s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 20}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:10<00:00,  2.68s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 20}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:10<00:00,  2.68s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 20}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:13<00:00,  3.43s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 20}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:13<00:00,  3.43s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 20}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:13<00:00,  3.46s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 20}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:13<00:00,  3.46s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 20}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:13<00:00,  3.47s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 20}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:13<00:00,  3.49s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 20}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:22<00:00,  5.52s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 50}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:22<00:00,  5.52s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 50}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:22<00:00,  5.57s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.6, 'n_estimators': 50}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:21<00:00,  5.46s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 50}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:22<00:00,  5.50s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 50}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:22<00:00,  5.56s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.6, 'n_estimators': 50}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:30<00:00,  7.69s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 50}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:30<00:00,  7.63s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 50}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:30<00:00,  7.68s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.6, 'max_samples': 0.8, 'n_estimators': 50}
# irradiancecabrobo.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:31<00:00,  7.75s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 50}
# irradianceouricuri.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:31<00:00,  7.78s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 50}
# irradiancesalgueiro.txt
# 100%|█████████████████████████████████████████████| 4/4 [00:31<00:00,  7.84s/it]
# {'estimator': Model(hidden_dim=100), 'max_features': 0.8, 'max_samples': 0.8, 'n_estimators': 50}
