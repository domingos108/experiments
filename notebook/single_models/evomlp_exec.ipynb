# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model.mlp_ga import MetaHeuristicMLP

from model import single_ml_model_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = MetaHeuristicMLP()

experiment_id = 'gaevo'
model_name = 'mlpevofinetune'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1,
    'type_filter': None
}

model_parameters = {
    'iterations': [300],
    'crossover_type': ['roulette'],
    'pop_size': [100], 
    'pct_mutation': [0.3], 
    'hidden_layer_sizes': [10, 20, 50], 
}

grid_search_exp.grid_seach_multiple_bases(
     single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# coloradoRiver.txt
# 100%|███████████████████████████████████████████████████████████████████████| 300/300 [00:42<00:00,  7.01it/s]
# best arg 27
# 100%|███████████████████████████████████████████████████████████████████████| 300/300 [00:42<00:00,  7.03it/s]
# best arg 287
# 100%|███████████████████████████████████████████████████████████████████████| 300/300 [00:44<00:00,  6.73it/s]
# best arg 208
# 100%|███████████████████████████████████████████████████████████████████████| 300/300 [00:43<00:00,  6.83it/s]
# best arg 279
# 100%|███████████████████████████████████████████████████████████████████████| 300/300 [00:44<00:00,  6.76it/s]
# best arg 23
# 100%|███████████████████████████████████████████████████████████████████████| 300/300 [00:43<00:00,  6.83it/s]
# best arg 17
# 100%|███████████████████████████████████████████████████████████████████████| 300/300 [00:39<00:00,  7.58it/s]
# best arg 53
# ...
