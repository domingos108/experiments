# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import Informer
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = Informer

experiment_id = 'pertexps'
model_name = 'informer'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    "lag_size": None
}

model_parameters = {
    'scaler_type': ['robust'],
    'hidden_size': [50, 100, 200],
    'conv_hidden_size': [32],
    'n_head': [2],
    'loss': [DistributionLoss(distribution='StudentT', level=[80, 90], return_params=True)],
    'learning_rate': [0.01, 0.001, 0.0001],
    'max_steps': [200],

}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 3696
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# melbmin.txt
# consumocoformated.txt
# Seed set to 9230
# Seed set to 7340
# Seed set to 500
# Seed set to 8022
# Seed set to 3673
# Seed set to 6892
# Seed set to 8843
# Seed set to 1790
# Seed set to 3031
# Seed set to 451
# Seed set to 7241
# Seed set to 415
# Seed set to 6712
# Seed set to 5954
# Seed set to 6166
# Seed set to 2624
# Seed set to 6889
# Seed set to 9701
# Seed set to 3471
# Seed set to 1971
# consumoneformated.txt
# Seed set to 9020
# Seed set to 9983
# Seed set to 7147
# Seed set to 5466
# Seed set to 7454
# Seed set to 6888
# Seed set to 3574
# Seed set to 6299
# Seed set to 186
# Seed set to 4988
# Seed set to 6422
# Seed set to 7072
# Seed set to 9104
# Seed set to 4373
# Seed set to 3990
# Seed set to 6989
# Seed set to 2900
# Seed set to 5955
# Seed set to 1623
# Seed set to 7621
# consumonoformated.txt
# Seed set to 2582
# Seed set to 3329
# Seed set to 3390
# Seed set to 9949
# Seed set to 4645
# Seed set to 347
# Seed set to 3280
# Seed set to 2929
# Seed set to 3243
# Seed set to 8751
# Seed set to 755
# Seed set to 2154
# Seed set to 936
# Seed set to 399
# Seed set to 2470
# Seed set to 9079
# Seed set to 9113
# Seed set to 5375
# Seed set to 5621
# Seed set to 8311
# consumosdformated.txt
# Seed set to 690
# Seed set to 5541
# Seed set to 3588
# Seed set to 393
# Seed set to 3060
# Seed set to 8037
# Seed set to 4955
# Seed set to 1323
# Seed set to 5991
# Seed set to 6546
# Seed set to 8919
# Seed set to 6061
# Seed set to 2549
# Seed set to 4047
# Seed set to 6318
# Seed set to 1034
# Seed set to 7249
# Seed set to 9801
# Seed set to 4020
# Seed set to 9200
# consumosulformated.txt
# Seed set to 7411
# Seed set to 7707
# Seed set to 231
# Seed set to 6376
# Seed set to 1153
# Seed set to 3363
# Seed set to 8213
# Seed set to 9371
# Seed set to 3107
# Seed set to 5697
# Seed set to 2818
# Seed set to 1978
# Seed set to 6663
# Seed set to 9031
# Seed set to 1171
# Seed set to 6693
# Seed set to 3395
# Seed set to 7252
# Seed set to 4660

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = KAN

experiment_id = 'pertexps'
model_name = 'kan'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    "lag_size": None
}

model_parameters = {
    'scaler_type': ['robust'],
    'loss': [DistributionLoss(distribution='StudentT', level=[80, 90], return_params=True)],
    'max_steps': [100],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 1528
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# melbmin.txt
# consumocoformated.txt
# Seed set to 2148
# Seed set to 9487
# Seed set to 8603
# Seed set to 2018
# Seed set to 6282
# Seed set to 1249
# Seed set to 8586
# Seed set to 1344
# Seed set to 2418
# Seed set to 9612
# Seed set to 1062
# Seed set to 4931
# Seed set to 1661
# Seed set to 7674
# Seed set to 3542
# Seed set to 5031
# Seed set to 7920
# Seed set to 7010
# Seed set to 6207
# Seed set to 9099
# consumoneformated.txt
# Seed set to 6282
# Seed set to 3546
# Seed set to 9893
# Seed set to 8421
# Seed set to 3184
# Seed set to 6508
# Seed set to 1133
# Seed set to 4501
# Seed set to 3843
# Seed set to 1575
# Seed set to 7466
# Seed set to 6181
# Seed set to 46
# Seed set to 5379
# Seed set to 3008
# Seed set to 8500
# Seed set to 7318
# Seed set to 5946
# Seed set to 4908
# Seed set to 4517
# consumonoformated.txt
# Seed set to 2450
# Seed set to 7169
# Seed set to 7189
# Seed set to 4238
# Seed set to 5671
# Seed set to 6892
# Seed set to 6943
# Seed set to 6559
# Seed set to 5155
# Seed set to 4190
# Seed set to 8026
# Seed set to 6161
# Seed set to 4874
# Seed set to 9146
# Seed set to 2464
# Seed set to 4869
# Seed set to 5580
# Seed set to 9940
# Seed set to 5053
# Seed set to 3961
# consumosdformated.txt
# Seed set to 3067
# Seed set to 2186
# Seed set to 5167
# Seed set to 6663
# Seed set to 4633
# Seed set to 9685
# Seed set to 825
# Seed set to 6228
# Seed set to 6343
# Seed set to 9591
# Seed set to 7994
# Seed set to 3684
# Seed set to 7348
# Seed set to 1605
# Seed set to 6484
# Seed set to 9543
# Seed set to 5000
# Seed set to 3940
# Seed set to 5878
# Seed set to 8462
# consumosulformated.txt
# Seed set to 9862
# Seed set to 5369
# Seed set to 5081
# Seed set to 3677
# Seed set to 921
# Seed set to 853
# Seed set to 5105
# Seed set to 9822
# Seed set to 2880
# Seed set to 3381
# Seed set to 6516
# Seed set to 2009
# Seed set to 2012
# Seed set to 6886
# Seed set to 5207
# Seed set to 3290
# Seed set to 3249
# Seed set to 4703
# Seed set to 2492

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import DeepAR
from neuralforecast.losses.pytorch import DistributionLoss, MQLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = DeepAR

experiment_id = 'pertexps'
model_name = 'deepar'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    "lag_size": None
}

model_parameters = {
    'scaler_type': ['robust'],
    'lstm_n_layers': [1],
    'trajectory_samples': [100],
    'valid_loss': [MQLoss(level=[80, 90])],
    'loss': [DistributionLoss(distribution='StudentT', level=[80, 90], return_params=True)],
    'learning_rate': [0.005],
    'max_steps': [100],

}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 6265
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# melbmin.txt
# consumocoformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9011
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 576
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5877
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4590
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6720
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4180
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5562
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8225
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8249
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 376
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 717
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 3457
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9337
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 1626
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 7213
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6951
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8455
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9229
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 815
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9132
# consumoneformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 3630
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6313
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 292
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 3404
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 405
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 1523
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 7596
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 2421
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9828
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 674
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4532
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5991
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6655
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8026
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9702
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4541
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4789
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6692
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 31
# consumonoformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8813
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4647
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 7641
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6587
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 7011
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 7995
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8820
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8665
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5526
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 1879
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 757
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8838
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5353
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 1051
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 2165
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6853
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9398
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 7159
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5141
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 1951
# consumosdformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4631
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 1041
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6039
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 1086
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6490
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 7432
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 2522
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5250
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8143
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 3085
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6361
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 2328
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5175
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 1796
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 2964
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5342
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6251
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 640
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8074
# consumosulformated.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8604
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6568
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 7792
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4799
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8591
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 2110
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4339
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8018
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9331
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6260
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 2541
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 9331
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 8300
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 4752
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6100
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 5384
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 3747
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 3023
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(
# Seed set to 6959
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn(

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import NHITS
from neuralforecast.losses.pytorch import DistributionLoss, RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = NHITS

experiment_id = 'pertexps'
model_name = 'nhits'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    "lag_size": None
}

model_parameters = {
    'learning_rate': [1e-3],
    'loss': [DistributionLoss(distribution='StudentT', level=[80, 90], return_params=True)],
    'n_freq_downsample': [[2, 1, 1]],
    'scaler_type': ['robust'],
    'max_steps': [200],
    'inference_windows_batch_size': [1],
    'val_check_steps': [10],
    'learning_rate': [1e-3],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 9504
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# melbmin.txt
# consumocoformated.txt
# Seed set to 2173
# Seed set to 6915
# Seed set to 8340
# Seed set to 4317
# Seed set to 7963
# Seed set to 544
# Seed set to 9650
# Seed set to 6578
# Seed set to 3656
# Seed set to 1542
# Seed set to 1367
# Seed set to 7352
# Seed set to 1774
# Seed set to 3884
# Seed set to 5745
# Seed set to 3719
# Seed set to 8772
# Seed set to 6950
# Seed set to 4785
# Seed set to 6614
# consumoneformated.txt
# Seed set to 241
# Seed set to 5261
# Seed set to 411
# Seed set to 2921
# Seed set to 4774
# Seed set to 594
# Seed set to 5619
# Seed set to 3505
# Seed set to 9660
# Seed set to 8270
# Seed set to 8788
# Seed set to 6635
# Seed set to 8893
# Seed set to 5660
# Seed set to 302
# Seed set to 2636
# Seed set to 3381
# Seed set to 3400
# Seed set to 1318
# Seed set to 6296
# consumonoformated.txt
# Seed set to 4968
# Seed set to 7960
# Seed set to 9229
# Seed set to 3128
# Seed set to 9244
# Seed set to 7545
# Seed set to 7087
# Seed set to 2830
# Seed set to 2739
# Seed set to 7255
# Seed set to 6846
# Seed set to 9691
# Seed set to 1719
# Seed set to 8270
# Seed set to 6529
# Seed set to 5721
# Seed set to 1541
# Seed set to 578
# Seed set to 9997
# Seed set to 6954
# consumosdformated.txt
# Seed set to 3451
# Seed set to 8337
# Seed set to 6928
# Seed set to 7666
# Seed set to 2889
# Seed set to 4444
# Seed set to 6997
# Seed set to 8984
# Seed set to 2311
# Seed set to 6473
# Seed set to 5495
# Seed set to 7282
# Seed set to 7037
# Seed set to 7333
# Seed set to 9041
# Seed set to 4799
# Seed set to 7026
# Seed set to 5132
# Seed set to 1182
# Seed set to 4156
# consumosulformated.txt
# Seed set to 5847
# Seed set to 5685
# Seed set to 5851
# Seed set to 1125
# Seed set to 9886
# Seed set to 2191
# Seed set to 445
# Seed set to 4533
# Seed set to 8308
# Seed set to 7193
# Seed set to 8945
# Seed set to 1922
# Seed set to 2227
# Seed set to 1393
# Seed set to 8455
# Seed set to 4579
# Seed set to 7043
# Seed set to 3576
# Seed set to 1696
