# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.losses.pytorch import RMSE

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = KAN

experiment_id = 'hourwindspeed'
model_name = 'kan'
normalize = True
force = False
model_exec = 10
horizon = 24
experiment_params = {
    'diff_kpss': False,
    'horizon': horizon
}

model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# windspeedcampinagrandehour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 2263
# Seed set to 4768
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
#  33%|███████████████████████████▋                                                       | 1/3 [17:56<35:52, 1076.07s/it]Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [36:11<18:07, 1087.72s/it]Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [55:24<00:00, 1108.03s/it]
# Seed set to 2604
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 24, 'random_seed': 3444, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# windspeedcaruaruhour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
#  33%|███████████████████████████▋                                                       | 1/3 [17:39<35:19, 1059.72s/it]Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [35:57<18:02, 1082.19s/it]Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [55:17<00:00, 1105.94s/it]
# Seed set to 2604
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 24, 'random_seed': 3444, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# windspeedcastelodopiauihour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
#  33%|███████████████████████████▋                                                       | 1/3 [17:27<34:54, 1047.20s/it]Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [35:28<17:47, 1067.28s/it]Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [54:36<00:00, 1092.19s/it]
# Seed set to 2604
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 24, 'random_seed': 3444, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# windspeedmaceiohour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
#  33%|███████████████████████████▋                                                       | 1/3 [17:26<34:52, 1046.07s/it]Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [35:31<17:49, 1069.42s/it]Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [54:50<00:00, 1096.83s/it]
# Seed set to 2604
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 24, 'random_seed': 3444, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 5785
# Seed set to 9335
# Seed set to 1061
# Seed set to 2283
# Seed set to 2826
# Seed set to 9184
# Seed set to 3444
# Seed set to 2604
# Seed set to 5785
# windspeedsalvadorhour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 9335
# Seed set to 1988
# Seed set to 9685
# Seed set to 3840
# Seed set to 8392
# Seed set to 3177
# Seed set to 7598
# Seed set to 6657
# Seed set to 6475
# Seed set to 4300
#  33%|███████████████████████████▋                                                       | 1/3 [16:47<33:34, 1007.27s/it]Seed set to 365
# Seed set to 282
# Seed set to 772
# Seed set to 5664
# Seed set to 2799
# Seed set to 1991
# Seed set to 7373
# Seed set to 8739
# Seed set to 1573
# Seed set to 5613
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [34:19<17:13, 1033.93s/it]Seed set to 8565
# Seed set to 6887
# Seed set to 7420
# Seed set to 5301
# Seed set to 655
# Seed set to 167
# Seed set to 8044
# Seed set to 8708
# Seed set to 7208
# Seed set to 3249
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [52:36<00:00, 1052.15s/it]
# Seed set to 9938
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 24, 'random_seed': 3249, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 9269
# Seed set to 7963
# Seed set to 7295
# Seed set to 1602
# Seed set to 2030
# Seed set to 1572
# Seed set to 9386
# Seed set to 3817
# Seed set to 1447
