# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.losses.pytorch import RMSE

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = KAN

experiment_id = 'irradiance'
model_name = 'kanval'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# irradiancecabrobo.txt
# Seed set to 5564
# /home/domingosjr/experiments/src/model/neural_forecast_exp.py:16: SyntaxWarning: invalid escape sequence '\('
#   warnings.filterwarnings("ignore", message="`isinstance\(treespec, LeafSpec\)` is deprecated")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 34
#      22 experiment_params = {
#      23     'diff_kpss': True,
#      24     'horizon': 1
#      25 }
#      27 model_parameters = {
#      28     'scaler_type': ['minmax'],
#      29     'hidden_size': [50, 100, 200],
#      30     'loss': [RMSE()],
#      31     'max_steps': [100],
#      32 }
# ---> 34 grid_search_exp.grid_seach_multiple_bases(
#      35      neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
#      36      model_exec, model_name, experiment_id, force = force
#      37 )
#
# File ~/experiments/src/model/grid_search_exp.py:171, in grid_seach_multiple_bases(fit_predict_class, model, normalize, model_parameters, experiment_params, model_exec, model_name, experiment_id, force, use_val_slipt_for_prev)
#     155     continue
#     157 exec_gs = GridSearch(
#     158     fit_predict_class,
#     159     model,
#    (...)    168     use_val_slipt_for_prev = use_val_slipt_for_prev
#     169 )
# --> 171 exec_gs.execution()
#
# File ~/experiments/src/model/grid_search_exp.py:102, in GridSearch.execution(self)
#     100 def execution(self):
# --> 102     best_exec_val, best_params = self._search_params()
#     104     experiment_params = self.experiment_params.copy()
#     105     experiment_params['test_size'] = config.TEST_SIZE
#
# File ~/experiments/src/model/grid_search_exp.py:85, in GridSearch._search_params(self)
#      73     model_actual = clone(self.model).set_params(** params)
#      75 model_exp = self.model_class_exp(
#      76     model_actual,
#      77     self.experiment_id,
#    (...)     82     experiment_params
#      83 )
# ---> 85 model_exp.fit_predict()
#      86 metrics_results = model_exp.metrics_results
#      87 exec_list_metrics.append(
#      88     metrics_results.get(self.group_metrics_name, {self.metric: np.inf})[self.metric]
#      89 )
#
# File ~/experiments/src/model/neural_forecast_exp.py:108, in NeuralForecastExp.fit_predict(self)
#     104 test_prevs = []
#     105 for i in range(df_prev.shape[0]):
#     106     # Prevemos o próximo ponto
#     107     # O Nixtla usa o final do DataFrame fornecido para gerar a previsão
# --> 108     forecast = fcst.predict(df=current_train)
#     109     test_prevs.append(forecast[model_name].iloc[params['h'] -1])
#     111     # "Update": Adicionamos a linha real do teste ao DataFrame de treino
#
# File ~/experiments/.venv/lib/python3.12/site-packages/neuralforecast/core.py:948, in NeuralForecast.predict(self, df, static_df, futr_df, verbose, engine, level, quantiles, h, **data_kwargs)
#     946 if df is not None:
#     947     validate_freq(df[self.time_col], self.freq)
# --> 948     dataset, uids, last_dates, _ = self._prepare_fit(
#     949         df=df,
#     950         static_df=static_df,
#     951         id_col=self.id_col,
#     952         time_col=self.time_col,
#     953         target_col=self.target_col,
#     954     )
#     955 else:
#     956     dataset = self.dataset
#
# File ~/experiments/.venv/lib/python3.12/site-packages/neuralforecast/core.py:339, in NeuralForecast._prepare_fit(self, df, static_df, id_col, time_col, target_col)
#     336 self.target_col = target_col
#     337 self._check_nan(df, static_df, id_col, time_col, target_col)
# --> 339 dataset, uids, last_dates, ds = TimeSeriesDataset.from_df(
#     340     df=df,
#     341     static_df=static_df,
#     342     id_col=id_col,
#     343     time_col=time_col,
#     344     target_col=target_col,
#     345 )
#     346 self._scalers_fit_transform(dataset)
#     347 return dataset, uids, last_dates, ds
#
# File ~/experiments/.venv/lib/python3.12/site-packages/neuralforecast/tsdataset.py:360, in TimeSeriesDataset.from_df(df, static_df, id_col, time_col, target_col)
#     352 @staticmethod
#     353 def from_df(df, static_df=None, id_col="unique_id", time_col="ds", target_col="y"):
#     354     # TODO: protect on equality of static_df + df indexes
#     355     # Define indices if not given and then extract static features
#     356     static, static_cols = TimeSeriesDataset._extract_static_features(
#     357         static_df, id_col
#     358     )
# --> 360     ids, times, data, indptr, sort_idxs = ufp.process_df(
#     361         df, id_col, time_col, target_col
#     362     )
#     363     # processor sets y as the first column
#     364     temporal_cols = pd.Index(
#     365         [target_col]
#     366         + [c for c in df.columns if c not in (id_col, time_col, target_col)]
#     367     )
#
# File ~/experiments/.venv/lib/python3.12/site-packages/utilsforecast/processing.py:676, in process_df(df, id_col, time_col, target_col)
#     673 validate_format(df, id_col, time_col, target_col)
#     675 # ids
# --> 676 id_counts = counts_by_id(df, id_col)
#     677 uids = id_counts[id_col]
#     679 # indices
#
# File ~/experiments/.venv/lib/python3.12/site-packages/utilsforecast/processing.py:58, in counts_by_id(df, id_col)
#      56 def counts_by_id(df: DataFrame, id_col: str) -> DataFrame:
#      57     if isinstance(df, pd.DataFrame):
# ---> 58         id_counts = df[id_col].value_counts(sort=False, dropna=True)
#      59         ids = id_counts.index
#      60         if isinstance(ids.dtype, pd.CategoricalDtype):
#      61             # there's no observed argument in value_counts
#      62             # so this can return unseen categories
#
# File ~/experiments/.venv/lib/python3.12/site-packages/pandas/core/base.py:1010, in IndexOpsMixin.value_counts(self, normalize, sort, ascending, bins, dropna)
#     923 @final
#     924 def value_counts(
#     925     self,
#    (...)    930     dropna: bool = True,
#     931 ) -> Series:
#     932     """
#     933     Return a Series containing counts of unique values.
#     934
#    (...)   1008     Name: count, dtype: int64
#    1009     """
# -> 1010     return algorithms.value_counts_internal(
#    1011         self,
#    1012         sort=sort,
#    1013         ascending=ascending,
#    1014         normalize=normalize,
#    1015         bins=bins,
#    1016         dropna=dropna,
#    1017     )
#
# File ~/experiments/.venv/lib/python3.12/site-packages/pandas/core/algorithms.py:933, in value_counts_internal(values, sort, ascending, normalize, bins, dropna)
#     929     keys = keys.astype(np.float32)
#     931 # For backwards compatibility, we let Index do its normal type
#     932 #  inference, _except_ for if if infers from object to bool.
# --> 933 idx = Index(keys)
#     934 if idx.dtype == bool and keys.dtype == object:
#     935     idx = idx.astype(object)
#
# File ~/experiments/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:507, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     503     # error: Incompatible return value type (got "MultiIndex",
#     504     # expected "Self")
#     505     return result  # type: ignore[return-value]
# --> 507 elif is_ea_or_datetimelike_dtype(dtype):
#     508     # non-EA dtype indexes have special casting logic, so we punt here
#     509     pass
#     511 elif is_ea_or_datetimelike_dtype(data_dtype):
#
# File ~/experiments/.venv/lib/python3.12/site-packages/pandas/core/dtypes/common.py:1339, in is_ea_or_datetimelike_dtype(dtype)
#    1331 def is_ea_or_datetimelike_dtype(dtype: DtypeObj | None) -> bool:
#    1332     """
#    1333     Check for ExtensionDtype, datetime64 dtype, or timedelta64 dtype.
#    1334
#    (...)   1337     Checks only for dtype objects, not dtype-castable strings or types.
#    1338     """
# -> 1339     return isinstance(dtype, ExtensionDtype) or (lib.is_np_dtype(dtype, "mM"))
#
# KeyboardInterrupt:
