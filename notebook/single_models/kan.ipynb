# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = KAN

experiment_id = 'chamados'
model_name = 'kanval'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 8297
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# masamu.txt
# Seed set to 2733
# Seed set to 8812
# Seed set to 7123
# Seed set to 1339
# Seed set to 6549
# Seed set to 6833
# Seed set to 505
# Seed set to 1128
# Seed set to 9911
# Seed set to 4982
# Seed set to 6831
# Seed set to 7647
# Seed set to 7162
# Seed set to 1368
# Seed set to 6370
# Seed set to 3121
# Seed set to 3875
# Seed set to 2299
# Seed set to 4674
# Seed set to 2281
# Seed set to 364
# Seed set to 3573
# Seed set to 6934
# Seed set to 1415
# Seed set to 6172
# Seed set to 7807
# Seed set to 1461
# Seed set to 1754
# Seed set to 3494
# Seed set to 3584
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 3494, 'input_size': 7, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 5933
# Seed set to 1594
# Seed set to 6928
# Seed set to 9681
# Seed set to 8011
# Seed set to 436
# Seed set to 686
# Seed set to 5263
# Seed set to 1836
# Seed set to 5579
# marecacc.txt
# Seed set to 9176
# Seed set to 7685
# Seed set to 6132
# Seed set to 7860
# Seed set to 6025
# Seed set to 5686
# Seed set to 3790
# Seed set to 7721
# Seed set to 151
# Seed set to 9212
# Seed set to 266
# Seed set to 8197
# Seed set to 979
# Seed set to 3332
# Seed set to 1146
# Seed set to 9011
# Seed set to 241
# Seed set to 7045
# Seed set to 1564
# Seed set to 8226
# Seed set to 9893
# Seed set to 3407
# Seed set to 4506
# Seed set to 2203
# Seed set to 286
# Seed set to 1055
# Seed set to 1511
# Seed set to 2192
# Seed set to 605
# Seed set to 6741
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 605, 'input_size': 7, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 1805
# Seed set to 7097
# Seed set to 2480
# Seed set to 8610
# Seed set to 1933
# Seed set to 3628
# Seed set to 9795
# Seed set to 8652
# Seed set to 1437
