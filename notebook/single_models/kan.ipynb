# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

# %%
model = KAN

experiment_id = 'pertexps'
model_name = 'kan'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    "lag_size": None
}

model_parameters = {
    'scaler_type': ['robust'],
    'loss': [DistributionLoss(distribution='StudentT', level=[80, 90], return_params=True)],
    'max_steps': [100],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# coloradoRiver.txt
# Seed set to 4126
# Seed set to 7526
# Seed set to 9276
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/experiments/.venv/lib/python3.10/site-packages/tensorboardX/record_writer.py:47, in directory_check(path)
#      46 prefix = path.split(':')[0]
# ---> 47 factory = REGISTERED_FACTORIES[prefix]
#      48 return factory.directory_check(path)
#
# KeyError: '/home/domingossj/experiments/notebook/single_models/lightning_logs/version_52546'
#
# During handling of the above exception, another exception occurred:
#
# FileExistsError                           Traceback (most recent call last)
# Cell In[2], line 22
#       9 experiment_params = {
#      10     'diff_kpss': True,
#      11     "lag_size": None
#      12 }
#      14 model_parameters = {
#      15     'scaler_type': ['robust'],
#      16     'loss': [DistributionLoss(distribution='StudentT', level=[80, 90], return_params=True)],
#    (...)
#      19     'enable_model_summary': [False],
#      20 }
# ---> 22 grid_search_exp.grid_seach_multiple_bases(
#      23      neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
#      24      model_exec, model_name, experiment_id, force = force
#      25 )
#
# File ~/experiments/src/model/grid_search_exp.py:152, in grid_seach_multiple_bases(fit_predict_class, model, normalize, model_parameters, experiment_params, model_exec, model_name, experiment_id, force)
#     137     continue
#     139 exec_gs = GridSearch(
#     140     fit_predict_class,
#     141     model,
#    (...)
#     149     model_exec = model_exec
#     150 )
# --> 152 exec_gs.execution()
#
# File ~/experiments/src/model/grid_search_exp.py:93, in GridSearch.execution(self)
#      91 def execution(self):
# ---> 93     best_exec_val, best_params = self._search_params()
#      95     experiment_params = self.experiment_params.copy()
#      96     experiment_params['test_size'] = config.TEST_SIZE
#
# File ~/experiments/src/model/grid_search_exp.py:79, in GridSearch._search_params(self)
#      67     model_actual = clone(self.model).set_params(** params)
#      69 model_exp = self.model_class_exp(
#      70     model_actual,
#      71     self.experiment_id,
#    (...)
#      76     experiment_params
#      77 )
# ---> 79 model_exp.fit_predict()
#      80 metrics_results = model_exp.metrics_results
#      81 exec_list_metrics.append(
#      82     metrics_results.get(self.group_metrics_name, {self.metric: np.inf})[self.metric]
#      83 )
#
# File ~/experiments/src/model/neural_forecast_exp.py:88, in NeuralForecastExp.fit_predict(self)
#      83 train_predict = fcst.predict_insample(step_size=1)[model_name]
#      85 for i in range(df_prev.shape[0]):
#      86     # Prevemos o próximo ponto
#      87     # O Nixtla usa o final do DataFrame fornecido para gerar a previsão
# ---> 88     forecast = fcst.predict(df=current_train)
#      89     test_prevs.append(forecast[model_name].iloc[params['h'] -1])
#      91     # "Update": Adicionamos a linha real do teste ao DataFrame de treino
#
# File ~/experiments/.venv/lib/python3.10/site-packages/neuralforecast/core.py:960, in NeuralForecast.predict(self, df, static_df, futr_df, verbose, engine, level, quantiles, h, **data_kwargs)
#     957 self._scalers_transform(futr_dataset)
#     958 dataset = dataset.append(futr_dataset)
# --> 960 fcsts, cols = self._generate_forecasts(
#     961     dataset=dataset,
#     962     uids=uids,
#     963     quantiles_=quantiles_,
#     964     level_=level_,
#     965     has_level=has_level,
#     966     h=h,
#     967     **data_kwargs,
#     968 )
#     970 if self.scalers_:
#     971     indptr = np.append(0, np.full(len(uids), h).cumsum())
#
# File ~/experiments/.venv/lib/python3.10/site-packages/neuralforecast/core.py:2060, in NeuralForecast._generate_forecasts(self, dataset, uids, h, quantiles_, level_, has_level, **data_kwargs)
#    2057     cols.extend([model_name] + out_cols)
#    2058 # base case: quantiles or levels are not supported or provided as arguments
#    2059 else:
# -> 2060     model_fcsts = model.predict(dataset=dataset, h=h, **data_kwargs)
#    2061     fcsts_list.append(model_fcsts)
#    2062     cols.extend(model_name + n for n in model.loss.output_names)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/neuralforecast/common/_base_model.py:2051, in BaseModel.predict(self, dataset, test_size, step_size, random_seed, quantiles, h, explainer_config, **data_module_kwargs)
#    2049 else:
#    2050     trainer = pl.Trainer(**pred_trainer_kwargs)
# -> 2051     fcsts = trainer.predict(self, datamodule=datamodule)
#    2052     fcsts = torch.vstack(fcsts)
#    2053     self.explanations = None
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:941, in Trainer.predict(self, model, dataloaders, datamodule, return_predictions, ckpt_path, weights_only)
#     939 self.state.status = TrainerStatus.RUNNING
#     940 self.predicting = True
# --> 941 return call._call_and_handle_interrupt(
#     942     self,
#     943     self._predict_impl,
#     944     model,
#     945     dataloaders,
#     946     datamodule,
#     947     return_predictions,
#     948     ckpt_path,
#     949     weights_only,
#     950 )
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47     if trainer.strategy.launcher is not None:
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#      52     _call_teardown_hook(trainer)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:990, in Trainer._predict_impl(self, model, dataloaders, datamodule, return_predictions, ckpt_path, weights_only)
#     986     download_model_from_registry(ckpt_path, self)
#     987 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     988     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     989 )
# --> 990 results = self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     992 assert self.state.stopped
#     993 self.predicting = False
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1039, in Trainer._run(self, model, ckpt_path, weights_only)
#    1036 log.debug(f"{self.__class__.__name__}: preparing data")
#    1037 self._data_connector.prepare_data()
# -> 1039 call._call_setup_hook(self)  # allow user to set up LightningModule in accelerator environment
#    1040 log.debug(f"{self.__class__.__name__}: configuring model")
#    1041 call._call_configure_model(self)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:102, in _call_setup_hook(trainer)
#     100 # Trigger lazy creation of experiment in loggers so loggers have their metadata available
#     101 for logger in loggers:
# --> 102     if hasattr(logger, "experiment"):
#     103         _ = logger.experiment
#     105 trainer.strategy.barrier("pre_setup")
#
# File ~/experiments/.venv/lib/python3.10/site-packages/lightning_fabric/loggers/logger.py:118, in rank_zero_experiment.<locals>.experiment(self)
#     116 if rank_zero_only.rank > 0:
#     117     return _DummyExperiment()
# --> 118 return fn(self)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/lightning_fabric/loggers/tensorboard.py:195, in TensorBoardLogger.experiment(self)
#     192 else:
#     193     from tensorboardX import SummaryWriter  # type: ignore[no-redef]
# --> 195 self._experiment = SummaryWriter(log_dir=self.log_dir, **self._kwargs)
#     196 return self._experiment
#
# File ~/experiments/.venv/lib/python3.10/site-packages/tensorboardX/writer.py:344, in SummaryWriter.__init__(self, logdir, comment, purge_step, max_queue, flush_secs, filename_suffix, write_to_disk, log_dir, comet_config, **kwargs)
#     341 # Initialize the file writers, but they can be cleared out on close
#     342 # and recreated later as needed.
#     343 self.file_writer = self.all_writers = None
# --> 344 self._get_file_writer()
#     346 # Create default bins for histograms, see generate_testdata.py in tensorflow/tensorboard
#     347 v = 1E-12
#
# File ~/experiments/.venv/lib/python3.10/site-packages/tensorboardX/writer.py:378, in SummaryWriter._get_file_writer(self)
#     375     return self.file_writer
#     377 if self.all_writers is None or self.file_writer is None:
# --> 378     self.file_writer = FileWriter(logdir=self.logdir,
#     379                                   max_queue=self._max_queue,
#     380                                   flush_secs=self._flush_secs,
#     381                                   filename_suffix=self._filename_suffix,
#     382                                   **self.kwargs)
#     383     if self.purge_step is not None:
#     384         self.file_writer.add_event(
#     385             Event(step=self.purge_step, file_version='brain.Event:2'))
#
# File ~/experiments/.venv/lib/python3.10/site-packages/tensorboardX/writer.py:118, in FileWriter.__init__(self, logdir, max_queue, flush_secs, filename_suffix)
#     113 # Sometimes PosixPath is passed in and we need to coerce it to
#     114 # a string in all cases
#     115 # TODO: See if we can remove this in the future if we are
#     116 # actually the ones passing in a PosixPath
#     117 logdir = str(logdir)
# --> 118 self.event_writer = EventFileWriter(
#     119     logdir, max_queue, flush_secs, filename_suffix)
#     121 def cleanup():
#     122     self.event_writer.close()
#
# File ~/experiments/.venv/lib/python3.10/site-packages/tensorboardX/event_file_writer.py:101, in EventFileWriter.__init__(self, logdir, max_queue_size, flush_secs, filename_suffix)
#      86 """Creates a `EventFileWriter` and an event file to write to.
#      87
#      88 On construction the summary writer creates a new event file in `logdir`.
#    (...)
#      98     pending events and summaries to disk.
#      99 """
#     100 self._logdir = logdir
# --> 101 directory_check(self._logdir)
#     102 self._event_queue = multiprocessing.Queue(max_queue_size)
#     103 self._ev_writer = EventsWriter(os.path.join(
#     104     self._logdir, "events"), filename_suffix)
#
# File ~/experiments/.venv/lib/python3.10/site-packages/tensorboardX/record_writer.py:51, in directory_check(path)
#      49 except KeyError:
#      50     if not os.path.exists(path):
# ---> 51         os.makedirs(path)
#
# File /usr/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: '/home/domingossj/experiments/notebook/single_models/lightning_logs/version_52546'
