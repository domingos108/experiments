# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_marima_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'marima'
experiment_id = 'consumoenergia'

# %%
for base_name in base_name_list:
    print(base_name)
    
    exec_marima_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'])
# Out:
# consumocoformated.txt
# MA SELECTED 2
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2638.144, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2588.881, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2640.694, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2485.888, Time=0.11 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2487.647, Time=0.34 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2486.436, Time=0.55 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=2490.251, Time=0.11 sec
#
# Best model:  ARIMA(2,1,0)(0,0,0)[0] intercept
# Total fit time: 3.240 seconds
# consumoneformated.txt
# MA SELECTED 2
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2926.782, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2900.313, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2928.161, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2878.238, Time=0.04 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2880.152, Time=0.24 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2862.119, Time=0.44 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.99 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2874.054, Time=0.21 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0] intercept
# Total fit time: 4.498 seconds
# consumonoformated.txt
# MA SELECTED 2
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2560.718, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2493.629, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2564.082, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2482.848, Time=0.12 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2483.648, Time=0.20 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2455.425, Time=0.33 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2467.521, Time=0.17 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0] intercept
# Total fit time: 3.835 seconds
# consumosdformated.txt
# MA SELECTED 6
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2798.054, Time=0.79 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3042.887, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2872.831, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2922.832, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3048.008, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2855.167, Time=0.57 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=2811.137, Time=1.17 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2808.802, Time=1.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2872.841, Time=0.39 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2829.807, Time=1.00 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2823.427, Time=0.47 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=2815.247, Time=1.17 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2800.684, Time=0.29 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 7.796 seconds
# consumosulformated.txt
# MA SELECTED 2
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2862.658, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3122.351, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3035.815, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2918.138, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3121.518, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2902.515, Time=0.51 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.85 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.17 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2906.776, Time=0.35 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2880.114, Time=0.96 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2902.678, Time=0.96 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=2886.574, Time=1.32 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2874.127, Time=0.68 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 7.890 seconds
