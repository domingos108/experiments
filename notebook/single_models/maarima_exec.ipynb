# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_marima_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_name_list = config.BASE_NAME_LIST
model_name = 'marima'
experiment_id = 'consumoenergia'

# %%
for base_name in base_name_list:
    print(base_name)
    
    exec_marima_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'])
# Out:
# consumocoformated.txt
# MA SELECTED 11
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=2698.537, Time=0.16 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=2761.898, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=2762.292, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=2760.839, Time=0.01 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=2710.562, Time=0.06 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=2727.350, Time=0.03 sec
#  ARIMA(3,2,2)(0,0,0)[0]             : AIC=2677.259, Time=0.19 sec
#  ARIMA(3,2,1)(0,0,0)[0]             : AIC=2727.361, Time=0.04 sec
#  ARIMA(4,2,2)(0,0,0)[0]             : AIC=inf, Time=0.19 sec
#  ARIMA(3,2,3)(0,0,0)[0]             : AIC=2700.966, Time=0.08 sec
#  ARIMA(2,2,3)(0,0,0)[0]             : AIC=inf, Time=0.21 sec
#  ARIMA(4,2,1)(0,0,0)[0]             : AIC=2715.922, Time=0.05 sec
#  ARIMA(4,2,3)(0,0,0)[0]             : AIC=inf, Time=0.28 sec
# ...
