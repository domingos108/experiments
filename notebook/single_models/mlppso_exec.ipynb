# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model import single_ml_model_exp, grid_search_exp, mlp_pso

import config
# %load_ext autoreload
# %autoreload 2
for hidden_layer_sizes in [10, 20, 50, 100]:
    for n_epocas_ft in [10, 20, 30]:
        for horizon in [1, 12, 24]:

            model = mlp_pso.PSOMlpRegressor()
            
            experiment_id = 'hourwindspeed'
            model_name = f'mlppso{n_epocas_ft}{hidden_layer_sizes}'
            normalize = True
            force = False
            model_exec = 10
            
            experiment_params = {
                'diff_kpss': False,
                'horizon': 12,
                'type_filter': None
            }
            
            model_parameters = {
                'hidden_layer_sizes': [(hidden_layer_sizes,)], 
                'n_epocas_ft': [n_epocas_ft],
            }
            
            grid_search_exp.grid_seach_multiple_bases(
                 single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
                 model_exec, model_name, experiment_id, force = force
            )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcaruaruhour.txt
# windspeedcastelodopiauihour.txt
# windspeedmaceiohour.txt
# windspeedsalvadorhour.txt
# windspeedcaruaruhour.txt
# windspeedcastelodopiauihour.txt
# windspeedmaceiohour.txt
# windspeedsalvadorhour.txt
# windspeedcaruaruhour.txt
# windspeedcastelodopiauihour.txt
# windspeedmaceiohour.txt
# windspeedsalvadorhour.txt
# windspeedcaruaruhour.txt
# windspeedcastelodopiauihour.txt
# windspeedmaceiohour.txt
# windspeedsalvadorhour.txt
# windspeedcaruaruhour.txt
# windspeedcastelodopiauihour.txt
# windspeedmaceiohour.txt
# windspeedsalvadorhour.txt
# windspeedcaruaruhour.txt
# windspeedcastelodopiauihour.txt
# windspeedmaceiohour.txt
# windspeedsalvadorhour.txt
# windspeedcaruaruhour.txt
# windspeedcastelodopiauihour.txt
# windspeedmaceiohour.txt
# windspeedsalvadorhour.txt
# windspeedcaruaruhour.txt
# windspeedcastelodopiauihour.txt
# windspeedmaceiohour.txt
# ...
