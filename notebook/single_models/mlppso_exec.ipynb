# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model import single_ml_model_exp, grid_search_exp, mlp_pso

import config
# %load_ext autoreload
# %autoreload 2
for hidden_layer_sizes in [10, 20, 50]:
    for n_epocas_ft in [5, 10, 20]:
        for horizon in [1]:

            model = mlp_pso.PSOMlpRegressor(sigma_share = 13, use_fine_tuning = True, use_fitness_sharing=True, pop_size = 100)
            
            experiment_id = 'multiplebases'
            model_name = f'mpfs{n_epocas_ft}{hidden_layer_sizes}'
            normalize = True
            force = False
            model_exec = 10
            
            experiment_params = {
                'diff_kpss': False,
                'horizon': horizon,
                'type_filter': None
            }
            
            model_parameters = {
                'hidden_layer_sizes': [(hidden_layer_sizes,)], 
                'n_epocas_ft': [n_epocas_ft],
            }
            
            grid_search_exp.grid_seach_multiple_bases(
                 single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
                 model_exec, model_name, experiment_id, force = force
            )
# Out:
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# ...

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.models import NHITS
from neuralforecast.losses.pytorch import RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = NHITS

experiment_id = 'multiplebases'
model_name = 'nhits'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'loss': [RMSE()],
    'n_freq_downsample': [[2, 1, 1]],
    'scaler_type': ['minmax'],
    'max_steps': [200],
    #'activation': ['Sigmoid'],
    'inference_windows_batch_size': [1],
    'val_check_steps': [10],
    'learning_rate': [0.001],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
    'mlp_units':[
        [[50, 50], [50, 50], [50, 50]],
        [[20, 20], [20, 20], [20, 20]],
        [[10, 10], [10, 10], [10, 10]],

    ]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)#l9:58
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# sunspot.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 2473
# Seed set to 5160
# Seed set to 6068
# Seed set to 9648
# Seed set to 6842
# Seed set to 8027
# Seed set to 2870
# Seed set to 4734
# Seed set to 7513
# Seed set to 5929
#  33%|████████████████████████████▎                                                        | 1/3 [01:14<02:28, 74.35s/it]Seed set to 4795
# Seed set to 4408
# Seed set to 1493
# Seed set to 8857
# Seed set to 5613
# Seed set to 4828
# Seed set to 101
# Seed set to 7444
# Seed set to 5807
# Seed set to 4712
#  67%|████████████████████████████████████████████████████████▋                            | 2/3 [02:14<01:06, 66.28s/it]Seed set to 6283
# Seed set to 3638
# Seed set to 555
# Seed set to 6817
# Seed set to 4925
# Seed set to 3836
# Seed set to 1578
# Seed set to 9848
# ...

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.losses.pytorch import RMSE

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = KAN

experiment_id = 'multiplebases'
model_name = 'kan'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# sunspot.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 5287
# Seed set to 8971
# Seed set to 6371
# Seed set to 371
# Seed set to 7729
# Seed set to 5536
# Seed set to 8604
# Seed set to 3094
# Seed set to 3163
# Seed set to 4099
#  33%|████████████████████████████▎                                                        | 1/3 [01:09<02:19, 69.92s/it]Seed set to 9971
# Seed set to 3443
# Seed set to 586
# Seed set to 6732
# Seed set to 7042
# Seed set to 1477
# Seed set to 497
# Seed set to 3596
# Seed set to 2133
# Seed set to 6292
#  67%|████████████████████████████████████████████████████████▋                            | 2/3 [02:53<01:29, 89.60s/it]Seed set to 5483
# Seed set to 6506
# Seed set to 2634
# Seed set to 4565
# Seed set to 1186
# Seed set to 8839
# Seed set to 2740
# Seed set to 7906
# ...

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.losses.pytorch import RMSE

from neuralforecast.models import TCN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = TCN

experiment_id = 'multiplebases'
model_name = 'tcn'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'loss': [RMSE()],
    'learning_rate': [5e-4],
    'max_steps': [500],
    'kernel_size': [2],
    'dilations':[[1,2,4,8,16]],
    'context_size': [10],
    'decoder_hidden_size': [128],
    'encoder_hidden_size': [128],
    'decoder_layers': [2]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 6428
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# sunspot.txt
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax'}
# Seed set to 9644
# Seed set to 2853
# Seed set to 3126
# Seed set to 7103
# Seed set to 116
# Seed set to 6897
# Seed set to 7208
# Seed set to 4133
# Seed set to 7516
# Seed set to 8374
# austres.txt
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax'}
# Seed set to 7104
# Seed set to 2157
# Seed set to 1944
# Seed set to 3253
# Seed set to 2843
# Seed set to 1245
# Seed set to 2863
# Seed set to 5899
# Seed set to 1899
# Seed set to 894
# heartrate.txt
# ...

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model import single_ml_model_exp, grid_search_exp, mlp_pso

import config
# %load_ext autoreload
# %autoreload 2
for hidden_layer_sizes in [10, 20, 50]:
    for n_epocas_ft in [5, 10, 20]:
        for horizon in [1]:

            model = mlp_pso.PSOMlpRegressor(sigma_share = 13, use_fine_tuning = True, use_fitness_sharing=True, pop_size = 50)
            
            experiment_id = 'multiplebases'
            model_name = f'mpfs50{n_epocas_ft}{hidden_layer_sizes}'
            normalize = True
            force = False
            model_exec = 10
            
            experiment_params = {
                'diff_kpss': False,
                'horizon': horizon,
                'type_filter': None
            }
            
            model_parameters = {
                'hidden_layer_sizes': [(hidden_layer_sizes,)], 
                'n_epocas_ft': [n_epocas_ft],
            }
            
            grid_search_exp.grid_seach_multiple_bases(
                 single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
                 model_exec, model_name, experiment_id, force = force
            )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# sunspot.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 5}
# austres.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 5}
# heartrate.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 5}
# ozon.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 5}
# pollution.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 5}
# redwine.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 5}
# gasoline.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 5}
# temperature.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 5}
# sunspot.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 10}
# austres.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 10}
# heartrate.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 10}
# ozon.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 10}
# pollution.txt
# {'hidden_layer_sizes': (10,), 'n_epocas_ft': 10}
# redwine.txt
# ...
