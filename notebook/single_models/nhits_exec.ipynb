# %%
from sklearn.base import clone

from model import generics
from model.arima import exec_training_testing
from input import input
import config

# %load_ext autoreload
# %autoreload 2

base_name_list = config.BASE_NAME_LIST
model_name = 'arima'
experiment_id = 'hourwindspeed'
horizon = 1
force= True
           
for base_name in base_name_list:
    print(base_name)    
    exec_training_testing(base_name, experiment_id, model_name, config.BASE_INFORMATION[base_name]['m'], horizon, force)
# Out:
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:14: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 1.23.2)
#   from scipy.sparse import csr_matrix, issparse
# windspeedcaruaruhour.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.72 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16194.492, Time=0.37 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=15417.911, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=15156.868, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16192.492, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=14869.634, Time=1.37 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=14690.776, Time=2.32 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=15253.459, Time=0.26 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=14686.618, Time=2.13 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=15180.549, Time=0.31 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=14678.081, Time=2.22 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=15136.806, Time=0.38 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=14684.886, Time=3.58 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=14680.938, Time=3.25 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=14686.757, Time=1.89 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=15117.658, Time=0.52 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=14679.558, Time=3.62 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=14676.021, Time=0.89 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=14675.325, Time=0.73 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=14688.789, Time=0.51 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=15178.550, Time=0.19 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=14683.690, Time=0.92 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=15251.459, Time=0.16 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=inf, Time=0.81 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=15134.807, Time=0.24 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=14678.467, Time=1.20 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 30.201 seconds
# windspeedcastelodopiauihour.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=11661.965, Time=1.99 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12494.161, Time=0.22 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12171.252, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12116.502, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12492.162, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.73 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=1.70 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.38 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=2.97 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=11659.609, Time=1.92 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=12094.492, Time=0.51 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=12119.842, Time=0.25 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=11657.706, Time=0.49 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=12114.504, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=12169.253, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=0.68 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=0.72 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=12092.494, Time=0.23 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=12117.844, Time=0.14 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=11653.382, Time=0.92 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=inf, Time=1.03 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=inf, Time=1.06 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=11585.327, Time=0.94 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=12081.322, Time=0.26 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=11577.981, Time=1.25 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=12041.885, Time=0.55 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=11578.732, Time=1.77 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=11577.027, Time=1.53 sec
#  ARIMA(0,1,5)(0,0,0)[0]             : AIC=11874.685, Time=0.95 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=inf, Time=2.26 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=11648.295, Time=4.12 sec
#
# Best model:  ARIMA(1,1,5)(0,0,0)[0]
# Total fit time: 33.273 seconds
# windspeedmaceiohour.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=16929.682, Time=1.31 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=17073.814, Time=0.27 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16985.302, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=16995.194, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=17071.815, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=16943.056, Time=0.90 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=16955.002, Time=1.02 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=16829.106, Time=2.08 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=16946.910, Time=1.55 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=16833.855, Time=2.86 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=16912.293, Time=3.24 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=16888.400, Time=3.37 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=16945.012, Time=1.93 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=3.78 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=inf, Time=1.06 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0] intercept
# Total fit time: 23.928 seconds
# windspeedsalvadorhour.txt
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4711.445, Time=2.16 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5877.680, Time=0.24 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5068.552, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4787.015, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5875.681, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4493.227, Time=1.51 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=4760.891, Time=0.71 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4755.082, Time=0.82 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=4709.146, Time=2.74 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=4756.887, Time=1.00 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=4543.393, Time=1.83 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=4601.558, Time=2.26 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=4490.343, Time=0.68 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=4758.894, Time=0.21 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=4753.085, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=4573.121, Time=0.88 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=4521.801, Time=0.86 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=4785.017, Time=0.17 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=4754.890, Time=0.33 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=4541.394, Time=0.63 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=4494.250, Time=1.25 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 19.178 seconds

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.models import NHITS
from neuralforecast.losses.pytorch import RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = NHITS

experiment_id = 'hourwindspeed'
model_name = 'nhits'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'loss': [RMSE()],
    'n_freq_downsample': [[2, 1, 1]],
    'scaler_type': ['minmax'],
    'max_steps': [200],
    #'activation': ['Sigmoid'],
    'inference_windows_batch_size': [1],
    'val_check_steps': [10],
    'learning_rate': [0.001],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
    'mlp_units':[
        [[50, 50], [50, 50], [50, 50]],
        [[20, 20], [20, 20], [20, 20]],
        [[10, 10], [10, 10], [10, 10]],

    ]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)#l9:58
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcaruaruhour.txt
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Seed set to 1880
# Seed set to 4551
# Seed set to 4379
# Seed set to 7183
# Seed set to 8296
# Seed set to 7691
# Seed set to 8556
# Seed set to 9943
# Seed set to 5796
# Seed set to 3415
#  33%|██████████████▋                             | 1/3 [05:01<10:03, 301.66s/it]Seed set to 1548
# Seed set to 531
# Seed set to 6689
# Seed set to 6630
# Seed set to 7967
# Seed set to 1990
# Seed set to 5290
# Seed set to 6801
# Seed set to 986
# Seed set to 3322
#  67%|█████████████████████████████▎              | 2/3 [10:06<05:03, 303.40s/it]Seed set to 3361
# Seed set to 2189
# Seed set to 9460
# Seed set to 1511
# Seed set to 2460
# Seed set to 5125
# Seed set to 7389
# Seed set to 3943
# Seed set to 2639
# Seed set to 510
# 100%|████████████████████████████████████████████| 3/3 [14:55<00:00, 298.55s/it]
# Seed set to 597
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 3415, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 5871
# Seed set to 5906
# Seed set to 5378
# Seed set to 530
# Seed set to 2380
# Seed set to 6468
# Seed set to 1664
# Seed set to 4567
# Seed set to 6541
# windspeedcastelodopiauihour.txt
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Seed set to 4967
# Seed set to 4298
# Seed set to 817
# Seed set to 8427
# Seed set to 1238
# Seed set to 1147
# Seed set to 6239
# Seed set to 8224
# Seed set to 1404
# Seed set to 5386
#  33%|██████████████▋                             | 1/3 [05:51<11:43, 351.89s/it]Seed set to 1648
# Seed set to 1935
# Seed set to 2476
# Seed set to 5894
# Seed set to 5797
# Seed set to 4591
# Seed set to 627
# Seed set to 9824
# Seed set to 7801
# Seed set to 7011
#  67%|█████████████████████████████▎              | 2/3 [10:55<05:23, 323.66s/it]Seed set to 9312
# Seed set to 3084
# Seed set to 9486
# Seed set to 6726
# Seed set to 6164
# Seed set to 5074
# Seed set to 4871
# Seed set to 5904
# Seed set to 5747
# Seed set to 1174
# 100%|████████████████████████████████████████████| 3/3 [15:51<00:00, 317.19s/it]
# Seed set to 6699
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 5386, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 8792
# Seed set to 8657
# Seed set to 3057
# Seed set to 3961
# Seed set to 1969
# Seed set to 9618
# Seed set to 5036
# Seed set to 519
# Seed set to 7507
# windspeedmaceiohour.txt
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Seed set to 8529
# Seed set to 4477
# Seed set to 1556
# Seed set to 1489
# Seed set to 3774
# Seed set to 8006
# Seed set to 3178
# Seed set to 2821
# Seed set to 1263
# Seed set to 5439
#  33%|██████████████▋                             | 1/3 [04:55<09:51, 295.78s/it]Seed set to 3029
# Seed set to 6852
# Seed set to 9493
# Seed set to 4256
# Seed set to 4543
# Seed set to 9418
# Seed set to 2978
# Seed set to 6977
# Seed set to 9131
# Seed set to 4128
#  67%|█████████████████████████████▎              | 2/3 [09:52<04:56, 296.43s/it]Seed set to 8879
# Seed set to 4470
# Seed set to 7393
# Seed set to 8808
# Seed set to 4191
# Seed set to 2259
# Seed set to 8403
# Seed set to 5865
# Seed set to 78
# Seed set to 6531
# 100%|████████████████████████████████████████████| 3/3 [15:10<00:00, 303.65s/it]
# Seed set to 9379
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 5439, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 2782
# Seed set to 5518
# Seed set to 2951
# Seed set to 479
# Seed set to 1611
# Seed set to 6938
# Seed set to 610
# Seed set to 3021
# Seed set to 6389
# windspeedsalvadorhour.txt
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Seed set to 4573
# Seed set to 8005
# Seed set to 2124
# Seed set to 8018
# Seed set to 271
# Seed set to 7173
# Seed set to 3514
# Seed set to 1871
# Seed set to 1081
# Seed set to 66
#  33%|██████████████▋                             | 1/3 [04:32<09:05, 272.96s/it]Seed set to 2027
# Seed set to 3384
# Seed set to 8212
# Seed set to 7389
# Seed set to 2659
# Seed set to 9917
# Seed set to 5362
# Seed set to 6504
# Seed set to 5648
# Seed set to 5706
#  67%|█████████████████████████████▎              | 2/3 [09:09<04:35, 275.32s/it]Seed set to 6795
# Seed set to 6598
# Seed set to 4341
# Seed set to 3939
# Seed set to 1268
# Seed set to 987
# Seed set to 3362
# Seed set to 6829
# Seed set to 3885
# Seed set to 2944
# 100%|████████████████████████████████████████████| 3/3 [13:55<00:00, 278.58s/it]
# Seed set to 5054
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 66, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 2725
# Seed set to 7157
# Seed set to 3288
# Seed set to 9874
# Seed set to 22
# Seed set to 6859
# Seed set to 3636
# Seed set to 2412
# Seed set to 3333

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.losses.pytorch import RMSE

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = KAN

experiment_id = 'hourwindspeed'
model_name = 'kan'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcaruaruhour.txt
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Seed set to 4228
# Seed set to 9616
# Seed set to 6104
# Seed set to 8115
# Seed set to 1845
# Seed set to 9632
# Seed set to 6308
# Seed set to 8740
# Seed set to 7908
# Seed set to 9133
#  33%|██████████████▋                             | 1/3 [04:34<09:08, 274.44s/it]Seed set to 5430
# Seed set to 6547
# Seed set to 120
# Seed set to 3678
# Seed set to 8268
# Seed set to 1378
# Seed set to 836
# Seed set to 9116
# Seed set to 5989
# Seed set to 8342
#  67%|█████████████████████████████▎              | 2/3 [09:22<04:42, 282.40s/it]Seed set to 6632
# Seed set to 9070
# Seed set to 533
# Seed set to 1707
# Seed set to 6027
# Seed set to 6998
# Seed set to 5748
# Seed set to 3684
# Seed set to 1592
# Seed set to 9099
# 100%|████████████████████████████████████████████| 3/3 [17:42<00:00, 354.01s/it]
# Seed set to 9944
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 9099, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 2753
# Seed set to 2996
# Seed set to 3579
# Seed set to 2327
# Seed set to 8219
# Seed set to 7314
# Seed set to 248
# Seed set to 3493
# Seed set to 975
# windspeedcastelodopiauihour.txt
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Seed set to 9593
# Seed set to 1407
# Seed set to 8309
# Seed set to 3961
# Seed set to 8990
# Seed set to 7599
# Seed set to 7694
# Seed set to 785
# Seed set to 6362
# Seed set to 9436
#  33%|██████████████▋                             | 1/3 [04:34<09:08, 274.04s/it]Seed set to 2219
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
#  67%|█████████████████████████████▎              | 2/3 [10:02<05:06, 306.30s/it]Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# 100%|████████████████████████████████████████████| 3/3 [18:40<00:00, 373.46s/it]
# Seed set to 6044
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 9928, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# windspeedmaceiohour.txt
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
#  33%|██████████████▋                             | 1/3 [04:29<08:59, 269.71s/it]Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
#  67%|█████████████████████████████▎              | 2/3 [10:08<05:10, 310.54s/it]Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# 100%|████████████████████████████████████████████| 3/3 [17:55<00:00, 358.38s/it]
# Seed set to 8761
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 6044, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# Seed set to 9928
# Seed set to 6044
# Seed set to 8761
# windspeedsalvadorhour.txt
#   0%|                                                     | 0/3 [00:00<?, ?it/s]Seed set to 9928
# Seed set to 4670
# Seed set to 731
# Seed set to 5291
# Seed set to 3041
# Seed set to 8699
# Seed set to 8102
# Seed set to 5257
# Seed set to 6523
# Seed set to 6630
#  33%|██████████████▋                             | 1/3 [04:19<08:39, 259.82s/it]Seed set to 5314
# Seed set to 8117
# Seed set to 9713
# Seed set to 8798
# Seed set to 5838
# Seed set to 7905
# Seed set to 8724
# Seed set to 6067
# Seed set to 8812
# Seed set to 1229
#  67%|█████████████████████████████▎              | 2/3 [09:25<04:46, 286.52s/it]Seed set to 4444
# Seed set to 805
# Seed set to 9830
# Seed set to 5522
# Seed set to 7534
# Seed set to 3196
# Seed set to 55
# Seed set to 1516
# Seed set to 8399
# Seed set to 3282
# 100%|████████████████████████████████████████████| 3/3 [17:01<00:00, 340.44s/it]
# Seed set to 1654
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 3282, 'input_size': 24, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 5721
# Seed set to 2115
# Seed set to 1025
# Seed set to 6703
# Seed set to 3183
# Seed set to 9682
# Seed set to 6539
# Seed set to 3493
# Seed set to 3550

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.losses.pytorch import RMSE

from neuralforecast.models import TCN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = TCN

experiment_id = 'hourwindspeed'
model_name = 'tcn'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'loss': [RMSE()],
    'learning_rate': [5e-4],
    'max_steps': [500],
    'kernel_size': [2],
    'dilations':[[1,2,4,8,16]],
    'context_size': [10],
    'decoder_hidden_size': [128],
    'encoder_hidden_size': [128],
    'decoder_layers': [2]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 6114
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcaruaruhour.txt
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax'}
# Seed set to 7021
# Seed set to 9744
# Seed set to 9862
# Seed set to 6144
# Seed set to 1097
# Seed set to 5059
# Seed set to 2932
# Seed set to 3095
# Seed set to 639
# Seed set to 82
# windspeedcastelodopiauihour.txt
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax'}
# Seed set to 9682
# Seed set to 3106
# Seed set to 609
# Seed set to 1501
# Seed set to 1487
# Seed set to 8570
# Seed set to 1100
# Seed set to 7442
# Seed set to 2552
# Seed set to 3120
# windspeedmaceiohour.txt
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax'}
# Seed set to 6781
# Seed set to 9912
# Seed set to 9482
# Seed set to 3284
# Seed set to 7284
# Seed set to 9245
# Seed set to 5136
# Seed set to 4959
# Seed set to 7717
# Seed set to 4678
# windspeedsalvadorhour.txt
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax'}
# Seed set to 3525
# Seed set to 3368
# Seed set to 9124
# Seed set to 7766
# Seed set to 1910
# Seed set to 8563
# Seed set to 2968
# Seed set to 8880
# Seed set to 5590
