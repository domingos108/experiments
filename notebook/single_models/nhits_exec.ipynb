# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.models import NHITS
from neuralforecast.losses.pytorch import RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = NHITS

experiment_id = 'hourwindspeed'
model_name = 'nhits'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 24
}

model_parameters = {
    'loss': [RMSE()],
    'n_freq_downsample': [[2, 1, 1]],
    'scaler_type': ['minmax'],
    'max_steps': [200],
    #'activation': ['Sigmoid'],
    'inference_windows_batch_size': [1],
    'val_check_steps': [10],
    'learning_rate': [0.001],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
    'mlp_units':[
        [[100, 100], [100, 100], [100, 100]],
        [[50, 50], [50, 50], [50, 50]],
        [[20, 20], [20, 20], [20, 20]],

    ]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)#l9:58
# Out:
# windspeedcampinagrandehour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 7979
# Seed set to 9692
# Seed set to 1256
# Seed set to 6861
# Seed set to 4611
# Seed set to 2892
# Seed set to 2363
# Seed set to 8790
# Seed set to 5281
# Seed set to 9385
#  33%|███████████████████████████                                                      | 1/3 [53:37<1:47:15, 3217.67s/it]Seed set to 7649
# Seed set to 7016
# Seed set to 7785
# Seed set to 5283
# Seed set to 8801
# Seed set to 3627
# Seed set to 3581
# Seed set to 3221
# Seed set to 2611
# Seed set to 8439
#  67%|██████████████████████████████████████████████████████                           | 2/3 [1:44:34<52:02, 3122.95s/it]Seed set to 8663
# Seed set to 4347
# Seed set to 2631
# Seed set to 2429
# Seed set to 616
# Seed set to 5831
# Seed set to 7107
# Seed set to 4547
# Seed set to 1423
# Seed set to 6213
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [2:28:05<00:00, 2961.84s/it]
# Seed set to 7960
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 24, 'random_seed': 9385, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 7306
# Seed set to 2746
# Seed set to 7553
# Seed set to 6765
# Seed set to 2431
# Seed set to 5014
# Seed set to 2012
# Seed set to 2259
# Seed set to 7076
# windspeedcaruaruhour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 4594
# Seed set to 8505
# Seed set to 9157
# Seed set to 7492
# Seed set to 9710
# Seed set to 1633
# Seed set to 3647
# Seed set to 5150
# Seed set to 7209
# Seed set to 7942
#  33%|███████████████████████████                                                      | 1/3 [53:19<1:46:39, 3199.91s/it]Seed set to 5732
# Seed set to 6828
# Seed set to 7019
# Seed set to 5608
# Seed set to 6777
# Seed set to 8237
# Seed set to 6368
# Seed set to 8329
# Seed set to 6305
# Seed set to 9425
#  67%|██████████████████████████████████████████████████████                           | 2/3 [1:45:30<52:38, 3158.98s/it]Seed set to 1999
# Seed set to 3783
# Seed set to 2299
# Seed set to 9593
# Seed set to 3856
# Seed set to 6624
# Seed set to 1476
# Seed set to 489
# Seed set to 7074
# Seed set to 3899
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [2:30:09<00:00, 3003.03s/it]
# Seed set to 7855
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 24, 'random_seed': 7942, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 7496
# Seed set to 5619
# Seed set to 3809
# Seed set to 6529
# Seed set to 1948
# Seed set to 3242
# Seed set to 7825
# Seed set to 2277
# Seed set to 5888
# windspeedcastelodopiauihour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 7398
# Seed set to 1403
# Seed set to 1697
# Seed set to 5435
# Seed set to 8193
# Seed set to 2356
# Seed set to 9686
# Seed set to 6055
# Seed set to 2523
# Seed set to 3204
#  33%|███████████████████████████                                                      | 1/3 [47:50<1:35:40, 2870.40s/it]Seed set to 4034
# Seed set to 6974
# Seed set to 9612
# Seed set to 8531
# Seed set to 2795
# Seed set to 3029
# Seed set to 2238
# Seed set to 1576
# Seed set to 8608
# Seed set to 464
#  67%|██████████████████████████████████████████████████████                           | 2/3 [1:15:39<36:03, 2163.57s/it]Seed set to 9768
# Seed set to 5957
# Seed set to 4920
# Seed set to 7296
# Seed set to 4341
# Seed set to 367
# Seed set to 1033
# Seed set to 7885
# Seed set to 3214
# Seed set to 4236
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [1:41:32<00:00, 2030.68s/it]
# Seed set to 2149
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 24, 'random_seed': 3204, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 9953
# Seed set to 6963
# Seed set to 7195
# Seed set to 6742
# Seed set to 7475
# Seed set to 424
# Seed set to 6314
# Seed set to 3721
# Seed set to 9911
# windspeedmaceiohour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 3453
# Seed set to 2624
# Seed set to 4224
# Seed set to 3190
# Seed set to 9386
# Seed set to 5261
# Seed set to 2745
# Seed set to 8212
# Seed set to 3493
# Seed set to 2396
#  33%|███████████████████████████▋                                                       | 1/3 [29:17<58:35, 1757.70s/it]Seed set to 8467
# Seed set to 2261
# Seed set to 302
# Seed set to 6316
# Seed set to 7113
# Seed set to 1177
# Seed set to 4895
# Seed set to 6021
# Seed set to 7200
# Seed set to 5391
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [58:03<28:58, 1738.98s/it]Seed set to 7112
# Seed set to 736
# Seed set to 1929
# Seed set to 9953
# Seed set to 6963
# Seed set to 7195
# Seed set to 6742
# Seed set to 7475
# Seed set to 424
# Seed set to 6314
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [1:26:55<00:00, 1738.60s/it]
# Seed set to 3721
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 24, 'random_seed': 2396, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 9911
# Seed set to 3453
# Seed set to 2624
# Seed set to 4224
# Seed set to 3190
# Seed set to 9386
# Seed set to 5261
# Seed set to 2745
# Seed set to 8212
# windspeedsalvadorhour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 3493
# Seed set to 719
# Seed set to 4070
# Seed set to 2262
# Seed set to 7588
# Seed set to 7809
# Seed set to 8930
# Seed set to 262
# Seed set to 3122
# Seed set to 3702
#  33%|███████████████████████████▋                                                       | 1/3 [28:05<56:11, 1685.53s/it]Seed set to 7768
# Seed set to 5451
# Seed set to 2265
# Seed set to 7841
# Seed set to 8109
# Seed set to 423
# Seed set to 5491
# Seed set to 1130
# Seed set to 4311
# Seed set to 2776
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [54:57<27:22, 1642.38s/it]Seed set to 9434
# Seed set to 1509
# Seed set to 5804
# Seed set to 8229
# Seed set to 455
# Seed set to 621
# Seed set to 5150
# Seed set to 6244
# Seed set to 4575
# Seed set to 6327
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [1:19:42<00:00, 1594.07s/it]
# Seed set to 4922
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 24, 'random_seed': 3702, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 7564
# Seed set to 1214
# Seed set to 6169
# Seed set to 8754
# Seed set to 7103
# Seed set to 7302
# Seed set to 8490
# Seed set to 9585
# Seed set to 4202

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.models import NHITS
from neuralforecast.losses.pytorch import RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = NHITS

experiment_id = 'hourwindspeed'
model_name = 'nhits'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 48
}

model_parameters = {
    'loss': [RMSE()],
    'n_freq_downsample': [[2, 1, 1]],
    'scaler_type': ['minmax'],
    'max_steps': [200],
    #'activation': ['Sigmoid'],
    'inference_windows_batch_size': [1],
    'val_check_steps': [10],
    'learning_rate': [0.001],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
    'mlp_units':[
        [[100, 100], [100, 100], [100, 100]],
        [[50, 50], [50, 50], [50, 50]],
        [[20, 20], [20, 20], [20, 20]],

    ]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)#l9:58
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcampinagrandehour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 6465
# Seed set to 8760
# Seed set to 1623
# Seed set to 5094
# Seed set to 3533
# Seed set to 3113
# Seed set to 6487
# Seed set to 3426
# Seed set to 3957
# Seed set to 9457
#  33%|███████████████████████████                                                      | 1/3 [30:10<1:00:21, 1810.67s/it]Seed set to 6370
# Seed set to 304
# Seed set to 187
# Seed set to 1456
# Seed set to 824
# Seed set to 2458
# Seed set to 7568
# Seed set to 3344
# Seed set to 8286
# Seed set to 7979
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [57:17<28:22, 1702.55s/it]Seed set to 6540
# Seed set to 1094
# Seed set to 1095
# Seed set to 5947
# Seed set to 3295
# Seed set to 8390
# Seed set to 5932
# Seed set to 9416
# Seed set to 3062
# Seed set to 4908
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [1:19:37<00:00, 1592.61s/it]
# Seed set to 5463
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 48, 'random_seed': 9457, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 7758
# Seed set to 6019
# Seed set to 3977
# Seed set to 163
# Seed set to 6954
# Seed set to 4020
# Seed set to 6602
# Seed set to 377
# Seed set to 2785
# windspeedcaruaruhour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 5144
# Seed set to 6278
# Seed set to 3304
# Seed set to 8
# Seed set to 8389
# Seed set to 9326
# Seed set to 4973
# Seed set to 4341
# Seed set to 7584
# Seed set to 6163
#  33%|███████████████████████████▋                                                       | 1/3 [19:39<39:18, 1179.40s/it]Seed set to 6321
# Seed set to 5706
# Seed set to 7170
# Seed set to 5264
# Seed set to 2679
# Seed set to 3160
# Seed set to 5850
# Seed set to 3856
# Seed set to 2772
# Seed set to 7424
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [39:02<19:29, 1169.67s/it]Seed set to 6704
# Seed set to 3150
# Seed set to 9260
# Seed set to 7967
# Seed set to 530
# Seed set to 1383
# Seed set to 5117
# Seed set to 1997
# Seed set to 5020
# Seed set to 1225
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [58:28<00:00, 1169.45s/it]
# Seed set to 7324
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 48, 'random_seed': 7424, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 5237
# Seed set to 5822
# Seed set to 136
# Seed set to 5575
# Seed set to 7043
# Seed set to 7723
# Seed set to 2883
# Seed set to 8862
# Seed set to 5509
# windspeedcastelodopiauihour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 5105
# Seed set to 1763
# Seed set to 3461
# Seed set to 8059
# Seed set to 2423
# Seed set to 4486
# Seed set to 309
# Seed set to 4011
# Seed set to 3408
# Seed set to 9392
#  33%|███████████████████████████▋                                                       | 1/3 [19:40<39:21, 1180.51s/it]Seed set to 8603
# Seed set to 2405
# Seed set to 8674
# Seed set to 1647
# Seed set to 5754
# Seed set to 8033
# Seed set to 6180
# Seed set to 7408
# Seed set to 9724
# Seed set to 8342
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [39:09<19:34, 1174.00s/it]Seed set to 3247
# Seed set to 2154
# Seed set to 6906
# Seed set to 1981
# Seed set to 2532
# Seed set to 9438
# Seed set to 7535
# Seed set to 4098
# Seed set to 4268
# Seed set to 9285
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [58:28<00:00, 1169.66s/it]
# Seed set to 9207
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 48, 'random_seed': 9392, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 3960
# Seed set to 7052
# Seed set to 2528
# Seed set to 4712
# Seed set to 4325
# Seed set to 4262
# Seed set to 2631
# Seed set to 1982
# Seed set to 3943
# windspeedmaceiohour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 8910
# Seed set to 7397
# Seed set to 9648
# Seed set to 678
# Seed set to 44
# Seed set to 8547
# Seed set to 8642
# Seed set to 7601
# Seed set to 4909
# Seed set to 4245
#  33%|███████████████████████████▋                                                       | 1/3 [19:44<39:28, 1184.24s/it]Seed set to 5339
# Seed set to 6284
# Seed set to 3441
# Seed set to 3402
# Seed set to 9528
# Seed set to 4680
# Seed set to 3442
# Seed set to 3331
# Seed set to 8575
# Seed set to 1257
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [39:07<19:32, 1172.06s/it]Seed set to 2900
# Seed set to 9165
# Seed set to 2100
# Seed set to 8709
# Seed set to 8023
# Seed set to 3676
# Seed set to 2482
# Seed set to 9349
# Seed set to 4867
# Seed set to 8483
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [58:21<00:00, 1167.04s/it]
# Seed set to 9145
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 48, 'random_seed': 4245, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 7860
# Seed set to 3041
# Seed set to 1042
# Seed set to 2850
# Seed set to 3615
# Seed set to 3007
# Seed set to 5838
# Seed set to 8627
# Seed set to 6346
# windspeedsalvadorhour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 4575
# Seed set to 2236
# Seed set to 9238
# Seed set to 3307
# Seed set to 3714
# Seed set to 5681
# Seed set to 3116
# Seed set to 6986
# Seed set to 2674
# Seed set to 4598
#  33%|███████████████████████████▋                                                       | 1/3 [18:37<37:15, 1117.84s/it]Seed set to 4106
# Seed set to 8505
# Seed set to 9606
# Seed set to 1265
# Seed set to 848
# Seed set to 1428
# Seed set to 2856
# Seed set to 9329
# Seed set to 1725
# Seed set to 2270
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [36:59<18:28, 1108.11s/it]Seed set to 5793
# Seed set to 5071
# Seed set to 4503
# Seed set to 4701
# Seed set to 8369
# Seed set to 8179
# Seed set to 864
# Seed set to 2815
# Seed set to 7349
# Seed set to 765
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [55:12<00:00, 1104.33s/it]
# Seed set to 7656
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 48, 'random_seed': 4598, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 3919
# Seed set to 3082
# Seed set to 6761
# Seed set to 4924
# Seed set to 6150
# Seed set to 5385
# Seed set to 1668
# Seed set to 7722
# Seed set to 8587

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
from neuralforecast.models import NHITS
from neuralforecast.losses.pytorch import RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = NHITS

experiment_id = 'hourwindspeed'
model_name = 'nhits'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 72
}

model_parameters = {
    'loss': [RMSE()],
    'n_freq_downsample': [[2, 1, 1]],
    'scaler_type': ['minmax'],
    'max_steps': [200],
    #'activation': ['Sigmoid'],
    'inference_windows_batch_size': [1],
    'val_check_steps': [10],
    'learning_rate': [0.001],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
    'mlp_units':[
        [[100, 100], [100, 100], [100, 100]],
        [[50, 50], [50, 50], [50, 50]],
        [[20, 20], [20, 20], [20, 20]],

    ]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)#l9:58
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcampinagrandehour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 1323
# Seed set to 2952
# Seed set to 863
# Seed set to 4184
# Seed set to 3257
# Seed set to 5273
# Seed set to 5945
# Seed set to 2962
# Seed set to 6051
# Seed set to 8911
#  33%|███████████████████████████▋                                                       | 1/3 [19:52<39:44, 1192.22s/it]Seed set to 347
# Seed set to 255
# Seed set to 6943
# Seed set to 6876
# Seed set to 5590
# Seed set to 7932
# Seed set to 8971
# Seed set to 6448
# Seed set to 7187
# Seed set to 9608
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [39:31<19:44, 1184.71s/it]Seed set to 6042
# Seed set to 9545
# Seed set to 2065
# Seed set to 7191
# Seed set to 5586
# Seed set to 8368
# Seed set to 2655
# Seed set to 7072
# Seed set to 5243
# Seed set to 2385
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [59:17<00:00, 1185.76s/it]
# Seed set to 8533
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 72, 'random_seed': 8911, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 7071
# Seed set to 1062
# Seed set to 5162
# Seed set to 3510
# Seed set to 2429
# Seed set to 801
# Seed set to 4358
# Seed set to 3274
# Seed set to 2588
# windspeedcaruaruhour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 9749
# Seed set to 3355
# Seed set to 3089
# Seed set to 9742
# Seed set to 2169
# Seed set to 4041
# Seed set to 9296
# Seed set to 7070
# Seed set to 1181
# Seed set to 360
#  33%|███████████████████████████▋                                                       | 1/3 [19:49<39:38, 1189.32s/it]Seed set to 5019
# Seed set to 483
# Seed set to 4794
# Seed set to 9406
# Seed set to 7895
# Seed set to 7898
# Seed set to 6414
# Seed set to 8583
# Seed set to 3462
# Seed set to 3785
#  67%|██████████████████████████████████████████████████████                           | 2/3 [1:06:12<35:26, 2126.95s/it]Seed set to 8367
# Seed set to 2587
# Seed set to 2654
# Seed set to 7096
# Seed set to 9925
# Seed set to 2099
# Seed set to 7822
# Seed set to 52
# Seed set to 5459
# Seed set to 5114
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [1:47:43<00:00, 2154.65s/it]
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 72, 'random_seed': 360, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 2268
# Seed set to 893
# Seed set to 7546
# Seed set to 4426
# Seed set to 4096
# Seed set to 1845
# Seed set to 8542
# Seed set to 2175
# Seed set to 6717
# Seed set to 6408
# windspeedcastelodopiauihour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 1837
# Seed set to 3823
# Seed set to 1977
# Seed set to 8439
# Seed set to 4401
# Seed set to 5927
# Seed set to 6639
# Seed set to 8477
# Seed set to 4464
# Seed set to 1014
#  33%|███████████████████████████                                                      | 1/3 [41:33<1:23:06, 2493.17s/it]Seed set to 7457
# Seed set to 973
# Seed set to 2310
# Seed set to 5276
# Seed set to 2170
# Seed set to 978
# Seed set to 6606
# Seed set to 961
# Seed set to 7576
# Seed set to 8869
#  67%|██████████████████████████████████████████████████████                           | 2/3 [1:35:34<48:53, 2933.29s/it]Seed set to 521
# Seed set to 4790
# Seed set to 4587
# Seed set to 1677
# Seed set to 2724
# Seed set to 1836
# Seed set to 2477
# Seed set to 8981
# Seed set to 3487
# Seed set to 179
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [2:22:02<00:00, 2840.76s/it]
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 72, 'random_seed': 1014, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 9971
# Seed set to 1095
# Seed set to 3376
# Seed set to 503
# Seed set to 892
# Seed set to 3851
# Seed set to 6292
# Seed set to 9309
# Seed set to 1852
# Seed set to 2646
# windspeedmaceiohour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 9610
# Seed set to 9897
# Seed set to 2724
# Seed set to 1836
# Seed set to 2477
# Seed set to 8981
# Seed set to 3487
# Seed set to 179
# Seed set to 9971
# Seed set to 1095
#  33%|██████████████████████████▎                                                    | 1/3 [1:05:33<2:11:06, 3933.07s/it]Seed set to 3376
# Seed set to 503
# Seed set to 892
# Seed set to 3851
# Seed set to 6292
# Seed set to 9309
# Seed set to 1852
# Seed set to 2646
# Seed set to 9610
# Seed set to 9897
#  67%|██████████████████████████████████████████████████████                           | 2/3 [1:54:30<55:47, 3347.31s/it]Seed set to 2724
# Seed set to 1836
# Seed set to 2477
# Seed set to 8981
# Seed set to 3487
# Seed set to 179
# Seed set to 9971
# Seed set to 1095
# Seed set to 3376
# Seed set to 503
# 100%|█████████████████████████████████████████████████████████████████████████████████| 3/3 [2:44:14<00:00, 3284.95s/it]
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 72, 'random_seed': 1095, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 892
# Seed set to 3851
# Seed set to 6292
# Seed set to 9309
# Seed set to 1852
# Seed set to 2646
# Seed set to 9610
# Seed set to 9897
# Seed set to 2724
# Seed set to 1836
# windspeedsalvadorhour.txt
#   0%|                                                                                             | 0/3 [00:00<?, ?it/s]Seed set to 2477
# Seed set to 6960
# Seed set to 9649
# Seed set to 6575
# Seed set to 6255
# Seed set to 7972
# Seed set to 3528
# Seed set to 1415
# Seed set to 1404
# Seed set to 1621
#  33%|███████████████████████████▋                                                       | 1/3 [20:50<41:40, 1250.40s/it]Seed set to 4727
# Seed set to 1651
# Seed set to 2686
# Seed set to 2594
# Seed set to 8997
# Seed set to 2588
# Seed set to 4535
# Seed set to 2326
# Seed set to 6077
# Seed set to 9708
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [40:42<20:15, 1215.98s/it]Seed set to 9989
# Seed set to 4673
# Seed set to 7472
# Seed set to 2359
# Seed set to 1644
# Seed set to 3649
# Seed set to 5366
# Seed set to 2177
# Seed set to 6929
# Seed set to 8085
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [59:41<00:00, 1193.98s/it]
# Seed set to 9259
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[100, 100], [100, 100], [100, 100]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 72, 'random_seed': 1621, 'input_size': 24, 'logger': False, 'default_root_dir': None}
# Seed set to 5361
# Seed set to 1671
# Seed set to 7622
# Seed set to 4389
# Seed set to 8044
# Seed set to 9033
# Seed set to 9249
# Seed set to 3994
# Seed set to 6351
