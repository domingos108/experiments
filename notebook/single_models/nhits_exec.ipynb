# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
import torch
from neuralforecast.models import NHITS
from neuralforecast.losses.pytorch import RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = NHITS

experiment_id = 'consumoenergia'
model_name = 'nhitsval'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'loss': [RMSE()],
    'n_freq_downsample': [[2, 1, 1]],
    'scaler_type': ['minmax'],
    'max_steps': [200],
    #'activation': ['Sigmoid'],
    'inference_windows_batch_size': [1],
    'val_check_steps': [10],
    'learning_rate': [0.01, 0.001, 0.0001],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
    'mlp_units':[
        [[50, 50], [50, 50], [50, 50]],
        [[20, 20], [20, 20], [20, 20]],
        [[10, 10], [10, 10], [10, 10]],

    ]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# recifeaccday.txt
# Seed set to 7729
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 9766, 'input_size': 7, 'logger': False, 'default_root_dir': None}
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# Seed set to 9766
# Seed set to 3742
# windspeedrecife.txt
# Seed set to 5692
# Seed set to 1983
# Seed set to 6301
# Seed set to 2929
# Seed set to 8579
# Seed set to 6792
# Seed set to 4856
# Seed set to 7848
# Seed set to 5990
# Seed set to 7751
# Seed set to 5680
# Seed set to 7911
# Seed set to 6185
# Seed set to 6680
# Seed set to 8856
# Seed set to 3790
# Seed set to 1913
# Seed set to 426
# Seed set to 265
# Seed set to 3782
# Seed set to 7359
# Seed set to 3210
# Seed set to 8463
# Seed set to 4663
# Seed set to 6509
# Seed set to 3296
# Seed set to 9857
# Seed set to 4830
# Seed set to 600
# Seed set to 7452
# Seed set to 4908
# Seed set to 4917
# Seed set to 3501
# Seed set to 2938
# Seed set to 5690
# Seed set to 1204
# Seed set to 8335
# Seed set to 6888
# Seed set to 5161
# Seed set to 2680
# Seed set to 8085
# Seed set to 827
# Seed set to 8800
# Seed set to 6722
# Seed set to 1849
# Seed set to 4935
# Seed set to 8160
# Seed set to 7962
# Seed set to 8940
# Seed set to 9345
# Seed set to 2446
# Seed set to 4844
# Seed set to 2925
# Seed set to 9376
# Seed set to 6004
# Seed set to 902
# Seed set to 8239
# Seed set to 9801
# Seed set to 3176
# Seed set to 5263
# Seed set to 9095
# Seed set to 3683
# Seed set to 7750
# Seed set to 1535
# Seed set to 6958
# Seed set to 7993
# Seed set to 5558
# Seed set to 3967
# Seed set to 412
# Seed set to 2622
# Seed set to 9343
# Seed set to 2466
# Seed set to 4628
# Seed set to 3857
# Seed set to 6573
# Seed set to 7637
# Seed set to 9134
# Seed set to 2709
# Seed set to 4640
# Seed set to 6623
# Seed set to 2832
# Seed set to 6673
# Seed set to 2296
# Seed set to 4502
# Seed set to 2328
# Seed set to 729
# Seed set to 2287
# Seed set to 187
# Seed set to 6840
# Seed set to 6600
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.0001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 412, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 223
# Seed set to 6770
# Seed set to 6236
# Seed set to 8498
# Seed set to 723
# Seed set to 3996
# Seed set to 2575
# Seed set to 1805
# Seed set to 8232
# Seed set to 5540
# windspeednatal.txt
# Seed set to 6011
# Seed set to 3644
# Seed set to 8550
# Seed set to 4973
# Seed set to 313
# Seed set to 4208
# Seed set to 2713
# Seed set to 1875
# Seed set to 3254
# Seed set to 7777
# Seed set to 1859
# Seed set to 5567
# Seed set to 464
# Seed set to 1998
# Seed set to 5799
# Seed set to 3519
# Seed set to 6742
# Seed set to 5139
# Seed set to 1084
# Seed set to 2181
# Seed set to 746
# Seed set to 5053
# Seed set to 8241
# Seed set to 1121
# Seed set to 8091
# Seed set to 7110
# Seed set to 8079
# Seed set to 5052
# Seed set to 5081
# Seed set to 9636
# Seed set to 4103
# Seed set to 6335
# Seed set to 412
# Seed set to 2622
# Seed set to 9343
# Seed set to 2466
# Seed set to 4628
# Seed set to 3857
# Seed set to 6573
# Seed set to 7637
# Seed set to 9134
# Seed set to 2709
# Seed set to 4640
# Seed set to 6623
# Seed set to 2832
# Seed set to 6673
# Seed set to 2296
# Seed set to 4502
# Seed set to 2328
# Seed set to 729
# Seed set to 2287
# Seed set to 187
# Seed set to 6840
# Seed set to 6600
# Seed set to 223
# Seed set to 6770
# Seed set to 6236
# Seed set to 8498
# Seed set to 723
# Seed set to 3996
# Seed set to 2575
# Seed set to 1805
# Seed set to 8232
# Seed set to 5540
# Seed set to 6011
# Seed set to 3644
# Seed set to 8550
# Seed set to 4973
# Seed set to 313
# Seed set to 4208
# Seed set to 2713
# Seed set to 1875
# Seed set to 3254
# Seed set to 7777
# Seed set to 1859
# Seed set to 5567
# Seed set to 464
# Seed set to 1998
# Seed set to 5799
# Seed set to 3519
# Seed set to 6742
# Seed set to 5139
# Seed set to 1084
# Seed set to 2181
# Seed set to 746
# Seed set to 5053
# Seed set to 8241
# Seed set to 1121
# Seed set to 8091
# Seed set to 7110
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.0001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 5799, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 8079
# Seed set to 5052
# Seed set to 5081
# Seed set to 9636
# Seed set to 4103
# Seed set to 6335
# Seed set to 412
# Seed set to 2622
# Seed set to 9343
# Seed set to 2466
# windspeedfortaleza.txt
# Seed set to 4628
# Seed set to 3857
# Seed set to 6573
# Seed set to 7637
# Seed set to 9134
# Seed set to 2709
# Seed set to 4640
# Seed set to 6623
# Seed set to 2832
# Seed set to 6673
# Seed set to 2296
# Seed set to 4502
# Seed set to 2328
# Seed set to 729
# Seed set to 2287
# Seed set to 187
# Seed set to 6840
# Seed set to 6600
# Seed set to 223
# Seed set to 6770
# Seed set to 6236
# Seed set to 8498
# Seed set to 723
# Seed set to 3996
# Seed set to 2575
# Seed set to 1805
# Seed set to 8232
# Seed set to 5540
# Seed set to 6011
# Seed set to 3644
# Seed set to 8550
# Seed set to 4973
# Seed set to 313
# Seed set to 4208
# Seed set to 2713
# Seed set to 1875
# Seed set to 3254
# Seed set to 7777
# Seed set to 1859
# Seed set to 5567
# Seed set to 464
# Seed set to 1998
# Seed set to 5799
# Seed set to 3519
# Seed set to 6742
# Seed set to 5139
# Seed set to 1084
# Seed set to 2181
# Seed set to 746
# Seed set to 5053
# Seed set to 8241
# Seed set to 1121
# Seed set to 8091
# Seed set to 7110
# Seed set to 8079
# Seed set to 5052
# Seed set to 5081
# Seed set to 9636
# Seed set to 4103
# Seed set to 6335
# Seed set to 412
# Seed set to 2622
# Seed set to 9343
# Seed set to 2466
# Seed set to 4628
# Seed set to 3857
# Seed set to 6573
# Seed set to 7637
# Seed set to 9134
# Seed set to 2709
# Seed set to 4640
# Seed set to 6623
# Seed set to 2832
# Seed set to 6673
# Seed set to 2296
# Seed set to 4502
# Seed set to 2328
# Seed set to 729
# Seed set to 2287
# Seed set to 187
# Seed set to 6840
# Seed set to 6600
# Seed set to 223
# Seed set to 6770
# Seed set to 6236
# Seed set to 8498
# Seed set to 723
# Seed set to 3996
# Seed set to 2575
# Seed set to 1805
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 1859, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 8232
# Seed set to 5540
# Seed set to 6011
# Seed set to 3644
# Seed set to 8550
# Seed set to 4973
# Seed set to 313
# Seed set to 4208
# Seed set to 2713
# Seed set to 1875
# irradiancesalvador.txt
# Seed set to 4388
# Seed set to 3396
# Seed set to 7686
# Seed set to 3249
# Seed set to 385
# Seed set to 837
# Seed set to 8750
# Seed set to 8629
# Seed set to 8714
# Seed set to 4283
# Seed set to 1978
# Seed set to 6875
# Seed set to 621
# Seed set to 3555
# Seed set to 3245
# Seed set to 847
# Seed set to 6401
# Seed set to 3271
# Seed set to 9312
# Seed set to 2439
# Seed set to 5807
# Seed set to 636
# Seed set to 472
# Seed set to 5599
# Seed set to 4562
# Seed set to 7470
# Seed set to 6471
# Seed set to 7542
# Seed set to 1578
# Seed set to 7347
# Seed set to 9670
# Seed set to 4450
# Seed set to 5979
# Seed set to 1974
# Seed set to 9401
# Seed set to 9444
# Seed set to 9656
# Seed set to 1409
# Seed set to 9682
# Seed set to 5528
# Seed set to 3360
# Seed set to 5837
# Seed set to 1082
# Seed set to 8839
# Seed set to 5394
# Seed set to 8711
# Seed set to 6370
# Seed set to 521
# Seed set to 6526
# Seed set to 7740
# Seed set to 2259
# Seed set to 2423
# Seed set to 1770
# Seed set to 8275
# Seed set to 4704
# Seed set to 6071
# Seed set to 9095
# Seed set to 377
# Seed set to 2245
# Seed set to 2686
# Seed set to 2553
# Seed set to 5225
# Seed set to 2512
# Seed set to 6512
# Seed set to 7419
# Seed set to 8286
# Seed set to 2067
# Seed set to 1448
# Seed set to 4438
# Seed set to 9394
# Seed set to 5163
# Seed set to 9273
# Seed set to 4798
# Seed set to 3290
# Seed set to 1921
# Seed set to 8866
# Seed set to 1682
# Seed set to 8113
# Seed set to 4887
# Seed set to 1362
# Seed set to 4621
# Seed set to 7124
# Seed set to 507
# Seed set to 5142
# Seed set to 1136
# Seed set to 6957
# Seed set to 7484
# Seed set to 8284
# Seed set to 8674
# Seed set to 6722
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 9312, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 9301
# Seed set to 4440
# Seed set to 9502
# Seed set to 6657
# Seed set to 6579
# Seed set to 5203
# Seed set to 9115
# Seed set to 7742
# Seed set to 1747
# Seed set to 243
# irradiancefortaleza.txt
# Seed set to 9052
# Seed set to 2892
# Seed set to 5121
# Seed set to 2103
# Seed set to 1728
# Seed set to 3303
# Seed set to 6310
# Seed set to 8272
# Seed set to 8631
# Seed set to 444
# Seed set to 4185
# Seed set to 9828
# Seed set to 1067
# Seed set to 4501
# Seed set to 9878
# Seed set to 2010
# Seed set to 9257
# Seed set to 5265
# Seed set to 986
# Seed set to 1487
# Seed set to 9383
# Seed set to 4897
# Seed set to 3895
# Seed set to 6025
# Seed set to 800
# Seed set to 7430
# Seed set to 7376
# Seed set to 6932
# Seed set to 3552
# Seed set to 9356
# Seed set to 5175
# Seed set to 4756
# Seed set to 87
# Seed set to 2312
# Seed set to 5882
# Seed set to 7613
# Seed set to 5331
# Seed set to 5708
# Seed set to 2140
# Seed set to 2352
# Seed set to 5079
# Seed set to 8517
# Seed set to 4278
# Seed set to 5975
# Seed set to 1827
# Seed set to 1488
# Seed set to 1616
# Seed set to 2866
# Seed set to 4666
# Seed set to 7744
# Seed set to 3194
# Seed set to 9565
# Seed set to 2782
# Seed set to 2574
# Seed set to 8630
# Seed set to 6180
# Seed set to 9823
# Seed set to 3676
# Seed set to 7481
# Seed set to 1121
# Seed set to 9575
# Seed set to 7886
# Seed set to 521
# Seed set to 6526
# Seed set to 7740
# Seed set to 2259
# Seed set to 2423
# Seed set to 1770
# Seed set to 8275
# Seed set to 4704
# Seed set to 6071
# Seed set to 9095
# Seed set to 377
# Seed set to 2245
# Seed set to 2686
# Seed set to 2553
# Seed set to 5225
# Seed set to 2512
# Seed set to 6512
# Seed set to 7419
# Seed set to 8286
# Seed set to 2067
# Seed set to 1448
# Seed set to 4438
# Seed set to 9394
# Seed set to 5163
# Seed set to 9273
# Seed set to 4798
# Seed set to 3290
# Seed set to 1921
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 8631, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 8866
# Seed set to 1682
# Seed set to 8113
# Seed set to 4887
# Seed set to 1362
# Seed set to 4621
# Seed set to 7124
# Seed set to 507
# Seed set to 5142
# Seed set to 1136
# irradiancefloripa.txt
# Seed set to 6957
# Seed set to 7484
# Seed set to 8284
# Seed set to 8674
# Seed set to 6722
# Seed set to 9301
# Seed set to 4440
# Seed set to 9502
# Seed set to 6657
# Seed set to 6579
# Seed set to 5203
# Seed set to 9115
# Seed set to 7742
# Seed set to 1747
# Seed set to 243
# Seed set to 9052
# Seed set to 2892
# Seed set to 5121
# Seed set to 2103
# Seed set to 1728
# Seed set to 3303
# Seed set to 6310
# Seed set to 8272
# Seed set to 8631
# Seed set to 444
# Seed set to 4185
# Seed set to 9828
# Seed set to 1067
# Seed set to 4501
# Seed set to 9878
# Seed set to 2010
# Seed set to 9257
# Seed set to 5265
# Seed set to 986
# Seed set to 1487
# Seed set to 9383
# Seed set to 4897
# Seed set to 3895
# Seed set to 6025
# Seed set to 800
# Seed set to 7430
# Seed set to 7376
# Seed set to 6932
# Seed set to 3552
# Seed set to 9356
# Seed set to 5175
# Seed set to 4756
# Seed set to 87
# Seed set to 2312
# Seed set to 5882
# Seed set to 7613
# Seed set to 5331
# Seed set to 5708
# Seed set to 2140
# Seed set to 2352
# Seed set to 5079
# Seed set to 8517
# Seed set to 4278
# Seed set to 5975
# Seed set to 1827
# Seed set to 1488
# Seed set to 1616
# Seed set to 2866
# Seed set to 4666
# Seed set to 7744
# Seed set to 3194
# Seed set to 9565
# Seed set to 2782
# Seed set to 2574
# Seed set to 8630
# Seed set to 6180
# Seed set to 9823
# Seed set to 3676
# Seed set to 7481
# Seed set to 1121
# Seed set to 9575
# Seed set to 7886
# Seed set to 521
# Seed set to 6526
# Seed set to 7740
# Seed set to 2259
# Seed set to 2423
# Seed set to 1770
# Seed set to 8275
# Seed set to 4704
# Seed set to 6071
# Seed set to 9095
# Seed set to 377
# Seed set to 2245
# Seed set to 2686
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 6657, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 2553
# Seed set to 5225
# Seed set to 2512
# Seed set to 6512
# Seed set to 7419
# Seed set to 8286
# Seed set to 2067
# Seed set to 1448
# Seed set to 4438
# Seed set to 9394
# irradiancesp.txt
# Seed set to 8316
# Seed set to 6426
# Seed set to 5995
# Seed set to 7283
# Seed set to 4552
# Seed set to 9654
# Seed set to 9029
# Seed set to 17
# Seed set to 1198
# Seed set to 2184
# Seed set to 1164
# Seed set to 1771
# Seed set to 3303
# Seed set to 4124
# Seed set to 7307
# Seed set to 6139
# Seed set to 1448
# Seed set to 2020
# Seed set to 2950
# Seed set to 107
# Seed set to 382
# Seed set to 6805
# Seed set to 5148
# Seed set to 1743
# Seed set to 2918
# Seed set to 9236
# Seed set to 5035
# Seed set to 3430
# Seed set to 7290
# Seed set to 3992
# Seed set to 9767
# Seed set to 2915
# Seed set to 4946
# Seed set to 275
# Seed set to 8004
# Seed set to 6414
# Seed set to 2252
# Seed set to 4728
# Seed set to 9043
# Seed set to 258
# Seed set to 9355
# Seed set to 9038
# Seed set to 9937
# Seed set to 6675
# Seed set to 9007
# Seed set to 5405
# Seed set to 6913
# Seed set to 3309
# Seed set to 4349
# Seed set to 7386
# Seed set to 8018
# Seed set to 8432
# Seed set to 3548
# Seed set to 9035
# Seed set to 965
# Seed set to 6751
# Seed set to 799
# Seed set to 2893
# Seed set to 8176
# Seed set to 2238
# Seed set to 6462
# Seed set to 5009
# Seed set to 2419
# Seed set to 7234
# Seed set to 4336
# Seed set to 2019
# Seed set to 3313
# Seed set to 440
# Seed set to 7707
# Seed set to 3569
# Seed set to 4820
# Seed set to 2912
# Seed set to 7623
# Seed set to 1355
# Seed set to 9873
# Seed set to 2232
# Seed set to 4174
# Seed set to 6659
# Seed set to 833
# Seed set to 2422
# Seed set to 4255
# Seed set to 2435
# Seed set to 5918
# Seed set to 1870
# Seed set to 8409
# Seed set to 3279
# Seed set to 3446
# Seed set to 2908
# Seed set to 4076
# Seed set to 1962
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 9043, 'input_size': 17, 'logger': False, 'default_root_dir': None}
# Seed set to 8984
# Seed set to 7146
# Seed set to 2996
# Seed set to 3108
# Seed set to 4978
# Seed set to 4629
# Seed set to 7953
# Seed set to 5127
# Seed set to 9775
# Seed set to 1119
# coloradoRiver.txt
# Seed set to 6345
# Seed set to 3364
# Seed set to 6993
# Seed set to 7080
# Seed set to 8035
# Seed set to 9228
# Seed set to 4803
# Seed set to 3817
# Seed set to 3439
# Seed set to 9268
# Seed set to 8006
# Seed set to 7407
# Seed set to 4743
# Seed set to 5489
# Seed set to 9475
# Seed set to 8761
# Seed set to 2313
# Seed set to 7325
# Seed set to 3957
# Seed set to 7213
# Seed set to 6609
# Seed set to 9471
# Seed set to 9798
# Seed set to 6094
# Seed set to 429
# Seed set to 3938
# Seed set to 4734
# Seed set to 5359
# Seed set to 9469
# Seed set to 1484
# Seed set to 6677
# Seed set to 5841
# Seed set to 539
# Seed set to 7604
# Seed set to 2284
# Seed set to 6895
# Seed set to 6771
# Seed set to 4610
# Seed set to 3004
# Seed set to 2681
# Seed set to 6008
# Seed set to 2536
# Seed set to 9380
# Seed set to 4946
# Seed set to 9372
# Seed set to 8897
# Seed set to 699
# Seed set to 5328
# Seed set to 4089
# Seed set to 7964
# Seed set to 3113
# Seed set to 4255
# Seed set to 9413
# Seed set to 9373
# Seed set to 8100
# Seed set to 6798
# Seed set to 1283
# Seed set to 7524
# Seed set to 265
# Seed set to 4321
# Seed set to 4359
# Seed set to 3400
# Seed set to 4634
# Seed set to 4074
# Seed set to 2350
# Seed set to 3087
# Seed set to 1448
# Seed set to 9891
# Seed set to 5653
# Seed set to 4779
# Seed set to 2862
# Seed set to 4646
# Seed set to 6119
# Seed set to 1121
# Seed set to 2906
# Seed set to 9974
# Seed set to 3549
# Seed set to 255
# Seed set to 964
# Seed set to 3309
# Seed set to 5132
# Seed set to 5189
# Seed set to 1193
# Seed set to 7090
# Seed set to 5509
# Seed set to 2043
# Seed set to 7022
# Seed set to 2490
# Seed set to 8241
# Seed set to 7036
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 3004, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 9930
# Seed set to 7287
# Seed set to 9986
# Seed set to 1304
# Seed set to 5241
# Seed set to 586
# Seed set to 4372
# Seed set to 9649
# Seed set to 5308
# Seed set to 4455
# sunspot.txt
# Seed set to 8619
# Seed set to 601
# Seed set to 2887
# Seed set to 1293
# Seed set to 1841
# Seed set to 2509
# Seed set to 9785
# Seed set to 563
# Seed set to 3200
# Seed set to 5627
# Seed set to 110
# Seed set to 9721
# Seed set to 2405
# Seed set to 4154
# Seed set to 6549
# Seed set to 620
# Seed set to 4835
# Seed set to 7779
# Seed set to 1039
# Seed set to 4969
# Seed set to 8688
# Seed set to 3455
# Seed set to 3164
# Seed set to 2606
# Seed set to 5875
# Seed set to 4123
# Seed set to 4983
# Seed set to 3265
# Seed set to 4777
# Seed set to 8671
# Seed set to 2556
# Seed set to 2509
# Seed set to 9785
# Seed set to 563
# Seed set to 3200
# Seed set to 5627
# Seed set to 110
# Seed set to 9721
# Seed set to 2405
# Seed set to 4154
# Seed set to 6549
# Seed set to 620
# Seed set to 4835
# Seed set to 7779
# Seed set to 1039
# Seed set to 4969
# Seed set to 8688
# Seed set to 3455
# Seed set to 3164
# Seed set to 2606
# Seed set to 5875
# Seed set to 4123
# Seed set to 4983
# Seed set to 3265
# Seed set to 4777
# Seed set to 8671
# Seed set to 2556
# Seed set to 2509
# Seed set to 9785
# Seed set to 563
# Seed set to 3200
# Seed set to 5627
# Seed set to 110
# Seed set to 9721
# Seed set to 2405
# Seed set to 4154
# Seed set to 6549
# Seed set to 620
# Seed set to 4835
# Seed set to 7779
# Seed set to 1039
# Seed set to 4969
# Seed set to 8688
# Seed set to 3455
# Seed set to 3164
# Seed set to 2606
# Seed set to 5875
# Seed set to 4123
# Seed set to 4983
# Seed set to 3265
# Seed set to 4777
# Seed set to 8671
# Seed set to 2556
# Seed set to 2509
# Seed set to 9785
# Seed set to 563
# Seed set to 3200
# Seed set to 5627
# Seed set to 110
# Seed set to 9721
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 1039, 'input_size': 9, 'logger': False, 'default_root_dir': None}
# Seed set to 2405
# Seed set to 4154
# Seed set to 6549
# Seed set to 620
# Seed set to 4835
# Seed set to 7779
# Seed set to 1039
# Seed set to 4969
# Seed set to 8688
# Seed set to 3455
# milk.txt
# Seed set to 6860
# Seed set to 4680
# Seed set to 6613
# Seed set to 9490
# Seed set to 476
# Seed set to 591
# Seed set to 6463
# Seed set to 7315
# Seed set to 3896
# Seed set to 2583
# Seed set to 2442
# Seed set to 8753
# Seed set to 8900
# Seed set to 1845
# Seed set to 4182
# Seed set to 8978
# Seed set to 6291
# Seed set to 8279
# Seed set to 6056
# Seed set to 7185
# Seed set to 1450
# Seed set to 6626
# Seed set to 5792
# Seed set to 8479
# Seed set to 2169
# Seed set to 1981
# Seed set to 8758
# Seed set to 1040
# Seed set to 2308
# Seed set to 1394
# Seed set to 3875
# Seed set to 5425
# Seed set to 1828
# Seed set to 1363
# Seed set to 218
# Seed set to 4372
# Seed set to 4111
# Seed set to 2820
# Seed set to 7349
# Seed set to 9388
# Seed set to 9698
# Seed set to 8029
# Seed set to 1997
# Seed set to 6911
# Seed set to 806
# Seed set to 9390
# Seed set to 7081
# Seed set to 1140
# Seed set to 1191
# Seed set to 4915
# Seed set to 2939
# Seed set to 8474
# Seed set to 5618
# Seed set to 5646
# Seed set to 9721
# Seed set to 1050
# Seed set to 8573
# Seed set to 9366
# Seed set to 9319
# Seed set to 1488
# Seed set to 3078
# Seed set to 4569
# Seed set to 7698
# Seed set to 3072
# Seed set to 6737
# Seed set to 310
# Seed set to 6124
# Seed set to 5975
# Seed set to 940
# Seed set to 1188
# Seed set to 9155
# Seed set to 6251
# Seed set to 4555
# Seed set to 3322
# Seed set to 6983
# Seed set to 1646
# Seed set to 979
# Seed set to 2686
# Seed set to 7253
# Seed set to 9905
# Seed set to 5351
# Seed set to 2750
# Seed set to 6526
# Seed set to 6873
# Seed set to 8535
# Seed set to 2121
# Seed set to 5655
# Seed set to 371
# Seed set to 7140
# Seed set to 6395
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 7349, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 3899
# Seed set to 2638
# Seed set to 716
# Seed set to 9302
# Seed set to 6271
# Seed set to 1655
# Seed set to 1791
# Seed set to 7804
# Seed set to 2074
# Seed set to 5177
# Unemployment.txt
# Seed set to 8030
# Seed set to 3357
# Seed set to 45
# Seed set to 4578
# Seed set to 9879
# Seed set to 9590
# Seed set to 1893
# Seed set to 3218
# Seed set to 6127
# Seed set to 4251
# Seed set to 6125
# Seed set to 2627
# Seed set to 500
# Seed set to 7783
# Seed set to 8654
# Seed set to 8667
# Seed set to 5925
# Seed set to 6343
# Seed set to 6903
# Seed set to 5717
# Seed set to 1005
# Seed set to 8188
# Seed set to 2433
# Seed set to 5616
# Seed set to 3910
# Seed set to 6799
# Seed set to 803
# Seed set to 9182
# Seed set to 8304
# Seed set to 4175
# Seed set to 4278
# Seed set to 2364
# Seed set to 4600
# Seed set to 5438
# Seed set to 172
# Seed set to 6621
# Seed set to 7217
# Seed set to 9076
# Seed set to 4299
# Seed set to 4233
# Seed set to 4969
# Seed set to 9161
# Seed set to 2029
# Seed set to 6412
# Seed set to 724
# Seed set to 3801
# Seed set to 7172
# Seed set to 9061
# Seed set to 2979
# Seed set to 2357
# Seed set to 532
# Seed set to 1946
# Seed set to 40
# Seed set to 2104
# Seed set to 18
# Seed set to 8162
# Seed set to 3300
# Seed set to 2915
# Seed set to 7527
# Seed set to 5198
# Seed set to 1421
# Seed set to 7715
# Seed set to 9364
# Seed set to 6468
# Seed set to 3544
# Seed set to 1781
# Seed set to 4933
# Seed set to 9047
# Seed set to 5130
# Seed set to 4522
# Seed set to 1652
# Seed set to 1487
# Seed set to 1213
# Seed set to 9674
# Seed set to 7441
# Seed set to 9855
# Seed set to 312
# Seed set to 6333
# Seed set to 7396
# Seed set to 1925
# Seed set to 6206
# Seed set to 3660
# Seed set to 5485
# Seed set to 1632
# Seed set to 924
# Seed set to 3923
# Seed set to 7784
# Seed set to 8605
# Seed set to 8569
# Seed set to 2896
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 4299, 'input_size': 18, 'logger': False, 'default_root_dir': None}
# Seed set to 740
# Seed set to 3755
# Seed set to 5429
# Seed set to 8264
# Seed set to 6469
# Seed set to 3227
# Seed set to 110
# Seed set to 2182
# Seed set to 6850
# Seed set to 6096
# ausbee.txt
# Seed set to 2780
# Seed set to 8211
# Seed set to 9062
# Seed set to 9377
# Seed set to 795
# Seed set to 636
# Seed set to 860
# Seed set to 3184
# Seed set to 8519
# Seed set to 6369
# Seed set to 339
# Seed set to 3036
# Seed set to 8158
# Seed set to 8989
# Seed set to 8937
# Seed set to 2979
# Seed set to 4430
# Seed set to 3974
# Seed set to 9263
# Seed set to 5349
# Seed set to 9834
# Seed set to 4557
# Seed set to 161
# Seed set to 1470
# Seed set to 1712
# Seed set to 7808
# Seed set to 992
# Seed set to 5121
# Seed set to 3217
# Seed set to 4140
# Seed set to 1984
# Seed set to 7186
# Seed set to 1621
# Seed set to 4243
# Seed set to 5777
# Seed set to 5548
# Seed set to 1723
# Seed set to 8434
# Seed set to 6448
# Seed set to 8248
# Seed set to 9388
# Seed set to 4148
# Seed set to 1449
# Seed set to 7524
# Seed set to 1788
# Seed set to 4932
# Seed set to 8414
# Seed set to 1128
# Seed set to 826
# Seed set to 2685
# Seed set to 8828
# Seed set to 1339
# Seed set to 857
# Seed set to 9155
# Seed set to 2218
# Seed set to 1800
# Seed set to 1090
# Seed set to 4656
# Seed set to 3363
# Seed set to 9191
# Seed set to 4101
# Seed set to 5698
# Seed set to 9254
# Seed set to 5751
# Seed set to 1712
# Seed set to 7808
# Seed set to 992
# Seed set to 5121
# Seed set to 3217
# Seed set to 4140
# Seed set to 1984
# Seed set to 7186
# Seed set to 1621
# Seed set to 4243
# Seed set to 5777
# Seed set to 5548
# Seed set to 1723
# Seed set to 8434
# Seed set to 6448
# Seed set to 8248
# Seed set to 9388
# Seed set to 4148
# Seed set to 1449
# Seed set to 7524
# Seed set to 1788
# Seed set to 4932
# Seed set to 8414
# Seed set to 1128
# Seed set to 826
# Seed set to 2685
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 8519, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 8828
# Seed set to 1339
# Seed set to 857
# Seed set to 9155
# Seed set to 2218
# Seed set to 1800
# Seed set to 1090
# Seed set to 4656
# Seed set to 3363
# Seed set to 9191
# austres.txt
# Seed set to 263
# Seed set to 1268
# Seed set to 3165
# Seed set to 2006
# Seed set to 1824
# Seed set to 3981
# Seed set to 9812
# Seed set to 5357
# Seed set to 7403
# Seed set to 9722
# Seed set to 7435
# Seed set to 3838
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 5978, 'input_size': 13, 'logger': False, 'default_root_dir': None}
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# Seed set to 8122
# Seed set to 460
# Seed set to 5978
# Seed set to 7684
# heartrate.txt
# Seed set to 7793
# Seed set to 5916
# Seed set to 8762
# Seed set to 4635
# Seed set to 2008
# Seed set to 904
# Seed set to 3081
# Seed set to 6117
# Seed set to 3169
# Seed set to 4022
# Seed set to 6346
# Seed set to 9650
# Seed set to 2387
# Seed set to 2345
# Seed set to 5044
# Seed set to 3962
# Seed set to 8845
# Seed set to 8634
# Seed set to 1149
# Seed set to 5652
# Seed set to 2126
# Seed set to 1038
# Seed set to 8840
# Seed set to 307
# Seed set to 3250
# Seed set to 8715
# Seed set to 547
# Seed set to 2379
# Seed set to 814
# Seed set to 290
# Seed set to 1180
# Seed set to 5550
# Seed set to 3745
# Seed set to 8153
# Seed set to 1792
# Seed set to 1800
# Seed set to 1070
# Seed set to 7662
# Seed set to 745
# Seed set to 696
# Seed set to 3682
# Seed set to 4673
# Seed set to 357
# Seed set to 3197
# Seed set to 9297
# Seed set to 5186
# Seed set to 2573
# Seed set to 7111
# Seed set to 3532
# Seed set to 2665
# Seed set to 5043
# Seed set to 6617
# Seed set to 9855
# Seed set to 2849
# Seed set to 2023
# Seed set to 22
# Seed set to 7374
# Seed set to 4677
# Seed set to 4534
# Seed set to 778
# Seed set to 827
# Seed set to 440
# Seed set to 1686
# Seed set to 2957
# Seed set to 9068
# Seed set to 5483
# Seed set to 3449
# Seed set to 2978
# Seed set to 275
# Seed set to 8371
# Seed set to 5192
# Seed set to 7764
# Seed set to 1868
# Seed set to 1057
# Seed set to 9256
# Seed set to 6219
# Seed set to 530
# Seed set to 5020
# Seed set to 5835
# Seed set to 8932
# Seed set to 1605
# Seed set to 5412
# Seed set to 5893
# Seed set to 5568
# Seed set to 4967
# Seed set to 8049
# Seed set to 4969
# Seed set to 7728
# Seed set to 7939
# Seed set to 9372
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.0001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 275, 'input_size': 2, 'logger': False, 'default_root_dir': None}
# Seed set to 8625
# Seed set to 3392
# Seed set to 2432
# Seed set to 9345
# Seed set to 244
# Seed set to 1373
# Seed set to 5838
# Seed set to 6704
# Seed set to 3488
# Seed set to 8720
# ozon.txt
# Seed set to 9735
# Seed set to 3328
# Seed set to 1319
# Seed set to 5875
# Seed set to 8832
# Seed set to 750
# Seed set to 5820
# Seed set to 9392
# Seed set to 434
# Seed set to 3703
# Seed set to 6569
# Seed set to 3919
# Seed set to 5113
# Seed set to 9284
# Seed set to 9355
# Seed set to 5718
# Seed set to 3050
# Seed set to 6503
# Seed set to 548
# Seed set to 1296
# Seed set to 7442
# Seed set to 7847
# Seed set to 1249
# Seed set to 7302
# Seed set to 6825
# Seed set to 1129
# Seed set to 4087
# Seed set to 9890
# Seed set to 5604
# Seed set to 5762
# Seed set to 3286
# Seed set to 5333
# Seed set to 7076
# Seed set to 457
# Seed set to 5156
# Seed set to 598
# Seed set to 5587
# Seed set to 5932
# Seed set to 75
# Seed set to 8588
# Seed set to 853
# Seed set to 9930
# Seed set to 7132
# Seed set to 9294
# Seed set to 851
# Seed set to 8981
# Seed set to 1772
# Seed set to 5461
# Seed set to 9955
# Seed set to 1239
# Seed set to 1745
# Seed set to 6351
# Seed set to 5258
# Seed set to 6964
# Seed set to 2937
# Seed set to 3019
# Seed set to 1088
# Seed set to 6959
# Seed set to 6491
# Seed set to 7278
# Seed set to 1263
# Seed set to 1682
# Seed set to 9066
# Seed set to 1535
# Seed set to 1549
# Seed set to 5852
# Seed set to 9760
# Seed set to 6135
# Seed set to 5168
# Seed set to 1383
# Seed set to 5772
# Seed set to 8310
# Seed set to 4456
# Seed set to 3023
# Seed set to 7394
# Seed set to 9682
# Seed set to 4875
# Seed set to 3397
# Seed set to 3888
# Seed set to 4358
# Seed set to 3944
# Seed set to 2885
# Seed set to 1089
# Seed set to 1217
# Seed set to 953
# Seed set to 3638
# Seed set to 9753
# Seed set to 2656
# Seed set to 1053
# Seed set to 2039
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.0001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 5168, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 6703
# Seed set to 1405
# Seed set to 8110
# Seed set to 6251
# Seed set to 728
# Seed set to 5715
# Seed set to 2203
# Seed set to 9309
# Seed set to 6780
# Seed set to 178
# pollution.txt
# Seed set to 9986
# Seed set to 3507
# Seed set to 246
# Seed set to 1463
# Seed set to 2849
# Seed set to 8580
# Seed set to 864
# Seed set to 7351
# Seed set to 1769
# Seed set to 9333
# Seed set to 5879
# Seed set to 4335
# Seed set to 4929
# Seed set to 1358
# Seed set to 5485
# Seed set to 9769
# Seed set to 225
# Seed set to 5826
# Seed set to 1821
# Seed set to 1349
# Seed set to 3994
# Seed set to 7236
# Seed set to 996
# Seed set to 3725
# Seed set to 3095
# Seed set to 8486
# Seed set to 5152
# Seed set to 9780
# Seed set to 9085
# Seed set to 7720
# Seed set to 2361
# Seed set to 9731
# Seed set to 6773
# Seed set to 4731
# Seed set to 212
# Seed set to 1563
# Seed set to 5983
# Seed set to 6823
# Seed set to 5139
# Seed set to 2984
# Seed set to 6919
# Seed set to 9424
# Seed set to 8983
# Seed set to 6114
# Seed set to 4229
# Seed set to 5011
# Seed set to 4648
# Seed set to 7157
# Seed set to 3330
# Seed set to 4099
# Seed set to 1948
# Seed set to 7410
# Seed set to 7572
# Seed set to 8444
# Seed set to 4835
# Seed set to 6315
# Seed set to 4270
# Seed set to 2094
# Seed set to 6719
# Seed set to 4736
# Seed set to 1263
# Seed set to 6011
# Seed set to 9703
# Seed set to 7577
# Seed set to 5305
# Seed set to 7566
# Seed set to 5791
# Seed set to 1214
# Seed set to 5494
# Seed set to 2110
# Seed set to 2186
# Seed set to 8928
# Seed set to 9195
# Seed set to 5138
# Seed set to 9272
# Seed set to 1109
# Seed set to 8552
# Seed set to 4130
# Seed set to 449
# Seed set to 7256
# Seed set to 6197
# Seed set to 9130
# Seed set to 7494
# Seed set to 9806
# Seed set to 1319
# Seed set to 739
# Seed set to 4724
# Seed set to 9635
# Seed set to 2153
# Seed set to 7652
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 3330, 'input_size': 10, 'logger': False, 'default_root_dir': None}
# Seed set to 3230
# Seed set to 4488
# Seed set to 8527
# Seed set to 7103
# Seed set to 5075
# Seed set to 5511
# Seed set to 8183
# Seed set to 5208
# Seed set to 8289
# Seed set to 3863
# redwine.txt
# Seed set to 7831
# Seed set to 6434
# Seed set to 2626
# Seed set to 9917
# Seed set to 1291
# Seed set to 6378
# Seed set to 9956
# Seed set to 3235
# Seed set to 3147
# Seed set to 3677
# Seed set to 9905
# Seed set to 5545
# Seed set to 9888
# Seed set to 9340
# Seed set to 4994
# Seed set to 7085
# Seed set to 6027
# Seed set to 9050
# Seed set to 309
# Seed set to 12
# Seed set to 4353
# Seed set to 6175
# Seed set to 1579
# Seed set to 9251
# Seed set to 4643
# Seed set to 860
# Seed set to 843
# Seed set to 2312
# Seed set to 7149
# Seed set to 8436
# Seed set to 8011
# Seed set to 8954
# Seed set to 3442
# Seed set to 6274
# Seed set to 8548
# Seed set to 9193
# Seed set to 7063
# Seed set to 9388
# Seed set to 8358
# Seed set to 7834
# Seed set to 8306
# Seed set to 3772
# Seed set to 1956
# Seed set to 4275
# Seed set to 4841
# Seed set to 5968
# Seed set to 2352
# Seed set to 6337
# Seed set to 867
# Seed set to 6124
# Seed set to 9451
# Seed set to 1261
# Seed set to 2400
# Seed set to 9239
# Seed set to 5410
# Seed set to 7845
# Seed set to 9039
# Seed set to 8765
# Seed set to 1058
# Seed set to 7960
# Seed set to 8919
# Seed set to 3784
# Seed set to 5071
# Seed set to 1303
# Seed set to 2589
# Seed set to 4284
# Seed set to 110
# Seed set to 488
# Seed set to 2458
# Seed set to 178
# Seed set to 3522
# Seed set to 3967
# Seed set to 9836
# Seed set to 7201
# Seed set to 7734
# Seed set to 553
# Seed set to 7830
# Seed set to 8877
# Seed set to 1045
# Seed set to 1758
# Seed set to 8701
# Seed set to 1293
# Seed set to 3217
# Seed set to 2943
# Seed set to 9429
# Seed set to 269
# Seed set to 1112
# Seed set to 218
# Seed set to 126
# Seed set to 8309
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 7149, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 4904
# Seed set to 4356
# Seed set to 3139
# Seed set to 9645
# Seed set to 5530
# Seed set to 4977
# Seed set to 9583
# Seed set to 3171
# Seed set to 4254
# Seed set to 802
# gasoline.txt
# Seed set to 6725
# Seed set to 3715
# Seed set to 6873
# Seed set to 8898
# Seed set to 9672
# Seed set to 8771
# Seed set to 6465
# Seed set to 9096
# Seed set to 3626
# Seed set to 6242
# Seed set to 6836
# Seed set to 596
# Seed set to 4623
# Seed set to 7161
# Seed set to 5104
# Seed set to 9276
# Seed set to 7255
# Seed set to 3310
# Seed set to 4292
# Seed set to 9207
# Seed set to 473
# Seed set to 9282
# Seed set to 4730
# Seed set to 8360
# Seed set to 6781
# Seed set to 3364
# Seed set to 7893
# Seed set to 9503
# Seed set to 956
# Seed set to 7116
# Seed set to 3411
# Seed set to 6132
# Seed set to 9208
# Seed set to 6377
# Seed set to 5319
# Seed set to 6721
# Seed set to 3316
# Seed set to 9943
# Seed set to 2505
# Seed set to 7586
# Seed set to 7686
# Seed set to 2238
# Seed set to 2642
# Seed set to 9761
# Seed set to 2158
# Seed set to 8615
# Seed set to 926
# Seed set to 6952
# Seed set to 387
# Seed set to 3970
# Seed set to 5087
# Seed set to 9981
# Seed set to 6400
# Seed set to 8797
# Seed set to 9492
# Seed set to 9493
# Seed set to 7802
# Seed set to 8546
# Seed set to 4661
# Seed set to 1218
# Seed set to 7938
# Seed set to 708
# Seed set to 7141
# Seed set to 2533
# Seed set to 5703
# Seed set to 1921
# Seed set to 1375
# Seed set to 8336
# Seed set to 4115
# Seed set to 8951
# Seed set to 5190
# Seed set to 5786
# Seed set to 7454
# Seed set to 4307
# Seed set to 9122
# Seed set to 6551
# Seed set to 1932
# Seed set to 6768
# Seed set to 2505
# Seed set to 7586
# Seed set to 7686
# Seed set to 2238
# Seed set to 2642
# Seed set to 9761
# Seed set to 2158
# Seed set to 8615
# Seed set to 926
# Seed set to 6952
# Seed set to 387
# Seed set to 3970
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 387, 'input_size': 8, 'logger': False, 'default_root_dir': None}
# Seed set to 5087
# Seed set to 9981
# Seed set to 6400
# Seed set to 8797
# Seed set to 9492
# Seed set to 9493
# Seed set to 7802
# Seed set to 8546
# Seed set to 4661
# Seed set to 1218
# temperature.txt
# Seed set to 2839
# Seed set to 836
# Seed set to 9530
# Seed set to 4233
# Seed set to 6471
# Seed set to 2361
# Seed set to 8328
# Seed set to 1258
# Seed set to 5068
# Seed set to 891
# Seed set to 8859
# Seed set to 2975
# Seed set to 4586
# Seed set to 6146
# Seed set to 291
# Seed set to 1565
# Seed set to 6043
# Seed set to 5421
# Seed set to 3571
# Seed set to 5733
# Seed set to 7202
# Seed set to 2498
# Seed set to 1867
# Seed set to 3726
# Seed set to 5693
# Seed set to 2571
# Seed set to 4673
# Seed set to 8723
# Seed set to 9258
# Seed set to 8534
# Seed set to 3308
# Seed set to 9946
# Seed set to 8906
# Seed set to 6580
# Seed set to 5359
# Seed set to 394
# Seed set to 2241
# Seed set to 8202
# Seed set to 1740
# Seed set to 3799
# Seed set to 9171
# Seed set to 8352
# Seed set to 3506
# Seed set to 7520
# Seed set to 7536
# Seed set to 4413
# Seed set to 7765
# Seed set to 8205
# Seed set to 7873
# Seed set to 5946
# Seed set to 2370
# Seed set to 9833
# Seed set to 8208
# Seed set to 1602
# Seed set to 5484
# Seed set to 2997
# Seed set to 430
# Seed set to 269
# Seed set to 47
# Seed set to 800
# Seed set to 3180
# Seed set to 5790
# Seed set to 5099
# Seed set to 1468
# Seed set to 3479
# Seed set to 9882
# Seed set to 9658
# Seed set to 2953
# Seed set to 1838
# Seed set to 7026
# Seed set to 2444
# Seed set to 6371
# Seed set to 5287
# Seed set to 8351
# Seed set to 3663
# Seed set to 5916
# Seed set to 3893
# Seed set to 7589
# Seed set to 1516
# Seed set to 698
# Seed set to 753
# Seed set to 3970
# Seed set to 2839
# Seed set to 836
# Seed set to 9530
# Seed set to 4233
# Seed set to 6471
# Seed set to 2361
# Seed set to 8328
# Seed set to 1258
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 9258, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 5068
# Seed set to 891
# Seed set to 8859
# Seed set to 2975
# Seed set to 4586
# Seed set to 6146
# Seed set to 291
# Seed set to 1565
# Seed set to 6043
# Seed set to 5421
# woolyrnq.txt
# Seed set to 8253
# Seed set to 940
# Seed set to 2713
# Seed set to 6146
# Seed set to 3286
# Seed set to 6046
# Seed set to 8209
# Seed set to 1811
# Seed set to 8899
# Seed set to 6895
# Seed set to 3900
# Seed set to 2756
# Seed set to 157
# Seed set to 9230
# Seed set to 9378
# Seed set to 3996
# Seed set to 1910
# Seed set to 7836
# Seed set to 1030
# Seed set to 2849
# Seed set to 6837
# Seed set to 2182
# Seed set to 521
# Seed set to 5237
# Seed set to 3964
# Seed set to 7247
# Seed set to 768
# Seed set to 9614
# Seed set to 4540
# Seed set to 1996
# Seed set to 2186
# Seed set to 6707
# Seed set to 9502
# Seed set to 3329
# Seed set to 1153
# Seed set to 6350
# Seed set to 1745
# Seed set to 3365
# Seed set to 6858
# Seed set to 3711
# Seed set to 2740
# Seed set to 5452
# Seed set to 534
# Seed set to 8320
# Seed set to 3351
# Seed set to 9946
# Seed set to 9919
# Seed set to 3819
# Seed set to 9254
# Seed set to 6430
# Seed set to 4168
# Seed set to 4655
# Seed set to 7369
# Seed set to 9811
# Seed set to 1013
# Seed set to 1803
# Seed set to 657
# Seed set to 1049
# Seed set to 6340
# Seed set to 3162
# Seed set to 2874
# Seed set to 5541
# Seed set to 1720
# Seed set to 6237
# Seed set to 3094
# Seed set to 2583
# Seed set to 560
# Seed set to 4143
# Seed set to 6277
# Seed set to 617
# Seed set to 1214
# Seed set to 9065
# Seed set to 3934
# Seed set to 6833
# Seed set to 8549
# Seed set to 6326
# Seed set to 724
# Seed set to 3154
# Seed set to 7178
# Seed set to 4615
# Seed set to 5222
# Seed set to 4136
# Seed set to 8335
# Seed set to 7813
# Seed set to 1660
# Seed set to 2836
# Seed set to 2544
# Seed set to 6752
# Seed set to 766
# Seed set to 102
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 9254, 'input_size': 8, 'logger': False, 'default_root_dir': None}
# Seed set to 5537
# Seed set to 397
# Seed set to 2383
# Seed set to 18
# Seed set to 5376
# Seed set to 780
# Seed set to 652
# Seed set to 5841
# Seed set to 1635
# Seed set to 9128
# melbmin.txt
# Seed set to 2234
# Seed set to 875
# Seed set to 2369
# Seed set to 3177
# Seed set to 487
# Seed set to 2507
# Seed set to 1691
# Seed set to 4823
# Seed set to 4238
# Seed set to 9152
# Seed set to 1984
# Seed set to 7979
# Seed set to 6102
# Seed set to 4638
# Seed set to 4624
# Seed set to 3098
# Seed set to 2063
# Seed set to 1254
# Seed set to 7117
# Seed set to 9469
# Seed set to 3361
# Seed set to 4928
# Seed set to 8209
# Seed set to 505
# Seed set to 6134
# Seed set to 1843
# Seed set to 2993
# Seed set to 4217
# Seed set to 6936
# Seed set to 4723
# Seed set to 2084
# Seed set to 6823
# Seed set to 9139
# Seed set to 5370
# Seed set to 5894
# Seed set to 8298
# Seed set to 9372
# Seed set to 2096
# Seed set to 7643
# Seed set to 3328
# Seed set to 2599
# Seed set to 7511
# Seed set to 5290
# Seed set to 841
# Seed set to 3810
# Seed set to 4567
# Seed set to 7765
# Seed set to 7793
# Seed set to 4631
# Seed set to 3225
# Seed set to 725
# Seed set to 2113
# Seed set to 6175
# Seed set to 2181
# Seed set to 4512
# Seed set to 5828
# Seed set to 6425
# Seed set to 8952
# Seed set to 4509
# Seed set to 7301
# Seed set to 8138
# Seed set to 6583
# Seed set to 1068
# Seed set to 5722
# Seed set to 8967
# Seed set to 5292
# Seed set to 7151
# Seed set to 7003
# Seed set to 9431
# Seed set to 916
# Seed set to 8139
# Seed set to 3665
# Seed set to 1240
# Seed set to 6298
# Seed set to 8161
# Seed set to 7729
# Seed set to 1739
# Seed set to 677
# Seed set to 8781
# Seed set to 9256
# Seed set to 9319
# Seed set to 3819
# Seed set to 8418
# Seed set to 3329
# Seed set to 4674
# Seed set to 9791
# Seed set to 4037
# Seed set to 2016
# Seed set to 387
# Seed set to 504
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 6936, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 9980
# Seed set to 8186
# Seed set to 54
# Seed set to 2729
# Seed set to 339
# Seed set to 5885
# Seed set to 1868
# Seed set to 8971
# Seed set to 8324

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = KAN

experiment_id = 'resudualens'
model_name = 'kanval'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 3918
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# recifeaccday.txt
# Seed set to 8773
# Seed set to 7943
# Seed set to 4152
# Seed set to 1732
# Seed set to 3468
# Seed set to 1661
# Seed set to 4699
# Seed set to 1346
# Seed set to 4588
# Seed set to 2187
# Seed set to 5610
# Seed set to 7047
# Seed set to 6806
# Seed set to 7965
# Seed set to 6046
# Seed set to 3075
# Seed set to 9166
# Seed set to 8353
# Seed set to 8420
# Seed set to 1211
# Seed set to 3120
# Seed set to 3527
# Seed set to 8690
# Seed set to 925
# Seed set to 3601
# Seed set to 7346
# Seed set to 2201
# Seed set to 1578
# Seed set to 6678
# Seed set to 9830
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 6678, 'input_size': 7, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 6171
# Seed set to 9465
# Seed set to 5285
# Seed set to 6142
# Seed set to 9986
# Seed set to 3694
# Seed set to 3215
# Seed set to 8773
# Seed set to 7943
# Seed set to 4152
# windspeedrecife.txt
# Seed set to 1875
# Seed set to 3595
# Seed set to 8728
# Seed set to 9170
# Seed set to 7596
# Seed set to 480
# Seed set to 5124
# Seed set to 3441
# Seed set to 9541
# Seed set to 5179
# Seed set to 2660
# Seed set to 5492
# Seed set to 8927
# Seed set to 6649
# Seed set to 9254
# Seed set to 3024
# Seed set to 9559
# Seed set to 1087
# Seed set to 1340
# Seed set to 929
# Seed set to 5799
# Seed set to 9142
# Seed set to 4120
# Seed set to 3653
# Seed set to 7785
# Seed set to 3649
# Seed set to 7348
# Seed set to 4220
# Seed set to 408
# Seed set to 8006
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 408, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 8951
# Seed set to 3586
# Seed set to 3655
# Seed set to 8215
# Seed set to 8934
# Seed set to 4178
# Seed set to 3765
# Seed set to 2136
# Seed set to 4257
# Seed set to 4298
# windspeednatal.txt
# Seed set to 1638
# Seed set to 6277
# Seed set to 9385
# Seed set to 4313
# Seed set to 8291
# Seed set to 8354
# Seed set to 745
# Seed set to 616
# Seed set to 4537
# Seed set to 1113
# Seed set to 9579
# Seed set to 8197
# Seed set to 1847
# Seed set to 4722
# Seed set to 7397
# Seed set to 6333
# Seed set to 1382
# Seed set to 8223
# Seed set to 6962
# Seed set to 4550
# Seed set to 3814
# Seed set to 3068
# Seed set to 4308
# Seed set to 3535
# Seed set to 5481
# Seed set to 7425
# Seed set to 480
# Seed set to 5124
# Seed set to 3441
# Seed set to 9541
# {'hidden_size': 50, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 4537, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 5179
# Seed set to 2660
# Seed set to 5492
# Seed set to 8927
# Seed set to 6649
# Seed set to 9254
# Seed set to 3024
# Seed set to 9559
# Seed set to 1087
# Seed set to 1340
# windspeedfortaleza.txt
# Seed set to 929
# Seed set to 5799
# Seed set to 9142
# Seed set to 4120
# Seed set to 3653
# Seed set to 7785
# Seed set to 3649
# Seed set to 7348
# Seed set to 4220
# Seed set to 408
# Seed set to 8006
# Seed set to 8951
# Seed set to 3586
# Seed set to 3655
# Seed set to 8215
# Seed set to 8934
# Seed set to 4178
# Seed set to 3765
# Seed set to 2136
# Seed set to 4257
# Seed set to 4298
# Seed set to 1638
# Seed set to 6277
# Seed set to 9385
# Seed set to 4313
# Seed set to 8291
# Seed set to 8354
# Seed set to 745
# Seed set to 616
# Seed set to 4537
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 616, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 1113
# Seed set to 9579
# Seed set to 8197
# Seed set to 1847
# Seed set to 4722
# Seed set to 7397
# Seed set to 6333
# Seed set to 1382
# Seed set to 8223
# Seed set to 6962
# irradiancesalvador.txt
# Seed set to 8743
# Seed set to 4827
# Seed set to 6166
# Seed set to 570
# Seed set to 4922
# Seed set to 8125
# Seed set to 4667
# Seed set to 8819
# Seed set to 5526
# Seed set to 9396
# Seed set to 430
# Seed set to 3148
# Seed set to 9260
# Seed set to 636
# Seed set to 1516
# Seed set to 6517
# Seed set to 747
# Seed set to 6127
# Seed set to 1530
# Seed set to 8293
# Seed set to 7563
# Seed set to 2985
# Seed set to 9046
# Seed set to 2012
# Seed set to 8154
# Seed set to 6205
# Seed set to 1465
# Seed set to 1933
# Seed set to 6335
# Seed set to 9317
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 6335, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 687
# Seed set to 4717
# Seed set to 6618
# Seed set to 2387
# Seed set to 3067
# Seed set to 3906
# Seed set to 1466
# Seed set to 3343
# Seed set to 8301
# Seed set to 7429
# irradiancefortaleza.txt
# Seed set to 3174
# Seed set to 4341
# Seed set to 9557
# Seed set to 761
# Seed set to 1593
# Seed set to 8074
# Seed set to 3282
# Seed set to 2383
# Seed set to 1391
# Seed set to 797
# Seed set to 4048
# Seed set to 8415
# Seed set to 3017
# Seed set to 4548
# Seed set to 2499
# Seed set to 4243
# Seed set to 527
# Seed set to 1174
# Seed set to 949
# Seed set to 9816
# Seed set to 5845
# Seed set to 1770
# Seed set to 3579
# Seed set to 4573
# Seed set to 5395
# Seed set to 9230
# Seed set to 2587
# Seed set to 7451
# Seed set to 2531
# Seed set to 9289
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 2531, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 4756
# Seed set to 3965
# Seed set to 2925
# Seed set to 3074
# Seed set to 5398
# Seed set to 2415
# Seed set to 9424
# Seed set to 6442
# Seed set to 9316
# Seed set to 90
# irradiancefloripa.txt
# Seed set to 5984
# Seed set to 3826
# Seed set to 7278
# Seed set to 6077
# Seed set to 7340
# Seed set to 8287
# Seed set to 7034
# Seed set to 6286
# Seed set to 8123
# Seed set to 3365
# Seed set to 2007
# Seed set to 6331
# Seed set to 8470
# Seed set to 8067
# Seed set to 2439
# Seed set to 4884
# Seed set to 1569
# Seed set to 815
# Seed set to 7298
# Seed set to 6640
# Seed set to 3566
# Seed set to 8461
# Seed set to 646
# Seed set to 5641
# Seed set to 5142
# Seed set to 573
# Seed set to 688
# Seed set to 1535
# Seed set to 3682
# Seed set to 1755
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 3682, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 239
# Seed set to 8073
# Seed set to 93
# Seed set to 378
# Seed set to 7468
# Seed set to 4694
# Seed set to 6411
# Seed set to 171
# Seed set to 2929
# Seed set to 3791
# irradiancesp.txt
# Seed set to 3834
# Seed set to 5661
# Seed set to 8724
# Seed set to 24
# Seed set to 8880
# Seed set to 2142
# Seed set to 3497
# Seed set to 4116
# Seed set to 1961
# Seed set to 9412
# Seed set to 7122
# Seed set to 8528
# Seed set to 8147
# Seed set to 1223
# Seed set to 4648
# Seed set to 160
# Seed set to 4316
# Seed set to 2781
# Seed set to 6413
# Seed set to 8264
# Seed set to 4294
# Seed set to 4935
# Seed set to 659
# Seed set to 2042
# Seed set to 2803
# Seed set to 9362
# Seed set to 6184
# Seed set to 5771
# Seed set to 8736
# Seed set to 3132
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 8736, 'input_size': 17, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 1734
# Seed set to 1841
# Seed set to 1764
# Seed set to 2851
# Seed set to 2715
# Seed set to 99
# Seed set to 4294
# Seed set to 4935
# Seed set to 659
# Seed set to 2042
# coloradoRiver.txt
# Seed set to 5541
# Seed set to 2144
# Seed set to 2198
# Seed set to 5886
# Seed set to 785
# Seed set to 4435
# Seed set to 8136
# Seed set to 7813
# Seed set to 6554
# Seed set to 9075
# Seed set to 3487
# Seed set to 3308
# Seed set to 9148
# Seed set to 5919
# Seed set to 1136
# Seed set to 6670
# Seed set to 3035
# Seed set to 3833
# Seed set to 499
# Seed set to 2032
# Seed set to 3898
# Seed set to 3331
# Seed set to 3807
# Seed set to 6210
# Seed set to 4641
# Seed set to 2360
# Seed set to 6747
# Seed set to 1904
# Seed set to 2723
# Seed set to 979
# {'hidden_size': 50, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 6554, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 9565
# Seed set to 8751
# Seed set to 1842
# Seed set to 4556
# Seed set to 4219
# Seed set to 3535
# Seed set to 9294
# Seed set to 9624
# Seed set to 651
# Seed set to 5606
# sunspot.txt
# Seed set to 239
# Seed set to 3270
# Seed set to 9983
# Seed set to 7398
# Seed set to 1052
# Seed set to 1353
# Seed set to 7805
# Seed set to 5045
# Seed set to 5446
# Seed set to 7432
# Seed set to 1167
# Seed set to 2177
# Seed set to 3732
# Seed set to 2973
# Seed set to 8492
# Seed set to 4650
# Seed set to 4887
# Seed set to 7403
# Seed set to 299
# Seed set to 3923
# Seed set to 3660
# Seed set to 2103
# Seed set to 9684
# Seed set to 1860
# Seed set to 4816
# Seed set to 2991
# Seed set to 6171
# Seed set to 7257
# Seed set to 5390
# Seed set to 4686
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 5390, 'input_size': 9, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 1420
# Seed set to 2842
# Seed set to 8979
# Seed set to 6370
# Seed set to 302
# Seed set to 6036
# Seed set to 416
# Seed set to 6930
# Seed set to 7529
# Seed set to 2190
# milk.txt
# Seed set to 9024
# Seed set to 1388
# Seed set to 1530
# Seed set to 5206
# Seed set to 3344
# Seed set to 9303
# Seed set to 7287
# Seed set to 7687
# Seed set to 5516
# Seed set to 9366
# Seed set to 8983
# Seed set to 5592
# Seed set to 4308
# Seed set to 3554
# Seed set to 3817
# Seed set to 6320
# Seed set to 7323
# Seed set to 4481
# Seed set to 9965
# Seed set to 4328
# Seed set to 6132
# Seed set to 8203
# Seed set to 9887
# Seed set to 7522
# Seed set to 1923
# Seed set to 1510
# Seed set to 5863
# Seed set to 6634
# Seed set to 6132
# Seed set to 8203
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 6132, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 9887
# Seed set to 7522
# Seed set to 1923
# Seed set to 1510
# Seed set to 5863
# Seed set to 6634
# Seed set to 6132
# Seed set to 8203
# Seed set to 9887
# Seed set to 7522
# Unemployment.txt
# Seed set to 5225
# Seed set to 564
# Seed set to 4
# Seed set to 6675
# Seed set to 8720
# Seed set to 6934
# Seed set to 114
# Seed set to 6930
# Seed set to 4468
# Seed set to 1544
# Seed set to 2616
# Seed set to 1815
# Seed set to 2914
# Seed set to 6285
# Seed set to 6876
# Seed set to 8020
# Seed set to 5136
# Seed set to 5161
# Seed set to 9190
# Seed set to 4490
# Seed set to 2682
# Seed set to 6471
# Seed set to 6916
# Seed set to 4505
# Seed set to 8213
# Seed set to 5899
# Seed set to 2698
# Seed set to 8501
# Seed set to 3477
# Seed set to 9651
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 3477, 'input_size': 18, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 4155
# Seed set to 1260
# Seed set to 2502
# Seed set to 2193
# Seed set to 1180
# Seed set to 1342
# Seed set to 3301
# Seed set to 5169
# Seed set to 2236
# Seed set to 497
# ausbee.txt
# Seed set to 6966
# Seed set to 3949
# Seed set to 4693
# Seed set to 5976
# Seed set to 4272
# Seed set to 8660
# Seed set to 2668
# Seed set to 2863
# Seed set to 4542
# Seed set to 5348
# Seed set to 5994
# Seed set to 8334
# Seed set to 7663
# Seed set to 5158
# Seed set to 568
# Seed set to 2161
# Seed set to 5495
# Seed set to 1584
# Seed set to 2750
# Seed set to 3595
# Seed set to 8394
# Seed set to 228
# Seed set to 259
# Seed set to 6406
# Seed set to 1900
# Seed set to 6431
# Seed set to 1321
# Seed set to 5356
# Seed set to 6460
# Seed set to 1051
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 6460, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 6770
# Seed set to 8898
# Seed set to 670
# Seed set to 9566
# Seed set to 6625
# Seed set to 9154
# Seed set to 5235
# Seed set to 6850
# Seed set to 9200
# Seed set to 5995
# austres.txt
# Seed set to 544
# Seed set to 8529
# Seed set to 5595
# Seed set to 5209
# Seed set to 3254
# Seed set to 487
# Seed set to 8420
# Seed set to 6853
# Seed set to 4735
# Seed set to 681
# Seed set to 1767
# Seed set to 6626
# Seed set to 2801
# Seed set to 2871
# Seed set to 159
# Seed set to 5952
# Seed set to 488
# Seed set to 9090
# Seed set to 5988
# Seed set to 5585
# Seed set to 300
# Seed set to 5566
# Seed set to 7712
# Seed set to 5976
# Seed set to 4120
# Seed set to 8843
# Seed set to 5871
# Seed set to 8911
# Seed set to 3314
# Seed set to 2175
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 3314, 'input_size': 13, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 4741
# Seed set to 8391
# Seed set to 5214
# Seed set to 2828
# Seed set to 4403
# Seed set to 1486
# Seed set to 9494
# Seed set to 1262
# Seed set to 5036
# Seed set to 5296
# heartrate.txt
# Seed set to 4387
# Seed set to 1009
# Seed set to 5914
# Seed set to 8677
# Seed set to 1569
# Seed set to 1026
# Seed set to 3002
# Seed set to 911
# Seed set to 3290
# Seed set to 9988
# Seed set to 238
# Seed set to 1025
# Seed set to 4475
# Seed set to 7551
# Seed set to 3001
# Seed set to 915
# Seed set to 9481
# Seed set to 2338
# Seed set to 8766
# Seed set to 7076
# Seed set to 4101
# Seed set to 7670
# Seed set to 4897
# Seed set to 9350
# Seed set to 3260
# Seed set to 4163
# Seed set to 3900
# Seed set to 3355
# Seed set to 7321
# Seed set to 1645
# {'hidden_size': 100, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 8766, 'input_size': 2, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 4813
# Seed set to 1039
# Seed set to 3719
# Seed set to 4749
# Seed set to 4852
# Seed set to 6893
# Seed set to 867
# Seed set to 6494
# Seed set to 6948
# Seed set to 7418
# ozon.txt
# Seed set to 2808
# Seed set to 9387
# Seed set to 1413
# Seed set to 2335
# Seed set to 9190
# Seed set to 562
# Seed set to 7078
# Seed set to 3503
# Seed set to 9655
# Seed set to 6761
# Seed set to 2852
# Seed set to 6683
# Seed set to 83
# Seed set to 5909
# Seed set to 3946
# Seed set to 2535
# Seed set to 2296
# Seed set to 2854
# Seed set to 3250
# Seed set to 7294
# Seed set to 9903
# Seed set to 9670
# Seed set to 6202
# Seed set to 4155
# Seed set to 7727
# Seed set to 9526
# Seed set to 7636
# Seed set to 4740
# Seed set to 8065
# Seed set to 6354
# {'hidden_size': 50, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 9655, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 1373
# Seed set to 110
# Seed set to 7903
# Seed set to 7586
# Seed set to 865
# Seed set to 6645
# Seed set to 9724
# Seed set to 2997
# Seed set to 7055
# Seed set to 8555
# pollution.txt
# Seed set to 8409
# Seed set to 3538
# Seed set to 3125
# Seed set to 2258
# Seed set to 5090
# Seed set to 3623
# Seed set to 7355
# Seed set to 2500
# Seed set to 1477
# Seed set to 4607
# Seed set to 8085
# Seed set to 2124
# Seed set to 8013
# Seed set to 5476
# Seed set to 6215
# Seed set to 8059
# Seed set to 2851
# Seed set to 8
# Seed set to 4229
# Seed set to 423
# Seed set to 6502
# Seed set to 9086
# Seed set to 3193
# Seed set to 952
# Seed set to 4456
# Seed set to 4444
# Seed set to 8920
# Seed set to 3999
# Seed set to 6363
# Seed set to 8062
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 6363, 'input_size': 10, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 657
# Seed set to 9365
# Seed set to 3175
# Seed set to 3860
# Seed set to 7940
# Seed set to 3552
# Seed set to 7366
# Seed set to 8219
# Seed set to 7781
# Seed set to 6702
# redwine.txt
# Seed set to 8360
# Seed set to 9653
# Seed set to 4953
# Seed set to 153
# Seed set to 653
# Seed set to 4182
# Seed set to 6982
# Seed set to 2713
# Seed set to 1659
# Seed set to 7205
# Seed set to 3826
# Seed set to 3522
# Seed set to 1903
# Seed set to 1468
# Seed set to 8549
# Seed set to 1201
# Seed set to 4924
# Seed set to 1254
# Seed set to 3876
# Seed set to 9794
# Seed set to 7014
# Seed set to 5793
# Seed set to 7423
# Seed set to 3525
# Seed set to 8302
# Seed set to 1895
# Seed set to 9315
# Seed set to 4559
# Seed set to 2849
# Seed set to 371
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 2849, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 8125
# Seed set to 9793
# Seed set to 3533
# Seed set to 812
# Seed set to 2327
# Seed set to 6423
# Seed set to 3363
# Seed set to 9145
# Seed set to 6171
# Seed set to 7116
# gasoline.txt
# Seed set to 5910
# Seed set to 1571
# Seed set to 3554
# Seed set to 9936
# Seed set to 7108
# Seed set to 2808
# Seed set to 1156
# Seed set to 159
# Seed set to 6959
# Seed set to 5656
# Seed set to 669
# Seed set to 3811
# Seed set to 1791
# Seed set to 9752
# Seed set to 6550
# Seed set to 1634
# Seed set to 6068
# Seed set to 5857
# Seed set to 8691
# Seed set to 3416
# Seed set to 9936
# Seed set to 7108
# Seed set to 2808
# Seed set to 1156
# Seed set to 159
# Seed set to 6959
# Seed set to 5656
# Seed set to 669
# Seed set to 3811
# Seed set to 1791
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 3811, 'input_size': 8, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 9752
# Seed set to 6550
# Seed set to 1634
# Seed set to 6068
# Seed set to 5857
# Seed set to 8691
# Seed set to 3416
# Seed set to 9936
# Seed set to 7108
# Seed set to 2808
# temperature.txt
# Seed set to 981
# Seed set to 8733
# Seed set to 6873
# Seed set to 987
# Seed set to 556
# Seed set to 1683
# Seed set to 3026
# Seed set to 2056
# Seed set to 3176
# Seed set to 5229
# Seed set to 8732
# Seed set to 3288
# Seed set to 7932
# Seed set to 3368
# Seed set to 2334
# Seed set to 1984
# Seed set to 9290
# Seed set to 9558
# Seed set to 9489
# Seed set to 771
# Seed set to 6541
# Seed set to 769
# Seed set to 9728
# Seed set to 6777
# Seed set to 6728
# Seed set to 9685
# Seed set to 4474
# Seed set to 482
# Seed set to 8898
# Seed set to 8555
# {'hidden_size': 50, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 3176, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 4553
# Seed set to 62
# Seed set to 2806
# Seed set to 5354
# Seed set to 4252
# Seed set to 2419
# Seed set to 5859
# Seed set to 9898
# Seed set to 6864
# Seed set to 5714
# woolyrnq.txt
# Seed set to 2262
# Seed set to 9063
# Seed set to 3009
# Seed set to 7100
# Seed set to 1218
# Seed set to 979
# Seed set to 5299
# Seed set to 4387
# Seed set to 6242
# Seed set to 6677
# Seed set to 2550
# Seed set to 4230
# Seed set to 2490
# Seed set to 8343
# Seed set to 9822
# Seed set to 7095
# Seed set to 7424
# Seed set to 562
# Seed set to 5721
# Seed set to 7464
# Seed set to 3172
# Seed set to 7426
# Seed set to 6542
# Seed set to 7936
# Seed set to 2089
# Seed set to 5206
# Seed set to 3740
# Seed set to 508
# Seed set to 7377
# Seed set to 2146
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 7377, 'input_size': 8, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 4997
# Seed set to 7524
# Seed set to 6319
# Seed set to 8461
# Seed set to 2464
# Seed set to 1896
# Seed set to 7456
# Seed set to 2632
# Seed set to 6436
# Seed set to 6641
# melbmin.txt
# Seed set to 8129
# Seed set to 5422
# Seed set to 2941
# Seed set to 1026
# Seed set to 1656
# Seed set to 8860
# Seed set to 9693
# Seed set to 4653
# Seed set to 5886
# Seed set to 6568
# Seed set to 2950
# Seed set to 8795
# Seed set to 3828
# Seed set to 7059
# Seed set to 5568
# Seed set to 262
# Seed set to 7977
# Seed set to 6481
# Seed set to 283
# Seed set to 3203
# Seed set to 6607
# Seed set to 5675
# Seed set to 8377
# Seed set to 1421
# Seed set to 4282
# Seed set to 3347
# Seed set to 4081
# Seed set to 2092
# Seed set to 1333
# Seed set to 7430
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 1333, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 1273
# Seed set to 9163
# Seed set to 7977
# Seed set to 6481
# Seed set to 283
# Seed set to 3203
# Seed set to 6607
# Seed set to 5675
# Seed set to 8377

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import TCN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = TCN

experiment_id = 'resudualens'
model_name = 'tcn'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'loss': [RMSE()],
    'learning_rate': [5e-4],
    'max_steps': [500],
    'kernel_size': [2],
    'dilations':[[1,2,4,8,16]],
    'context_size': [10],
    'decoder_hidden_size': [128],
    'encoder_hidden_size': [128],
    'decoder_layers': [2]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 1421
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# recifeaccday.txt
# Seed set to 8022
# Seed set to 6537
# Seed set to 8425
# Seed set to 4318
# Seed set to 9811
# Seed set to 8574
# Seed set to 5601
# Seed set to 5610
# Seed set to 5404
# Seed set to 5388
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 5404, 'input_size': 7, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 3236
# Seed set to 7829
# Seed set to 4424
# Seed set to 6044
# Seed set to 1423
# Seed set to 3500
# Seed set to 2824
# Seed set to 3364
# Seed set to 3056
# Seed set to 5277
# windspeedrecife.txt
# Seed set to 4141
# Seed set to 4803
# Seed set to 954
# Seed set to 9389
# Seed set to 2708
# Seed set to 3071
# Seed set to 7468
# Seed set to 3949
# Seed set to 9610
# Seed set to 961
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 9610, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 7143
# Seed set to 916
# Seed set to 3330
# Seed set to 8192
# Seed set to 7314
# Seed set to 4383
# Seed set to 2660
# Seed set to 9511
# Seed set to 6004
# Seed set to 8404
# windspeednatal.txt
# Seed set to 5963
# Seed set to 3598
# Seed set to 8491
# Seed set to 7686
# Seed set to 1755
# Seed set to 674
# Seed set to 1657
# Seed set to 6589
# Seed set to 8058
# Seed set to 8972
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 8058, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 6880
# Seed set to 9003
# Seed set to 226
# Seed set to 7763
# Seed set to 34
# Seed set to 2751
# Seed set to 1554
# Seed set to 6894
# Seed set to 2
# Seed set to 1243
# windspeedfortaleza.txt
# Seed set to 7801
# Seed set to 6682
# Seed set to 7672
# Seed set to 6703
# Seed set to 1508
# Seed set to 8411
# Seed set to 4139
# Seed set to 1027
# Seed set to 7996
# Seed set to 7970
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 7996, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 7945
# Seed set to 3481
# Seed set to 2808
# Seed set to 6957
# Seed set to 693
# Seed set to 5951
# Seed set to 2670
# Seed set to 7700
# Seed set to 3158
# Seed set to 8732
# irradiancesalvador.txt
# Seed set to 613
# Seed set to 7765
# Seed set to 5070
# Seed set to 7077
# Seed set to 9696
# Seed set to 2807
# Seed set to 2309
# Seed set to 4841
# Seed set to 2184
# Seed set to 3937
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 2184, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 8378
# Seed set to 4535
# Seed set to 2846
# Seed set to 9693
# Seed set to 4980
# Seed set to 5155
# Seed set to 1024
# Seed set to 5533
# Seed set to 833
# Seed set to 3258
# irradiancefortaleza.txt
# Seed set to 176
# Seed set to 1126
# Seed set to 1827
# Seed set to 6448
# Seed set to 6240
# Seed set to 3061
# Seed set to 6804
# Seed set to 9473
# Seed set to 1907
# Seed set to 6844
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 1907, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 2290
# Seed set to 9806
# Seed set to 1824
# Seed set to 2637
# Seed set to 9363
# Seed set to 7916
# Seed set to 1575
# Seed set to 7925
# Seed set to 6163
# Seed set to 2472
# irradiancefloripa.txt
# Seed set to 2084
# Seed set to 1257
# Seed set to 1148
# Seed set to 6178
# Seed set to 6774
# Seed set to 2245
# Seed set to 7346
# Seed set to 5026
# Seed set to 311
# Seed set to 4457
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 311, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 81
# Seed set to 2769
# Seed set to 3719
# Seed set to 9084

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import DeepAR
from neuralforecast.losses.pytorch import DistributionLoss, MQLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = DeepAR

experiment_id = 'resudualens'
model_name = 'deepar'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'lstm_n_layers': [2],
    'trajectory_samples': [100],
    'lstm_hidden_size': [20, 50, 100],
    'valid_loss': [MQLoss(level=[80, 90])],
    'loss': [RMSE()],
    'learning_rate': [0.01, 0.001, 0.0001],
    'max_steps': [100],

}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
