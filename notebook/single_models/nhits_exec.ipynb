# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)
import torch
from neuralforecast.models import NHITS
from neuralforecast.losses.pytorch import RMSE
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = NHITS

experiment_id = 'resudualens'
model_name = 'nhitsval'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'loss': [RMSE()],
    'n_freq_downsample': [[2, 1, 1]],
    'scaler_type': ['minmax'],
    'max_steps': [200],
    #'activation': ['Sigmoid'],
    'inference_windows_batch_size': [1],
    'val_check_steps': [10],
    'learning_rate': [0.01, 0.001, 0.0001],
    'enable_progress_bar': [False],
    'enable_model_summary': [False],
    'mlp_units':[
        [[50, 50], [50, 50], [50, 50]],
        [[20, 20], [20, 20], [20, 20]],
        [[10, 10], [10, 10], [10, 10]],

    ]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 2393
# samuday.txt
# Seed set to 548
# Seed set to 7762
# Seed set to 8647
# Seed set to 5204
# Seed set to 9916
# Seed set to 9869
# Seed set to 8249
# Seed set to 652
# Seed set to 5915
# Seed set to 3210
# Seed set to 7204
# Seed set to 2320
# Seed set to 7445
# Seed set to 7332
# Seed set to 2310
# Seed set to 5165
# Seed set to 5465
# Seed set to 699
# Seed set to 6904
# Seed set to 148
# Seed set to 223
# Seed set to 1557
# Seed set to 2631
# Seed set to 5669
# Seed set to 7432
# Seed set to 942
# Seed set to 4780
# Seed set to 6866
# Seed set to 1675
# Seed set to 4272
# Seed set to 4810
# Seed set to 3760
# Seed set to 6257
# Seed set to 1534
# Seed set to 4736
# Seed set to 2813
# Seed set to 2379
# Seed set to 5504
# Seed set to 6759
# Seed set to 5719
# Seed set to 9683
# Seed set to 6706
# Seed set to 989
# Seed set to 7624
# Seed set to 3550
# Seed set to 71
# Seed set to 6281
# Seed set to 2260
# Seed set to 9957
# Seed set to 6576
# Seed set to 6969
# Seed set to 2374
# Seed set to 9925
# Seed set to 7853
# Seed set to 5123
# Seed set to 3143
# Seed set to 9766
# Seed set to 664
# Seed set to 5824
# Seed set to 905
# Seed set to 1823
# Seed set to 4049
# Seed set to 932
# Seed set to 473
# Seed set to 5730
# Seed set to 8938
# Seed set to 7425
# Seed set to 976
# Seed set to 4493
# Seed set to 8364
# Seed set to 2468
# Seed set to 8395
# Seed set to 7031
# Seed set to 2547
# Seed set to 1461
# Seed set to 8671
# Seed set to 4572
# Seed set to 1739
# Seed set to 2925
# Seed set to 4432
# Seed set to 9851
# Seed set to 3956
# Seed set to 5478
# Seed set to 1835
# Seed set to 1128
# Seed set to 9110
# Seed set to 2131
# Seed set to 8702
# Seed set to 6346
# Seed set to 2480
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 1675, 'input_size': 7, 'logger': False, 'default_root_dir': None}
# Seed set to 526
# Seed set to 393
# Seed set to 6960
# Seed set to 3314
# Seed set to 1641
# Seed set to 1712
# Seed set to 638
# Seed set to 5842
# Seed set to 1834
# Seed set to 2926
# recifeaccday.txt
# Seed set to 5135
# Seed set to 5570
# Seed set to 3396
# Seed set to 2483
# Seed set to 2260
# Seed set to 3129
# Seed set to 3018
# Seed set to 5143
# Seed set to 8176
# Seed set to 9683
# Seed set to 2368
# Seed set to 6333
# Seed set to 6332
# Seed set to 3931
# Seed set to 8629
# Seed set to 6066
# Seed set to 7541
# Seed set to 4596
# Seed set to 8074
# Seed set to 6331
# Seed set to 3135
# Seed set to 4785
# Seed set to 4412
# Seed set to 8386
# Seed set to 9204
# Seed set to 3144
# Seed set to 8324
# Seed set to 5180
# Seed set to 8983
# Seed set to 1727
# Seed set to 6143
# Seed set to 7907
# Seed set to 2129
# Seed set to 4957
# Seed set to 9027
# Seed set to 3650
# Seed set to 1772
# Seed set to 8469
# Seed set to 4051
# Seed set to 259
# Seed set to 2028
# Seed set to 9683
# Seed set to 2368
# Seed set to 6333
# Seed set to 6332
# Seed set to 3931
# Seed set to 8629
# Seed set to 6066
# Seed set to 7541
# Seed set to 4596
# Seed set to 8074
# Seed set to 6331
# Seed set to 3135
# Seed set to 4785
# Seed set to 4412
# Seed set to 8386
# Seed set to 9204
# Seed set to 3144
# Seed set to 8324
# Seed set to 5180
# Seed set to 8983
# Seed set to 1727
# Seed set to 6143
# Seed set to 7907
# Seed set to 2129
# Seed set to 4957
# Seed set to 9027
# Seed set to 3650
# Seed set to 1772
# Seed set to 8469
# Seed set to 4051
# Seed set to 259
# Seed set to 2028
# Seed set to 9683
# Seed set to 2368
# Seed set to 6333
# Seed set to 6332
# Seed set to 3931
# Seed set to 8629
# Seed set to 6066
# Seed set to 7541
# Seed set to 4596
# Seed set to 8074
# Seed set to 6331
# Seed set to 3135
# Seed set to 4785
# Seed set to 4412
# Seed set to 8386
# Seed set to 9204
# Seed set to 3144
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 7541, 'input_size': 7, 'logger': False, 'default_root_dir': None}
# Seed set to 8324
# Seed set to 5180
# Seed set to 8983
# Seed set to 1727
# Seed set to 6143
# Seed set to 7907
# Seed set to 2129
# Seed set to 4957
# Seed set to 9027
# Seed set to 3650
# windspeedrecife.txt
# Seed set to 4196
# Seed set to 9769
# Seed set to 8124
# Seed set to 7831
# Seed set to 325
# Seed set to 2986
# Seed set to 422
# Seed set to 2045
# Seed set to 4864
# Seed set to 2383
# Seed set to 4180
# Seed set to 671
# Seed set to 8273
# Seed set to 5119
# Seed set to 2797
# Seed set to 4614
# Seed set to 167
# Seed set to 91
# Seed set to 1260
# Seed set to 6633
# Seed set to 708
# Seed set to 5835
# Seed set to 224
# Seed set to 8641
# Seed set to 749
# Seed set to 6372
# Seed set to 7061
# Seed set to 3173
# Seed set to 3982
# Seed set to 8162
# Seed set to 8977
# Seed set to 1016
# Seed set to 940
# Seed set to 1073
# Seed set to 5246
# Seed set to 9063
# Seed set to 7460
# Seed set to 6584
# Seed set to 804
# Seed set to 2632
# Seed set to 5655
# Seed set to 2201
# Seed set to 1922
# Seed set to 6955
# Seed set to 569
# Seed set to 4410
# Seed set to 3868
# Seed set to 3540
# Seed set to 1436
# Seed set to 1259
# Seed set to 2643
# Seed set to 8181
# Seed set to 6803
# Seed set to 5359
# Seed set to 7661
# Seed set to 9362
# Seed set to 4890
# Seed set to 8542
# Seed set to 6578
# Seed set to 9224
# Seed set to 1120
# Seed set to 6659
# Seed set to 908
# Seed set to 3819
# Seed set to 2297
# Seed set to 7014
# Seed set to 3852
# Seed set to 9003
# Seed set to 5183
# Seed set to 1522
# Seed set to 192
# Seed set to 3344
# Seed set to 3623
# Seed set to 3890
# Seed set to 2070
# Seed set to 1325
# Seed set to 5240
# Seed set to 6323
# Seed set to 9730
# Seed set to 8421
# Seed set to 1885
# Seed set to 4647
# Seed set to 1018
# Seed set to 7642
# Seed set to 3894
# Seed set to 3099
# Seed set to 342
# Seed set to 2224
# Seed set to 5990
# Seed set to 7751
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 6578, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 5680
# Seed set to 7911
# Seed set to 6185
# Seed set to 6680
# Seed set to 8856
# Seed set to 3790
# Seed set to 1913
# Seed set to 426
# Seed set to 265
# Seed set to 3782
# windspeednatal.txt
# Seed set to 7359
# Seed set to 3210
# Seed set to 8463
# Seed set to 4663
# Seed set to 6509
# Seed set to 3296
# Seed set to 9857
# Seed set to 4830
# Seed set to 600
# Seed set to 7452
# Seed set to 4908
# Seed set to 4917
# Seed set to 3501
# Seed set to 2938
# Seed set to 5690
# Seed set to 1204
# Seed set to 8335
# Seed set to 6888
# Seed set to 5161
# Seed set to 2680
# Seed set to 8085
# Seed set to 827
# Seed set to 8800
# Seed set to 6722
# Seed set to 1849
# Seed set to 4935
# Seed set to 8160
# Seed set to 7962
# Seed set to 8940
# Seed set to 9345
# Seed set to 2446
# Seed set to 4844
# Seed set to 2925
# Seed set to 9376
# Seed set to 6004
# Seed set to 902
# Seed set to 8239
# Seed set to 9801
# Seed set to 3176
# Seed set to 5263
# Seed set to 9095
# Seed set to 3683
# Seed set to 7750
# Seed set to 1535
# Seed set to 6958
# Seed set to 7993
# Seed set to 5558
# Seed set to 3967
# Seed set to 412
# Seed set to 2622
# Seed set to 9343
# Seed set to 2466
# Seed set to 4628
# Seed set to 3857
# Seed set to 6573
# Seed set to 7637
# Seed set to 9134
# Seed set to 2709
# Seed set to 4640
# Seed set to 6623
# Seed set to 2832
# Seed set to 6673
# Seed set to 2296
# Seed set to 4502
# Seed set to 2328
# Seed set to 729
# Seed set to 2287
# Seed set to 187
# Seed set to 6840
# Seed set to 6600
# Seed set to 223
# Seed set to 6770
# Seed set to 6236
# Seed set to 8498
# Seed set to 723
# Seed set to 3996
# Seed set to 2575
# Seed set to 1805
# Seed set to 8232
# Seed set to 5540
# Seed set to 6011
# Seed set to 3644
# Seed set to 8550
# Seed set to 4973
# Seed set to 313
# Seed set to 4208
# Seed set to 2713
# Seed set to 1875
# Seed set to 3254
# Seed set to 7777
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.0001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 8232, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 1859
# Seed set to 5567
# Seed set to 464
# Seed set to 1998
# Seed set to 5799
# Seed set to 3519
# Seed set to 6742
# Seed set to 5139
# Seed set to 1084
# Seed set to 2181
# windspeedfortaleza.txt
# Seed set to 746
# Seed set to 5053
# Seed set to 8241
# Seed set to 1121
# Seed set to 8091
# Seed set to 7110
# Seed set to 8079
# Seed set to 5052
# Seed set to 5081
# Seed set to 9636
# Seed set to 4103
# Seed set to 6335
# Seed set to 412
# Seed set to 2622
# Seed set to 9343
# Seed set to 2466
# Seed set to 4628
# Seed set to 3857
# Seed set to 6573
# Seed set to 7637
# Seed set to 9134
# Seed set to 2709
# Seed set to 4640
# Seed set to 6623
# Seed set to 2832
# Seed set to 6673
# Seed set to 2296
# Seed set to 4502
# Seed set to 2328
# Seed set to 729
# Seed set to 2287
# Seed set to 187
# Seed set to 6840
# Seed set to 6600
# Seed set to 223
# Seed set to 6770
# Seed set to 6236
# Seed set to 8498
# Seed set to 723
# Seed set to 3996
# Seed set to 2575
# Seed set to 1805
# Seed set to 8232
# Seed set to 5540
# Seed set to 6011
# Seed set to 3644
# Seed set to 8550
# Seed set to 4973
# Seed set to 313
# Seed set to 4208
# Seed set to 2713
# Seed set to 1875
# Seed set to 3254
# Seed set to 7777
# Seed set to 1859
# Seed set to 5567
# Seed set to 464
# Seed set to 1998
# Seed set to 5799
# Seed set to 3519
# Seed set to 6742
# Seed set to 5139
# Seed set to 1084
# Seed set to 2181
# Seed set to 746
# Seed set to 5053
# Seed set to 8241
# Seed set to 1121
# Seed set to 8091
# Seed set to 7110
# Seed set to 8079
# Seed set to 5052
# Seed set to 5081
# Seed set to 9636
# Seed set to 4103
# Seed set to 6335
# Seed set to 412
# Seed set to 2622
# Seed set to 9343
# Seed set to 2466
# Seed set to 4628
# Seed set to 3857
# Seed set to 6573
# Seed set to 7637
# Seed set to 9134
# Seed set to 2709
# Seed set to 4640
# Seed set to 6623
# Seed set to 2832
# Seed set to 6673
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 723, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 2296
# Seed set to 4502
# Seed set to 2328
# Seed set to 729
# Seed set to 2287
# Seed set to 187
# Seed set to 6840
# Seed set to 6600
# Seed set to 223
# Seed set to 6770
# irradiancesalvador.txt
# Seed set to 5512
# Seed set to 6546
# Seed set to 3313
# Seed set to 5445
# Seed set to 290
# Seed set to 8997
# Seed set to 5029
# Seed set to 1805
# Seed set to 4536
# Seed set to 1001
# Seed set to 3684
# Seed set to 2790
# Seed set to 2100
# Seed set to 9550
# Seed set to 3266
# Seed set to 2997
# Seed set to 1859
# Seed set to 2747
# Seed set to 2419
# Seed set to 915
# Seed set to 744
# Seed set to 6737
# Seed set to 5983
# Seed set to 5829
# Seed set to 7211
# Seed set to 241
# Seed set to 822
# Seed set to 9860
# Seed set to 5073
# Seed set to 2351
# Seed set to 4923
# Seed set to 3168
# Seed set to 7500
# Seed set to 6036
# Seed set to 3794
# Seed set to 6606
# Seed set to 212
# Seed set to 7949
# Seed set to 8579
# Seed set to 4240
# Seed set to 21
# Seed set to 8881
# Seed set to 4486
# Seed set to 9971
# Seed set to 5975
# Seed set to 1827
# Seed set to 1488
# Seed set to 1616
# Seed set to 2866
# Seed set to 4666
# Seed set to 7744
# Seed set to 3194
# Seed set to 9565
# Seed set to 2782
# Seed set to 2574
# Seed set to 8630
# Seed set to 6180
# Seed set to 9823
# Seed set to 3676
# Seed set to 7481
# Seed set to 1121
# Seed set to 9575
# Seed set to 7886
# Seed set to 521
# Seed set to 6526
# Seed set to 7740
# Seed set to 2259
# Seed set to 2423
# Seed set to 1770
# Seed set to 8275
# Seed set to 4704
# Seed set to 6071
# Seed set to 9095
# Seed set to 377
# Seed set to 2245
# Seed set to 2686
# Seed set to 2553
# Seed set to 5225
# Seed set to 2512
# Seed set to 6512
# Seed set to 7419
# Seed set to 8286
# Seed set to 2067
# Seed set to 1448
# Seed set to 4438
# Seed set to 9394
# Seed set to 5163
# Seed set to 9273
# Seed set to 4798
# Seed set to 3290
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 2419, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 1921
# Seed set to 8866
# Seed set to 1682
# Seed set to 8113
# Seed set to 4887
# Seed set to 1362
# Seed set to 4621
# Seed set to 7124
# Seed set to 507
# Seed set to 5142
# irradiancefortaleza.txt
# Seed set to 1136
# Seed set to 6957
# Seed set to 7484
# Seed set to 8284
# Seed set to 8674
# Seed set to 6722
# Seed set to 9301
# Seed set to 4440
# Seed set to 9502
# Seed set to 6657
# Seed set to 6579
# Seed set to 5203
# Seed set to 9115
# Seed set to 7742
# Seed set to 1747
# Seed set to 243
# Seed set to 9052
# Seed set to 2892
# Seed set to 5121
# Seed set to 2103
# Seed set to 1728
# Seed set to 3303
# Seed set to 6310
# Seed set to 8272
# Seed set to 8631
# Seed set to 444
# Seed set to 4185
# Seed set to 9828
# Seed set to 1067
# Seed set to 4501
# Seed set to 9878
# Seed set to 2010
# Seed set to 9257
# Seed set to 5265
# Seed set to 986
# Seed set to 1487
# Seed set to 9383
# Seed set to 4897
# Seed set to 3895
# Seed set to 6025
# Seed set to 800
# Seed set to 7430
# Seed set to 7376
# Seed set to 6932
# Seed set to 3552
# Seed set to 9356
# Seed set to 5175
# Seed set to 4756
# Seed set to 87
# Seed set to 2312
# Seed set to 5882
# Seed set to 7613
# Seed set to 5331
# Seed set to 5708
# Seed set to 2140
# Seed set to 2352
# Seed set to 5079
# Seed set to 8517
# Seed set to 4278
# Seed set to 5975
# Seed set to 1827
# Seed set to 1488
# Seed set to 1616
# Seed set to 2866
# Seed set to 4666
# Seed set to 7744
# Seed set to 3194
# Seed set to 9565
# Seed set to 2782
# Seed set to 2574
# Seed set to 8630
# Seed set to 6180
# Seed set to 9823
# Seed set to 3676
# Seed set to 7481
# Seed set to 1121
# Seed set to 9575
# Seed set to 7886
# Seed set to 521
# Seed set to 6526
# Seed set to 7740
# Seed set to 2259
# Seed set to 2423
# Seed set to 1770
# Seed set to 8275
# Seed set to 4704
# Seed set to 6071
# Seed set to 9095
# Seed set to 377
# Seed set to 2245
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 9502, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 2686
# Seed set to 2553
# Seed set to 5225
# Seed set to 2512
# Seed set to 6512
# Seed set to 7419
# Seed set to 8286
# Seed set to 2067
# Seed set to 1448
# Seed set to 4438
# irradiancefloripa.txt
# Seed set to 9394
# Seed set to 5163
# Seed set to 9273
# Seed set to 4798
# Seed set to 3290
# Seed set to 1921
# Seed set to 8866
# Seed set to 1682
# Seed set to 8113
# Seed set to 4887
# Seed set to 1362
# Seed set to 4621
# Seed set to 7124
# Seed set to 507
# Seed set to 5142
# Seed set to 1136
# Seed set to 6957
# Seed set to 7484
# Seed set to 8284
# Seed set to 8674
# Seed set to 6722
# Seed set to 9301
# Seed set to 4440
# Seed set to 9502
# Seed set to 6657
# Seed set to 6579
# Seed set to 5203
# Seed set to 9115
# Seed set to 7742
# Seed set to 1747
# Seed set to 243
# Seed set to 9052
# Seed set to 2892
# Seed set to 5121
# Seed set to 2103
# Seed set to 1728
# Seed set to 3303
# Seed set to 6310
# Seed set to 8272
# Seed set to 8631
# Seed set to 444
# Seed set to 4185
# Seed set to 9828
# Seed set to 1067
# Seed set to 4501
# Seed set to 9878
# Seed set to 2010
# Seed set to 9257
# Seed set to 5265
# Seed set to 986
# Seed set to 1487
# Seed set to 9383
# Seed set to 4897
# Seed set to 3895
# Seed set to 6025
# Seed set to 800
# Seed set to 7430
# Seed set to 7376
# Seed set to 6932
# Seed set to 3552
# Seed set to 9356
# Seed set to 5175
# Seed set to 4756
# Seed set to 87
# Seed set to 2312
# Seed set to 5882
# Seed set to 7613
# Seed set to 5331
# Seed set to 5708
# Seed set to 2140
# Seed set to 2352
# Seed set to 5079
# Seed set to 8517
# Seed set to 4278
# Seed set to 5975
# Seed set to 1827
# Seed set to 1488
# Seed set to 1616
# Seed set to 2866
# Seed set to 4666
# Seed set to 7744
# Seed set to 3194
# Seed set to 9565
# Seed set to 2782
# Seed set to 2574
# Seed set to 8630
# Seed set to 6180
# Seed set to 9823
# Seed set to 3676
# Seed set to 7481
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 8284, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 1121
# Seed set to 9575
# Seed set to 7886
# Seed set to 521
# Seed set to 6526
# Seed set to 7740
# Seed set to 2259
# Seed set to 2423
# Seed set to 1770
# Seed set to 8275
# irradiancesp.txt
# Seed set to 7760
# Seed set to 160
# Seed set to 8425
# Seed set to 5910
# Seed set to 7466
# Seed set to 3382
# Seed set to 3132
# Seed set to 1538
# Seed set to 2624
# Seed set to 1366
# Seed set to 5454
# Seed set to 1404
# Seed set to 2886
# Seed set to 8006
# Seed set to 9069
# Seed set to 3345
# Seed set to 5610
# Seed set to 9374
# Seed set to 4223
# Seed set to 1607
# Seed set to 1787
# Seed set to 1133
# Seed set to 2799
# Seed set to 6381
# Seed set to 5984
# Seed set to 7411
# Seed set to 5468
# Seed set to 9018
# Seed set to 6596
# Seed set to 1177
# Seed set to 3595
# Seed set to 2694
# Seed set to 3647
# Seed set to 1675
# Seed set to 183
# Seed set to 9272
# Seed set to 3782
# Seed set to 8662
# Seed set to 5007
# Seed set to 9910
# Seed set to 2859
# Seed set to 4098
# Seed set to 2077
# Seed set to 5288
# Seed set to 7210
# Seed set to 9003
# Seed set to 1902
# Seed set to 8227
# Seed set to 4271
# Seed set to 5374
# Seed set to 3253
# Seed set to 4722
# Seed set to 7410
# Seed set to 2377
# Seed set to 6227
# Seed set to 43
# Seed set to 1137
# Seed set to 6440
# Seed set to 259
# Seed set to 9811
# Seed set to 5337
# Seed set to 5289
# Seed set to 7160
# Seed set to 4817
# Seed set to 2234
# Seed set to 1200
# Seed set to 9438
# Seed set to 795
# Seed set to 7600
# Seed set to 2104
# Seed set to 6650
# Seed set to 1745
# Seed set to 1982
# Seed set to 9971
# Seed set to 4297
# Seed set to 7231
# Seed set to 5500
# Seed set to 5760
# Seed set to 9209
# Seed set to 254
# Seed set to 4522
# Seed set to 8032
# Seed set to 6238
# Seed set to 7926
# Seed set to 7852
# Seed set to 6594
# Seed set to 5722
# Seed set to 2843
# Seed set to 6904
# Seed set to 6560
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 5007, 'input_size': 17, 'logger': False, 'default_root_dir': None}
# Seed set to 5622
# Seed set to 2989
# Seed set to 7181
# Seed set to 3766
# Seed set to 8609
# Seed set to 6519
# Seed set to 7503
# Seed set to 3472
# Seed set to 5626
# Seed set to 959
# coloradoRiver.txt
# Seed set to 2972
# Seed set to 9449
# Seed set to 4431
# Seed set to 4234
# Seed set to 5085
# Seed set to 1024
# Seed set to 457
# Seed set to 3770
# Seed set to 6710
# Seed set to 8168
# Seed set to 3911
# Seed set to 3358
# Seed set to 5358
# Seed set to 6201
# Seed set to 294
# Seed set to 8112
# Seed set to 811
# Seed set to 7604
# Seed set to 2284
# Seed set to 6895
# Seed set to 6771
# Seed set to 4610
# Seed set to 3004
# Seed set to 2681
# Seed set to 6008
# Seed set to 2536
# Seed set to 9380
# Seed set to 4946
# Seed set to 9372
# Seed set to 8897
# Seed set to 699
# Seed set to 5328
# Seed set to 4089
# Seed set to 7964
# Seed set to 3113
# Seed set to 4255
# Seed set to 9413
# Seed set to 9373
# Seed set to 8100
# Seed set to 6798
# Seed set to 1283
# Seed set to 7524
# Seed set to 265
# Seed set to 4321
# Seed set to 4359
# Seed set to 3400
# Seed set to 4634
# Seed set to 4074
# Seed set to 2350
# Seed set to 3087
# Seed set to 1448
# Seed set to 9891
# Seed set to 5653
# Seed set to 4779
# Seed set to 2862
# Seed set to 4646
# Seed set to 6119
# Seed set to 1121
# Seed set to 2906
# Seed set to 9974
# Seed set to 3549
# Seed set to 255
# Seed set to 964
# Seed set to 3309
# Seed set to 5132
# Seed set to 5189
# Seed set to 1193
# Seed set to 7090
# Seed set to 5509
# Seed set to 2043
# Seed set to 7022
# Seed set to 2490
# Seed set to 8241
# Seed set to 7036
# Seed set to 9930
# Seed set to 7287
# Seed set to 9986
# Seed set to 1304
# Seed set to 5241
# Seed set to 586
# Seed set to 4372
# Seed set to 9649
# Seed set to 5308
# Seed set to 4455
# Seed set to 8057
# Seed set to 3661
# Seed set to 9953
# Seed set to 9798
# Seed set to 6094
# Seed set to 429
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 8100, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 3938
# Seed set to 4734
# Seed set to 5359
# Seed set to 9469
# Seed set to 1484
# Seed set to 6677
# Seed set to 5841
# Seed set to 539
# Seed set to 7604
# Seed set to 2284
# sunspot.txt
# Seed set to 997
# Seed set to 9689
# Seed set to 8399
# Seed set to 3316
# Seed set to 9677
# Seed set to 7077
# Seed set to 6116
# Seed set to 5605
# Seed set to 4339
# Seed set to 4824
# Seed set to 6974
# Seed set to 7164
# Seed set to 1480
# Seed set to 6272
# Seed set to 2012
# Seed set to 2087
# Seed set to 9232
# Seed set to 7351
# Seed set to 6226
# Seed set to 745
# Seed set to 9374
# Seed set to 669
# Seed set to 6592
# Seed set to 4355
# Seed set to 5333
# Seed set to 9273
# Seed set to 7371
# Seed set to 2996
# Seed set to 8507
# Seed set to 6158
# Seed set to 8714
# Seed set to 1113
# Seed set to 7483
# Seed set to 8947
# Seed set to 1597
# Seed set to 5446
# Seed set to 7049
# Seed set to 5844
# Seed set to 9778
# Seed set to 1637
# Seed set to 4335
# Seed set to 8901
# Seed set to 4159
# Seed set to 9549
# Seed set to 9461
# Seed set to 7870
# Seed set to 8772
# Seed set to 935
# Seed set to 4859
# Seed set to 2132
# Seed set to 3310
# Seed set to 6122
# Seed set to 6688
# Seed set to 3518
# Seed set to 1750
# Seed set to 5712
# Seed set to 6092
# Seed set to 8874
# Seed set to 9359
# Seed set to 9604
# Seed set to 3510
# Seed set to 298
# Seed set to 3787
# Seed set to 8205
# Seed set to 7523
# Seed set to 2627
# Seed set to 5
# Seed set to 3452
# Seed set to 1523
# Seed set to 9663
# Seed set to 3648
# Seed set to 4009
# Seed set to 4790
# Seed set to 2440
# Seed set to 5508
# Seed set to 1782
# Seed set to 8187
# Seed set to 3816
# Seed set to 1167
# Seed set to 546
# Seed set to 6455
# Seed set to 6798
# Seed set to 597
# Seed set to 1856
# Seed set to 8568
# Seed set to 9853
# Seed set to 6862
# Seed set to 7602
# Seed set to 2935
# Seed set to 9512
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 6226, 'input_size': 9, 'logger': False, 'default_root_dir': None}
# Seed set to 9006
# Seed set to 4999
# Seed set to 4844
# Seed set to 891
# Seed set to 935
# Seed set to 4859
# Seed set to 2132
# Seed set to 3310
# Seed set to 6122
# Seed set to 6688
# milk.txt
# Seed set to 1793
# Seed set to 1179
# Seed set to 9931
# Seed set to 9105
# Seed set to 1308
# Seed set to 1625
# Seed set to 1783
# Seed set to 4124
# Seed set to 7925
# Seed set to 2258
# Seed set to 1424
# Seed set to 6430
# Seed set to 1746
# Seed set to 9153
# Seed set to 3699
# Seed set to 8355
# Seed set to 3186
# Seed set to 9327
# Seed set to 8238
# Seed set to 7013
# Seed set to 4180
# Seed set to 9889
# Seed set to 8964
# Seed set to 745
# Seed set to 7263
# Seed set to 4651
# Seed set to 6288
# Seed set to 4395
# Seed set to 7343
# Seed set to 8740
# Seed set to 4773
# Seed set to 4825
# Seed set to 9468
# Seed set to 2056
# Seed set to 9271
# Seed set to 4936
# Seed set to 8814
# Seed set to 5367
# Seed set to 803
# Seed set to 2896
# Seed set to 2051
# Seed set to 6602
# Seed set to 1229
# Seed set to 816
# Seed set to 4639
# Seed set to 7737
# Seed set to 5478
# Seed set to 1766
# Seed set to 558
# Seed set to 2677
# Seed set to 2139
# Seed set to 3605
# Seed set to 6646
# Seed set to 4117
# Seed set to 485
# Seed set to 8845
# Seed set to 8357
# Seed set to 2206
# Seed set to 133
# Seed set to 665
# Seed set to 7471
# Seed set to 9244
# Seed set to 6723
# Seed set to 6290
# Seed set to 3255
# Seed set to 9034
# Seed set to 8950
# Seed set to 2179
# Seed set to 3273
# Seed set to 3988
# Seed set to 8128
# Seed set to 5992
# Seed set to 1402
# Seed set to 9051
# Seed set to 6471
# Seed set to 3621
# Seed set to 8322
# Seed set to 7027
# Seed set to 5630
# Seed set to 6038
# Seed set to 9725
# Seed set to 1269
# Seed set to 5932
# Seed set to 444
# Seed set to 1109
# Seed set to 2276
# Seed set to 4763
# Seed set to 4745
# Seed set to 9448
# Seed set to 5755
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 8238, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 9258
# Seed set to 1515
# Seed set to 5738
# Seed set to 456
# Seed set to 8502
# Seed set to 4376
# Seed set to 9474
# Seed set to 4932
# Seed set to 4055
# Seed set to 3672
# Unemployment.txt
# Seed set to 8390
# Seed set to 1052
# Seed set to 1935
# Seed set to 6605
# Seed set to 3258
# Seed set to 871
# Seed set to 585
# Seed set to 8734
# Seed set to 6976
# Seed set to 3344
# Seed set to 6443
# Seed set to 9246
# Seed set to 4444
# Seed set to 8293
# Seed set to 1979
# Seed set to 6840
# Seed set to 9566
# Seed set to 9163
# Seed set to 9361
# Seed set to 2305
# Seed set to 8134
# Seed set to 5994
# Seed set to 3914
# Seed set to 3618
# Seed set to 7715
# Seed set to 9364
# Seed set to 6468
# Seed set to 3544
# Seed set to 1781
# Seed set to 4933
# Seed set to 9047
# Seed set to 5130
# Seed set to 4522
# Seed set to 1652
# Seed set to 1487
# Seed set to 1213
# Seed set to 9674
# Seed set to 7441
# Seed set to 9855
# Seed set to 312
# Seed set to 6333
# Seed set to 7396
# Seed set to 1925
# Seed set to 6206
# Seed set to 3660
# Seed set to 5485
# Seed set to 1632
# Seed set to 924
# Seed set to 3923
# Seed set to 7784
# Seed set to 8605
# Seed set to 8569
# Seed set to 2896
# Seed set to 740
# Seed set to 3755
# Seed set to 5429
# Seed set to 8264
# Seed set to 6469
# Seed set to 3227
# Seed set to 110
# Seed set to 2182
# Seed set to 6850
# Seed set to 6096
# Seed set to 7290
# Seed set to 3508
# Seed set to 8691
# Seed set to 3482
# Seed set to 4905
# Seed set to 6877
# Seed set to 2396
# Seed set to 2143
# Seed set to 4720
# Seed set to 2348
# Seed set to 1431
# Seed set to 7825
# Seed set to 2799
# Seed set to 1075
# Seed set to 2343
# Seed set to 985
# Seed set to 5130
# Seed set to 4522
# Seed set to 1652
# Seed set to 1487
# Seed set to 1213
# Seed set to 9674
# Seed set to 7441
# Seed set to 9855
# Seed set to 312
# Seed set to 6333
# Seed set to 7396
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 9855, 'input_size': 18, 'logger': False, 'default_root_dir': None}
# Seed set to 1925
# Seed set to 6206
# Seed set to 3660
# Seed set to 5485
# Seed set to 1632
# Seed set to 924
# Seed set to 3923
# Seed set to 7784
# Seed set to 8605
# Seed set to 8569
# ausbee.txt
# Seed set to 5276
# Seed set to 1411
# Seed set to 9097
# Seed set to 3676
# Seed set to 4315
# Seed set to 712
# Seed set to 599
# Seed set to 5585
# Seed set to 6741
# Seed set to 3311
# Seed set to 3203
# Seed set to 789
# Seed set to 5653
# Seed set to 6401
# Seed set to 5636
# Seed set to 7293
# Seed set to 8257
# Seed set to 3070
# Seed set to 150
# Seed set to 5288
# Seed set to 2879
# Seed set to 4738
# Seed set to 2151
# Seed set to 445
# Seed set to 8174
# Seed set to 7629
# Seed set to 1526
# Seed set to 9886
# Seed set to 6321
# Seed set to 7733
# Seed set to 9980
# Seed set to 4459
# Seed set to 3561
# Seed set to 1078
# Seed set to 9790
# Seed set to 7578
# Seed set to 5434
# Seed set to 2151
# Seed set to 445
# Seed set to 8174
# Seed set to 7629
# Seed set to 1526
# Seed set to 9886
# Seed set to 6321
# Seed set to 7733
# Seed set to 9980
# Seed set to 4459
# Seed set to 3561
# Seed set to 1078
# Seed set to 9790
# Seed set to 7578
# Seed set to 5434
# Seed set to 2151
# Seed set to 445
# Seed set to 8174
# Seed set to 7629
# Seed set to 1526
# Seed set to 9886
# Seed set to 6321
# Seed set to 7733
# Seed set to 9980
# Seed set to 4459
# Seed set to 3561
# Seed set to 1078
# Seed set to 9790
# Seed set to 7578
# Seed set to 5434
# Seed set to 2151
# Seed set to 445
# Seed set to 8174
# Seed set to 7629
# Seed set to 1526
# Seed set to 9886
# Seed set to 6321
# Seed set to 7733
# Seed set to 9980
# Seed set to 4459
# Seed set to 3561
# Seed set to 1078
# Seed set to 9790
# Seed set to 7578
# Seed set to 5434
# Seed set to 2151
# Seed set to 445
# Seed set to 8174
# Seed set to 7629
# Seed set to 1526
# Seed set to 9886
# Seed set to 6321
# Seed set to 7733
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 150, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 9980
# Seed set to 4459
# Seed set to 3561
# Seed set to 1078
# Seed set to 9790
# Seed set to 7578
# Seed set to 5434
# Seed set to 2151
# Seed set to 445
# Seed set to 8174
# austres.txt
# Seed set to 9891
# Seed set to 9865
# Seed set to 5417
# Seed set to 122
# Seed set to 7952
# Seed set to 8700
# Seed set to 2569
# Seed set to 4997
# Seed set to 5173
# Seed set to 289
# Seed set to 243
# Seed set to 6407
# Seed set to 1564
# Seed set to 3892
# Seed set to 5005
# Seed set to 2992
# Seed set to 3758
# Seed set to 7281
# Seed set to 4804
# Seed set to 948
# Seed set to 303
# Seed set to 166
# Seed set to 1019
# Seed set to 7424
# Seed set to 8400
# Seed set to 6472
# Seed set to 4653
# Seed set to 8382
# Seed set to 5287
# Seed set to 8149
# Seed set to 2951
# Seed set to 6674
# Seed set to 8726
# Seed set to 4251
# Seed set to 3542
# Seed set to 224
# Seed set to 5112
# Seed set to 7885
# Seed set to 1782
# Seed set to 9830
# Seed set to 4414
# Seed set to 5992
# Seed set to 6854
# Seed set to 8113
# Seed set to 6675
# Seed set to 7469
# Seed set to 4397
# Seed set to 8232
# Seed set to 2695
# Seed set to 9761
# Seed set to 2366
# Seed set to 7964
# Seed set to 2935
# Seed set to 8759
# Seed set to 7425
# Seed set to 7841
# Seed set to 9202
# Seed set to 6354
# Seed set to 3228
# Seed set to 1303
# Seed set to 9085
# Seed set to 9229
# Seed set to 9505
# Seed set to 2887
# Seed set to 2613
# Seed set to 5289
# Seed set to 9519
# Seed set to 2532
# Seed set to 5921
# Seed set to 4162
# Seed set to 2182
# Seed set to 8484
# Seed set to 1931
# Seed set to 9745
# Seed set to 9043
# Seed set to 2498
# Seed set to 2437
# Seed set to 9266
# Seed set to 1674
# Seed set to 3619
# Seed set to 3428
# Seed set to 2815
# Seed set to 1373
# Seed set to 6183
# Seed set to 638
# Seed set to 3585
# Seed set to 2112
# Seed set to 1619
# Seed set to 6128
# Seed set to 4546
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 2695, 'input_size': 13, 'logger': False, 'default_root_dir': None}
# Seed set to 9589
# Seed set to 5658
# Seed set to 7969
# Seed set to 5963
# Seed set to 4002
# Seed set to 3796
# Seed set to 3745
# Seed set to 1818
# Seed set to 4241
# Seed set to 7911
# heartrate.txt
# Seed set to 621
# Seed set to 3222
# Seed set to 2196
# Seed set to 9118
# Seed set to 732
# Seed set to 9796
# Seed set to 1170
# Seed set to 6311
# Seed set to 7386
# Seed set to 292
# Seed set to 7978
# Seed set to 6050
# Seed set to 5391
# Seed set to 4506
# Seed set to 4290
# Seed set to 5760
# Seed set to 7661
# Seed set to 1677
# Seed set to 5650
# Seed set to 4891
# Seed set to 6699
# Seed set to 7222
# Seed set to 7241
# Seed set to 2472
# Seed set to 154
# Seed set to 2848
# Seed set to 652
# Seed set to 9258
# Seed set to 5606
# Seed set to 492
# Seed set to 2364
# Seed set to 426
# Seed set to 6145
# Seed set to 8606
# Seed set to 5527
# Seed set to 70
# Seed set to 6061
# Seed set to 2570
# Seed set to 4329
# Seed set to 3358
# Seed set to 3819
# Seed set to 4695
# Seed set to 8467
# Seed set to 9953
# Seed set to 6537
# Seed set to 1382
# Seed set to 2204
# Seed set to 1083
# Seed set to 6853
# Seed set to 9862
# Seed set to 3493
# Seed set to 5097
# Seed set to 4697
# Seed set to 2040
# Seed set to 6512
# Seed set to 6325
# Seed set to 9824
# Seed set to 5369
# Seed set to 631
# Seed set to 7058
# Seed set to 4680
# Seed set to 6157
# Seed set to 7233
# Seed set to 6686
# Seed set to 8013
# Seed set to 5080
# Seed set to 6081
# Seed set to 5977
# Seed set to 4947
# Seed set to 9561
# Seed set to 2395
# Seed set to 8203
# Seed set to 8720
# Seed set to 5516
# Seed set to 1245
# Seed set to 9430
# Seed set to 5681
# Seed set to 7133
# Seed set to 9589
# Seed set to 3926
# Seed set to 8723
# Seed set to 3761
# Seed set to 6211
# Seed set to 5372
# Seed set to 8924
# Seed set to 4248
# Seed set to 9457
# Seed set to 4307
# Seed set to 5745
# Seed set to 107
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.0001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 9589, 'input_size': 2, 'logger': False, 'default_root_dir': None}
# Seed set to 6504
# Seed set to 1445
# Seed set to 8243
# Seed set to 1531
# Seed set to 9363
# Seed set to 9056
# Seed set to 286
# Seed set to 6229
# Seed set to 5
# Seed set to 9594
# ozon.txt
# Seed set to 4097
# Seed set to 6736
# Seed set to 7289
# Seed set to 4558
# Seed set to 9055
# Seed set to 5687
# Seed set to 704
# Seed set to 3228
# Seed set to 3858
# Seed set to 8332
# Seed set to 805
# Seed set to 5268
# Seed set to 8654
# Seed set to 3515
# Seed set to 3762
# Seed set to 1874
# Seed set to 5152
# Seed set to 1330
# Seed set to 4008
# Seed set to 1339
# Seed set to 7407
# Seed set to 2681
# Seed set to 1392
# Seed set to 6377
# Seed set to 6810
# Seed set to 6936
# Seed set to 2912
# Seed set to 6403
# Seed set to 2901
# Seed set to 8048
# Seed set to 805
# Seed set to 5268
# Seed set to 8654
# Seed set to 3515
# Seed set to 3762
# Seed set to 1874
# Seed set to 5152
# Seed set to 1330
# Seed set to 4008
# Seed set to 1339
# Seed set to 7407
# Seed set to 2681
# Seed set to 1392
# Seed set to 6377
# Seed set to 6810
# Seed set to 6936
# Seed set to 2912
# Seed set to 6403
# Seed set to 2901
# Seed set to 8048
# Seed set to 805
# Seed set to 5268
# Seed set to 8654
# Seed set to 3515
# Seed set to 3762
# Seed set to 1874
# Seed set to 5152
# Seed set to 1330
# Seed set to 4008
# Seed set to 1339
# Seed set to 7407
# Seed set to 2681
# Seed set to 1392
# Seed set to 6377
# Seed set to 6810
# Seed set to 6936
# Seed set to 2912
# Seed set to 6403
# Seed set to 2901
# Seed set to 8048
# Seed set to 805
# Seed set to 5268
# Seed set to 8654
# Seed set to 3515
# Seed set to 3762
# Seed set to 1874
# Seed set to 5152
# Seed set to 1330
# Seed set to 4008
# Seed set to 1339
# Seed set to 7407
# Seed set to 2681
# Seed set to 1392
# Seed set to 6377
# Seed set to 6810
# Seed set to 6936
# Seed set to 2912
# Seed set to 6403
# Seed set to 2901
# Seed set to 8048
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.0001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 2901, 'input_size': 12, 'logger': False, 'default_root_dir': None}
# Seed set to 805
# Seed set to 5268
# Seed set to 8654
# Seed set to 3515
# Seed set to 3762
# Seed set to 1874
# Seed set to 5152
# Seed set to 1330
# Seed set to 4008
# Seed set to 1339
# pollution.txt
# Seed set to 5909
# Seed set to 2679
# Seed set to 1603
# Seed set to 485
# Seed set to 7582
# Seed set to 5764
# Seed set to 2881
# Seed set to 6169
# Seed set to 7843
# Seed set to 5134
# Seed set to 1617
# Seed set to 9513
# Seed set to 2307
# Seed set to 5902
# Seed set to 3936
# Seed set to 2125
# Seed set to 1266
# Seed set to 7293
# Seed set to 2254
# Seed set to 8206
# Seed set to 5367
# Seed set to 6004
# Seed set to 1633
# Seed set to 5497
# Seed set to 3317
# Seed set to 2297
# Seed set to 9851
# Seed set to 7094
# Seed set to 5081
# Seed set to 3161
# Seed set to 2038
# Seed set to 2136
# Seed set to 682
# Seed set to 2659
# Seed set to 3117
# Seed set to 8719
# Seed set to 8207
# Seed set to 6100
# Seed set to 4673
# Seed set to 6038
# Seed set to 9829
# Seed set to 844
# Seed set to 5192
# Seed set to 3241
# Seed set to 3565
# Seed set to 6040
# Seed set to 6122
# Seed set to 3792
# Seed set to 6243
# Seed set to 4746
# Seed set to 5626
# Seed set to 7241
# Seed set to 8283
# Seed set to 5302
# Seed set to 7245
# Seed set to 9738
# Seed set to 3171
# Seed set to 3405
# Seed set to 7213
# Seed set to 3621
# Seed set to 1190
# Seed set to 6623
# Seed set to 6294
# Seed set to 3800
# Seed set to 8013
# Seed set to 6672
# Seed set to 7017
# Seed set to 2516
# Seed set to 1107
# Seed set to 2068
# Seed set to 509
# Seed set to 8130
# Seed set to 8387
# Seed set to 3631
# Seed set to 7476
# Seed set to 1143
# Seed set to 4851
# Seed set to 6028
# Seed set to 6397
# Seed set to 1579
# Seed set to 4848
# Seed set to 4273
# Seed set to 6871
# Seed set to 5354
# Seed set to 4161
# Seed set to 1501
# Seed set to 5652
# Seed set to 4189
# Seed set to 1962
# Seed set to 8701
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 4673, 'input_size': 10, 'logger': False, 'default_root_dir': None}
# Seed set to 1610
# Seed set to 6738
# Seed set to 5786
# Seed set to 7162
# Seed set to 9287
# Seed set to 406
# Seed set to 6930
# Seed set to 9307
# Seed set to 9160
# Seed set to 3742
# redwine.txt
# Seed set to 8342
# Seed set to 5041
# Seed set to 7628
# Seed set to 8409
# Seed set to 8158
# Seed set to 1111
# Seed set to 5321
# Seed set to 6749
# Seed set to 5552
# Seed set to 465
# Seed set to 5601
# Seed set to 2422
# Seed set to 2672
# Seed set to 2842
# Seed set to 1318
# Seed set to 9301
# Seed set to 1219
# Seed set to 3439
# Seed set to 4195
# Seed set to 1880
# Seed set to 7644
# Seed set to 4764
# Seed set to 1682
# Seed set to 4138
# Seed set to 5414
# Seed set to 4610
# Seed set to 1808
# Seed set to 1933
# Seed set to 8571
# Seed set to 4841
# Seed set to 5968
# Seed set to 2352
# Seed set to 6337
# Seed set to 867
# Seed set to 6124
# Seed set to 9451
# Seed set to 1261
# Seed set to 2400
# Seed set to 9239
# Seed set to 5410
# Seed set to 7845
# Seed set to 9039
# Seed set to 8765
# Seed set to 1058
# Seed set to 7960
# Seed set to 8919
# Seed set to 3784
# Seed set to 5071
# Seed set to 1303
# Seed set to 2589
# Seed set to 4284
# Seed set to 110
# Seed set to 488
# Seed set to 2458
# Seed set to 178
# Seed set to 3522
# Seed set to 3967
# Seed set to 9836
# Seed set to 7201
# Seed set to 7734
# Seed set to 553
# Seed set to 7830
# Seed set to 8877
# Seed set to 1045
# Seed set to 1758
# Seed set to 8701
# Seed set to 1293
# Seed set to 3217
# Seed set to 2943
# Seed set to 9429
# Seed set to 269
# Seed set to 1112
# Seed set to 218
# Seed set to 126
# Seed set to 8309
# Seed set to 4904
# Seed set to 4356
# Seed set to 3139
# Seed set to 9645
# Seed set to 5530
# Seed set to 4977
# Seed set to 9583
# Seed set to 3171
# Seed set to 4254
# Seed set to 802
# Seed set to 3931
# Seed set to 5641
# Seed set to 8191
# Seed set to 1785
# Seed set to 9734
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 8571, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 3991
# Seed set to 20
# Seed set to 5371
# Seed set to 5231
# Seed set to 1150
# Seed set to 9332
# Seed set to 6383
# Seed set to 9580
# Seed set to 4059
# Seed set to 1341
# gasoline.txt
# Seed set to 7144
# Seed set to 1311
# Seed set to 1674
# Seed set to 9793
# Seed set to 1551
# Seed set to 5011
# Seed set to 5150
# Seed set to 5956
# Seed set to 2428
# Seed set to 1456
# Seed set to 2470
# Seed set to 6351
# Seed set to 6603
# Seed set to 6072
# Seed set to 9135
# Seed set to 3583
# Seed set to 3953
# Seed set to 7064
# Seed set to 7596
# Seed set to 9484
# Seed set to 26
# Seed set to 4587
# Seed set to 9725
# Seed set to 7359
# Seed set to 4096
# Seed set to 6163
# Seed set to 9270
# Seed set to 1223
# Seed set to 9925
# Seed set to 2101
# Seed set to 1942
# Seed set to 1006
# Seed set to 1759
# Seed set to 1697
# Seed set to 8565
# Seed set to 6713
# Seed set to 3296
# Seed set to 7352
# Seed set to 1007
# Seed set to 7262
# Seed set to 1205
# Seed set to 5090
# Seed set to 4035
# Seed set to 2591
# Seed set to 1413
# Seed set to 574
# Seed set to 8305
# Seed set to 1014
# Seed set to 728
# Seed set to 2729
# Seed set to 2636
# Seed set to 3764
# Seed set to 5145
# Seed set to 1902
# Seed set to 7016
# Seed set to 6535
# Seed set to 2985
# Seed set to 8901
# Seed set to 5713
# Seed set to 6922
# Seed set to 8147
# Seed set to 811
# Seed set to 6931
# Seed set to 20
# Seed set to 206
# Seed set to 4932
# Seed set to 5830
# Seed set to 2481
# Seed set to 3357
# Seed set to 1773
# Seed set to 4374
# Seed set to 7610
# Seed set to 1521
# Seed set to 1502
# Seed set to 2882
# Seed set to 2739
# Seed set to 7068
# Seed set to 7309
# Seed set to 5146
# Seed set to 7439
# Seed set to 2193
# Seed set to 7317
# Seed set to 2140
# Seed set to 1537
# Seed set to 4305
# Seed set to 4244
# Seed set to 8703
# Seed set to 4820
# Seed set to 5604
# Seed set to 1151
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 728, 'input_size': 8, 'logger': False, 'default_root_dir': None}
# Seed set to 6615
# Seed set to 3586
# Seed set to 7576
# Seed set to 89
# Seed set to 4170
# Seed set to 3281
# Seed set to 3510
# Seed set to 9466
# Seed set to 3635
# Seed set to 2171
# temperature.txt
# Seed set to 9665
# Seed set to 7170
# Seed set to 8102
# Seed set to 6756
# Seed set to 1097
# Seed set to 9107
# Seed set to 6700
# Seed set to 9850
# Seed set to 2564
# Seed set to 9507
# Seed set to 4395
# Seed set to 5794
# Seed set to 4897
# Seed set to 4803
# Seed set to 2777
# Seed set to 2541
# Seed set to 5605
# Seed set to 2430
# Seed set to 3545
# Seed set to 527
# Seed set to 7593
# Seed set to 2728
# Seed set to 5554
# Seed set to 1649
# Seed set to 1898
# Seed set to 925
# Seed set to 324
# Seed set to 4984
# Seed set to 6419
# Seed set to 3487
# Seed set to 892
# Seed set to 6212
# Seed set to 1685
# Seed set to 1320
# Seed set to 8079
# Seed set to 3520
# Seed set to 7036
# Seed set to 9456
# Seed set to 7154
# Seed set to 9027
# Seed set to 4963
# Seed set to 5240
# Seed set to 7476
# Seed set to 996
# Seed set to 437
# Seed set to 6116
# Seed set to 4623
# Seed set to 8192
# Seed set to 9331
# Seed set to 4788
# Seed set to 8083
# Seed set to 3739
# Seed set to 8250
# Seed set to 1546
# Seed set to 4453
# Seed set to 760
# Seed set to 9838
# Seed set to 6244
# Seed set to 7516
# Seed set to 1286
# Seed set to 2187
# Seed set to 4425
# Seed set to 7435
# Seed set to 4055
# Seed set to 6481
# Seed set to 4224
# Seed set to 7882
# Seed set to 6715
# Seed set to 3587
# Seed set to 9382
# Seed set to 6432
# Seed set to 4185
# Seed set to 9785
# Seed set to 9190
# Seed set to 8728
# Seed set to 5744
# Seed set to 256
# Seed set to 2732
# Seed set to 8242
# Seed set to 2728
# Seed set to 5554
# Seed set to 1649
# Seed set to 1898
# Seed set to 925
# Seed set to 324
# Seed set to 4984
# Seed set to 6419
# Seed set to 3487
# Seed set to 892
# Seed set to 6212
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[50, 50], [50, 50], [50, 50]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 7154, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 1685
# Seed set to 1320
# Seed set to 8079
# Seed set to 3520
# Seed set to 7036
# Seed set to 9456
# Seed set to 7154
# Seed set to 9027
# Seed set to 4963
# Seed set to 5240
# woolyrnq.txt
# Seed set to 7715
# Seed set to 5754
# Seed set to 5803
# Seed set to 8822
# Seed set to 5007
# Seed set to 557
# Seed set to 8976
# Seed set to 5680
# Seed set to 9591
# Seed set to 3962
# Seed set to 304
# Seed set to 8251
# Seed set to 3769
# Seed set to 5812
# Seed set to 3639
# Seed set to 9102
# Seed set to 2925
# Seed set to 2005
# Seed set to 4412
# Seed set to 2061
# Seed set to 5693
# Seed set to 4227
# Seed set to 8531
# Seed set to 6342
# Seed set to 6997
# Seed set to 1848
# Seed set to 7587
# Seed set to 9749
# Seed set to 8195
# Seed set to 2341
# Seed set to 1214
# Seed set to 9065
# Seed set to 3934
# Seed set to 6833
# Seed set to 8549
# Seed set to 6326
# Seed set to 724
# Seed set to 3154
# Seed set to 7178
# Seed set to 4615
# Seed set to 5222
# Seed set to 4136
# Seed set to 8335
# Seed set to 7813
# Seed set to 1660
# Seed set to 2836
# Seed set to 2544
# Seed set to 6752
# Seed set to 766
# Seed set to 102
# Seed set to 5537
# Seed set to 397
# Seed set to 2383
# Seed set to 18
# Seed set to 5376
# Seed set to 780
# Seed set to 652
# Seed set to 5841
# Seed set to 1635
# Seed set to 9128
# Seed set to 4058
# Seed set to 1694
# Seed set to 9445
# Seed set to 6817
# Seed set to 7491
# Seed set to 5340
# Seed set to 131
# Seed set to 1320
# Seed set to 886
# Seed set to 5225
# Seed set to 1634
# Seed set to 4003
# Seed set to 6249
# Seed set to 8749
# Seed set to 234
# Seed set to 4102
# Seed set to 553
# Seed set to 2409
# Seed set to 1518
# Seed set to 1903
# Seed set to 9639
# Seed set to 4084
# Seed set to 4267
# Seed set to 8862
# Seed set to 4192
# Seed set to 5328
# Seed set to 1448
# Seed set to 8600
# Seed set to 6825
# Seed set to 6610
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.001, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[20, 20], [20, 20], [20, 20]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 766, 'input_size': 8, 'logger': False, 'default_root_dir': None}
# Seed set to 8482
# Seed set to 9683
# Seed set to 791
# Seed set to 9786
# Seed set to 1163
# Seed set to 8337
# Seed set to 8815
# Seed set to 979
# Seed set to 3274
# Seed set to 2271
# melbmin.txt
# Seed set to 1254
# Seed set to 7117
# Seed set to 9469
# Seed set to 3361
# Seed set to 4928
# Seed set to 8209
# Seed set to 505
# Seed set to 6134
# Seed set to 1843
# Seed set to 2993
# Seed set to 4217
# Seed set to 6936
# Seed set to 4723
# Seed set to 2084
# Seed set to 6823
# Seed set to 9139
# Seed set to 5370
# Seed set to 5894
# Seed set to 8298
# Seed set to 9372
# Seed set to 2096
# Seed set to 7643
# Seed set to 3328
# Seed set to 2599
# Seed set to 7511
# Seed set to 5290
# Seed set to 841
# Seed set to 3810
# Seed set to 4567
# Seed set to 7765
# Seed set to 7793
# Seed set to 4631
# Seed set to 3225
# Seed set to 725
# Seed set to 2113
# Seed set to 6175
# Seed set to 2181
# Seed set to 4512
# Seed set to 5828
# Seed set to 6425
# Seed set to 8952
# Seed set to 4509
# Seed set to 7301
# Seed set to 8138
# Seed set to 6583
# Seed set to 1068
# Seed set to 5722
# Seed set to 8967
# Seed set to 5292
# Seed set to 7151
# Seed set to 7003
# Seed set to 9431
# Seed set to 916
# Seed set to 8139
# Seed set to 3665
# Seed set to 1240
# Seed set to 6298
# Seed set to 8161
# Seed set to 7729
# Seed set to 1739
# Seed set to 677
# Seed set to 8781
# Seed set to 9256
# Seed set to 9319
# Seed set to 3819
# Seed set to 8418
# Seed set to 3329
# Seed set to 4674
# Seed set to 9791
# Seed set to 4037
# Seed set to 2016
# Seed set to 387
# Seed set to 504
# Seed set to 9980
# Seed set to 8186
# Seed set to 54
# Seed set to 2729
# Seed set to 339
# Seed set to 5885
# Seed set to 1868
# Seed set to 8971
# Seed set to 8324
# Seed set to 3918
# Seed set to 3567
# Seed set to 6821
# Seed set to 6257
# Seed set to 4722
# Seed set to 305
# Seed set to 9540
# Seed set to 3453
# {'enable_model_summary': False, 'enable_progress_bar': False, 'inference_windows_batch_size': 1, 'learning_rate': 0.01, 'loss': RMSE(), 'max_steps': 200, 'mlp_units': [[10, 10], [10, 10], [10, 10]], 'n_freq_downsample': [2, 1, 1], 'scaler_type': 'minmax', 'val_check_steps': 10, 'h': 1, 'random_seed': 4567, 'input_size': 20, 'logger': False, 'default_root_dir': None}
# Seed set to 436
# Seed set to 4550
# Seed set to 3917
# Seed set to 1796
# Seed set to 6451
# Seed set to 2215
# Seed set to 2723
# Seed set to 9673
# Seed set to 9354

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import KAN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = KAN

experiment_id = 'resudualens'
model_name = 'kanval'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'hidden_size': [50, 100, 200],
    'loss': [RMSE()],
    'max_steps': [100],
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 3914
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# samuday.txt
# Seed set to 2984
# Seed set to 976
# Seed set to 6620
# Seed set to 9256
# Seed set to 470
# Seed set to 5740
# Seed set to 779
# Seed set to 7706
# Seed set to 6740
# Seed set to 6297
# Seed set to 338
# Seed set to 1907
# Seed set to 3056
# Seed set to 786
# Seed set to 7640
# Seed set to 501
# Seed set to 696
# Seed set to 2259
# Seed set to 7849
# Seed set to 9609
# Seed set to 8426
# Seed set to 7182
# Seed set to 7255
# Seed set to 3996
# Seed set to 207
# Seed set to 8398
# Seed set to 4170
# Seed set to 6282
# Seed set to 2118
# Seed set to 9627
# {'hidden_size': 200, 'loss': RMSE(), 'max_steps': 100, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 2118, 'input_size': 7, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 6824
# Seed set to 3530
# Seed set to 7689
# Seed set to 2058
# Seed set to 7533
# Seed set to 96
# Seed set to 6439
# Seed set to 4851
# Seed set to 8957
# recifeaccday.txt
# windspeedrecife.txt
# windspeednatal.txt
# windspeedfortaleza.txt
# irradiancesalvador.txt
# irradiancefortaleza.txt
# irradiancefloripa.txt
# irradiancesp.txt
# coloradoRiver.txt
# sunspot.txt
# milk.txt
# Unemployment.txt
# ausbee.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
# woolyrnq.txt
# melbmin.txt

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import TCN
from neuralforecast.losses.pytorch import DistributionLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = TCN

experiment_id = 'resudualens'
model_name = 'tcn'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'loss': [RMSE()],
    'learning_rate': [5e-4],
    'max_steps': [500],
    'kernel_size': [2],
    'dilations':[[1,2,4,8,16]],
    'context_size': [10],
    'decoder_hidden_size': [128],
    'encoder_hidden_size': [128],
    'decoder_layers': [2]
}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# Seed set to 1421
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# recifeaccday.txt
# Seed set to 8022
# Seed set to 6537
# Seed set to 8425
# Seed set to 4318
# Seed set to 9811
# Seed set to 8574
# Seed set to 5601
# Seed set to 5610
# Seed set to 5404
# Seed set to 5388
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 5404, 'input_size': 7, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 3236
# Seed set to 7829
# Seed set to 4424
# Seed set to 6044
# Seed set to 1423
# Seed set to 3500
# Seed set to 2824
# Seed set to 3364
# Seed set to 3056
# Seed set to 5277
# windspeedrecife.txt
# Seed set to 4141
# Seed set to 4803
# Seed set to 954
# Seed set to 9389
# Seed set to 2708
# Seed set to 3071
# Seed set to 7468
# Seed set to 3949
# Seed set to 9610
# Seed set to 961
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 9610, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 7143
# Seed set to 916
# Seed set to 3330
# Seed set to 8192
# Seed set to 7314
# Seed set to 4383
# Seed set to 2660
# Seed set to 9511
# Seed set to 6004
# Seed set to 8404
# windspeednatal.txt
# Seed set to 5963
# Seed set to 3598
# Seed set to 8491
# Seed set to 7686
# Seed set to 1755
# Seed set to 674
# Seed set to 1657
# Seed set to 6589
# Seed set to 8058
# Seed set to 8972
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 8058, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 6880
# Seed set to 9003
# Seed set to 226
# Seed set to 7763
# Seed set to 34
# Seed set to 2751
# Seed set to 1554
# Seed set to 6894
# Seed set to 2
# Seed set to 1243
# windspeedfortaleza.txt
# Seed set to 7801
# Seed set to 6682
# Seed set to 7672
# Seed set to 6703
# Seed set to 1508
# Seed set to 8411
# Seed set to 4139
# Seed set to 1027
# Seed set to 7996
# Seed set to 7970
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 7996, 'input_size': 12, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 7945
# Seed set to 3481
# Seed set to 2808
# Seed set to 6957
# Seed set to 693
# Seed set to 5951
# Seed set to 2670
# Seed set to 7700
# Seed set to 3158
# Seed set to 8732
# irradiancesalvador.txt
# Seed set to 613
# Seed set to 7765
# Seed set to 5070
# Seed set to 7077
# Seed set to 9696
# Seed set to 2807
# Seed set to 2309
# Seed set to 4841
# Seed set to 2184
# Seed set to 3937
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 2184, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 8378
# Seed set to 4535
# Seed set to 2846
# Seed set to 9693
# Seed set to 4980
# Seed set to 5155
# Seed set to 1024
# Seed set to 5533
# Seed set to 833
# Seed set to 3258
# irradiancefortaleza.txt
# Seed set to 176
# Seed set to 1126
# Seed set to 1827
# Seed set to 6448
# Seed set to 6240
# Seed set to 3061
# Seed set to 6804
# Seed set to 9473
# Seed set to 1907
# Seed set to 6844
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 1907, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 2290
# Seed set to 9806
# Seed set to 1824
# Seed set to 2637
# Seed set to 9363
# Seed set to 7916
# Seed set to 1575
# Seed set to 7925
# Seed set to 6163
# Seed set to 2472
# irradiancefloripa.txt
# Seed set to 2084
# Seed set to 1257
# Seed set to 1148
# Seed set to 6178
# Seed set to 6774
# Seed set to 2245
# Seed set to 7346
# Seed set to 5026
# Seed set to 311
# Seed set to 4457
# {'context_size': 10, 'decoder_hidden_size': 128, 'decoder_layers': 2, 'dilations': [1, 2, 4, 8, 16], 'encoder_hidden_size': 128, 'kernel_size': 2, 'learning_rate': 0.0005, 'loss': RMSE(), 'max_steps': 500, 'scaler_type': 'minmax', 'h': 1, 'random_seed': 311, 'input_size': 20, 'logger': False, 'enable_progress_bar': False, 'enable_model_summary': False, 'default_root_dir': None}
# Seed set to 81
# Seed set to 2769
# Seed set to 3719
# Seed set to 9084

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from neuralforecast.models import DeepAR
from neuralforecast.losses.pytorch import DistributionLoss, MQLoss
from model import neural_forecast_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
    
model = DeepAR

experiment_id = 'resudualens'
model_name = 'deepar'
normalize = True
force = True
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'scaler_type': ['minmax'],
    'lstm_n_layers': [2],
    'trajectory_samples': [100],
    'lstm_hidden_size': [20, 50, 100],
    'valid_loss': [MQLoss(level=[80, 90])],
    'loss': [RMSE()],
    'learning_rate': [0.01, 0.001, 0.0001],
    'max_steps': [100],

}

grid_search_exp.grid_seach_multiple_bases(
     neural_forecast_exp.NeuralForecastExp, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
