# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model.scn import SCN_III, sigmoid

from model import single_ml_model_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = SCN_III()

experiment_id = 'resudualens'
model_name = f'scn'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters = {
    'l_max': [5, 10, 20, 30],
    "t_max": [10],
    'hidden_act_fuction': [sigmoid],#, relu, sigmoid, linear]
}

# %%
grid_search_exp.grid_seach_multiple_bases(
     single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# recifeaccday.txt
# windspeedrecife.txt
# windspeednatal.txt
# windspeedfortaleza.txt
# irradiancesalvador.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 30, 't_max': 10}
# irradiancefortaleza.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 30, 't_max': 10}
# irradiancefloripa.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 30, 't_max': 10}
# irradiancesp.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 30, 't_max': 10}
# coloradoRiver.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 10, 't_max': 10}
# sunspot.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 10, 't_max': 10}
# milk.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 20, 't_max': 10}
# Unemployment.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 20, 't_max': 10}
# ausbee.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 20, 't_max': 10}
# austres.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 5, 't_max': 10}
# heartrate.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 10, 't_max': 10}
# ozon.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 5, 't_max': 10}
# pollution.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 20, 't_max': 10}
# redwine.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 20, 't_max': 10}
# gasoline.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 10, 't_max': 10}
# temperature.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 30, 't_max': 10}
# woolyrnq.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 5, 't_max': 10}
# melbmin.txt
# {'hidden_act_fuction': <function sigmoid at 0x7ead9a8ab130>, 'l_max': 30, 't_max': 10}
