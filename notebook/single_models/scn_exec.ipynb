# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

from model.scn import SCN_III, sigmoid

from model import single_ml_model_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

model = SCN_III()

experiment_id = 'multiplebases'
model_name = f'scn'
normalize = True
force = False
model_exec = 10

experiment_params = {
    'diff_kpss': False,
    'horizon': 1
}

model_parameters = {
    'l_max': [5, 10, 20, 30],
    "t_max": [10],
    'hidden_act_fuction': [sigmoid],#, relu, sigmoid, linear]
}

grid_search_exp.grid_seach_multiple_bases(
     single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# lakeerie
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 4/4 [01:00<00:00, 15.19s/it]
# {'hidden_act_fuction': <function sigmoid at 0x764372ab6a20>, 'l_max': 30, 't_max': 10}
# sunspot.txt
# austres.txt
# heartrate.txt
# ozon.txt
# pollution.txt
# redwine.txt
# gasoline.txt
# temperature.txt
