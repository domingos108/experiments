# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from sklearn.svm import SVR

from model import single_ml_model_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

# %%
model = SVR(max_iter=100000)

experiment_id = 'resudualens'
model_name = 'svr'
normalize = True
force = True
model_exec = 1

experiment_params = {
    'diff_kpss': True,
    'horizon': 1
}

model_parameters =  {
    'C':[10, 100, 1000], 'gamma': ['auto'],
    'kernel':["rbf"],
    'epsilon': [0.1, 0.01, 0.001], 'tol':[0.001],
}

# %%
grid_search_exp.grid_seach_multiple_bases(
     single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# recifeaccday.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedrecife.txt
# {'C': 10, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeednatal.txt
# {'C': 10, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedfortaleza.txt
# {'C': 100, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# irradiancesalvador.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'C': 100, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# irradiancefortaleza.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'C': 10, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# irradiancefloripa.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'C': 100, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# irradiancesp.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# coloradoRiver.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'C': 10, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# sunspot.txt
# {'C': 100, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# milk.txt
# {'C': 10, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# Unemployment.txt
# {'C': 100, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# ausbee.txt
# {'C': 100, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# austres.txt
# {'C': 10, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# heartrate.txt
# {'C': 1000, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# ozon.txt
# {'C': 1000, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# pollution.txt
# {'C': 1000, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# redwine.txt
# {'C': 100, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# gasoline.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'C': 1000, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# temperature.txt
# {'C': 10, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# woolyrnq.txt
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# melbmin.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
