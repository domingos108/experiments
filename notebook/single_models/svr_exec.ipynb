# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from sklearn.svm import SVR

from model import single_ml_model_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

model = SVR(max_iter=100000)

experiment_id = 'hourwindspeed'
model_name = 'svr'
normalize = True
force = True
model_exec = 1

experiment_params = {
    'diff_kpss': False,
    'horizon': 48
}

model_parameters =  {
    'C':[10, 100, 1000], 'gamma': ['auto'],
    'kernel':["rbf"],
    'epsilon': [0.1, 0.01, 0.001], 'tol':[0.001],
}

grid_search_exp.grid_seach_multiple_bases(
     single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# windspeedcampinagrandehour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [06:55<00:00, 46.15s/it]
# {'C': 100, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedcaruaruhour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [06:15<00:00, 41.72s/it]
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedcastelodopiauihour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [02:22<00:00, 15.78s/it]
# {'C': 10, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedmaceiohour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [02:21<00:00, 15.70s/it]
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedsalvadorhour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [01:50<00:00, 12.25s/it]
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}

# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from sklearn.svm import SVR

from model import single_ml_model_exp, grid_search_exp

import config
# %load_ext autoreload
# %autoreload 2

model = SVR(max_iter=100000)

experiment_id = 'hourwindspeed'
model_name = 'svr'
normalize = True
force = True
model_exec = 1

experiment_params = {
    'diff_kpss': False,
    'horizon': 72
}

model_parameters =  {
    'C':[10, 100, 1000], 'gamma': ['auto'],
    'kernel':["rbf"],
    'epsilon': [0.1, 0.01, 0.001], 'tol':[0.001],
}

grid_search_exp.grid_seach_multiple_bases(
     single_ml_model_exp.SKlearnModel, model, normalize, model_parameters,experiment_params,
     model_exec, model_name, experiment_id, force = force
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# windspeedcampinagrandehour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [02:25<00:00, 16.19s/it]
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedcaruaruhour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [02:18<00:00, 15.43s/it]
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedcastelodopiauihour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [02:16<00:00, 15.17s/it]
# {'C': 10, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedmaceiohour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [02:20<00:00, 15.56s/it]
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# windspeedsalvadorhour.txt
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [01:52<00:00, 12.52s/it]
# {'C': 10, 'epsilon': 0.1, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
