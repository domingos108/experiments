# %%
from sklearn.svm import SVR

from model import generics

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = ['lynx.txt','sunspot.txt']
lag_size_list = [5, 18]
normalize=True

model_exec = 1

parameters = {'C':[10, 100, 1000], 'gamma': [0.1, 0.01, 0.001],
                  'kernel':["rbf"],
                  'epsilon': [0.1, 0.01, 0.001], 'tol':[0.001]
                 }

model = SVR(max_iter=100000)
model_name = 'svr'
experiment_id = 'test'

generics.grid_seach_multiple_bases(model,  base_name_list, normalize, lag_size_list,
                                   parameters, model_exec, model_name, experiment_id)
# Out:
# lynx.txt
# 100%|██████████████████████████████████████████| 27/27 [00:00<00:00, 197.26it/s]
# > /home/domingossj/experiments/src/model/generics.py(28)fit_predict_ml_schemma()
#      27         import ipdb;ipdb.set_trace()
# ---> 28     return train_predict, val_predict, test_predict
#      29
# ipdb>  test_predict
# array([ 0.43452977,  0.47638896,  0.26883578,  0.30464747,  0.38229976,
#        -0.13572673,  0.0807234 , -0.03928558,  0.06757068,  0.12495481,
#         0.15055326,  0.26283172,  0.41246487,  0.48398619,  0.26835702,
#         0.09655954,  0.00427374,  0.05739051,  0.10226946,  0.18992826,
#         0.27165542,  0.39465616])
# ipdb>  x_train.shape
# (87, 5)
