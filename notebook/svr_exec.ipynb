# %%
from sklearn.svm import SVR

from model import generics

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = ['lynx.txt','sunspot.txt']
lag_size_list = [5, 18]
normalize=True

model_exec = 1

parameters = {'C':[10, 100, 1000], 'gamma': [0.9, 0.1, 0.01],
                  'kernel':["rbf"],
                  'epsilon': [0.9, 0.1, 0.01], 'tol':[0.001]
                 }

model = SVR(max_iter=100000)
model_name = 'svr'
experiment_id = 'test'

generics.grid_seach_multiple_bases(model,  base_name_list, normalize, lag_size_list,
                                   parameters, model_exec, model_name, experiment_id)
# Out:
# lynx.txt
# Modelo já executado
# sunspot.txt
# Modelo já executado
