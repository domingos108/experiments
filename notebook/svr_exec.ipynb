# %%
import warnings
from statsmodels.tools.sm_exceptions import InterpolationWarning

warnings.simplefilter('ignore', InterpolationWarning)

from sklearn.svm import SVR

from model import generics

import config
# %load_ext autoreload
# %autoreload 2

# %%
base_name_list = config.BASE_NAME_LIST
normalize=True
force = False
model_exec = 1

parameters = {'C':[10, 100, 1000], 'gamma': ['auto'],
                  'kernel':["rbf"],
                  'epsilon': [0.1, 0.01, 0.001], 'tol':[0.001],
                'time_window': [None]#[12, 24, 72, 168]#[2, 6, 8, 12]
                 }

model = SVR(max_iter=100000)
model_name = 'svr'

experiment_id = 'scnexps'

generics.grid_seach_multiple_bases(model,  base_name_list, normalize,
                                   parameters, model_exec, model_name, experiment_id, force = force)
# Out:
# sunspot.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# coloradoRiver.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# milk.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#   0%|          | 0/9 [00:00<?, ?it/s]
# Unemployment.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# ausbee.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# austres.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# heartrate.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# ozon.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# pollution.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# redwine.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# taylor.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# gasoline.txt
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#   0%|          | 0/9 [00:00<?, ?it/s]
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /home/domingossj/experiments/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# temperature.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
# woolyrnq.txt
#   0%|          | 0/9 [00:00<?, ?it/s]
